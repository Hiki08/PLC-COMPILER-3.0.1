# %%
#Load PyFiles
from Imports import *
from QualityControlDataManager import em2P
import QualityControlDataManager
import DateAndTimeManager

# %%
#Variables 




excelData = ""

repairedProcess = ""

compiledFrame2 = ""
excelData2 = ""
processData = ""



processPendingToRepair = []



tempdfPi = ""



readCount = 0



dateToRead = "2024/11/28"
dateToReadDashFormat = "2024-11-28"

#UI Variables

compileButton = ""
autoRunButton = ""
autoRun = False

loadingText = "Loading"

time_picker = ""

frame1 = ""
frame2 = ""

calendarPicker = ""

# %%
#Compiler For PI 
class PiCompiler():
    dfPi = ""
    canCompilePI = False
    dfPiNotDone = ""

    piRow = 0

    compiledFrame = ""

    def __init__(self):
        pass

    #Checking If There's Master Pump In PICompiled
    def CheckPICsv(self):

        pd.set_option('display.max_columns', None)
        pd.set_option('display.max_rows', None)

        self.canCompilePI = False
        
        piDirectory = (r'\\192.168.2.19\ai_team\AI Program\Outputs\PICompiled')
        os.chdir(piDirectory)

        self.dfPi = pd.read_csv(f'PICompiled{dateToReadDashFormat}.csv', encoding='latin1')
        
        self.dfPiNotDone = self.dfPi[(self.dfPi["CHECKING"].isin(["-"])) & (self.dfPi["PROCESS S/N"].isin(["MASTER PUMP"])) | (self.dfPi["PROCESS S/N"].isin(["RUNNING"]))]
        if len(self.dfPiNotDone) != 0:
            self.canCompilePI = True
        else:
            self.canCompilePI = False

    def CompilePICsv(self):
        
        for a in range(0, len(self.dfPiNotDone)):
            self.piRow += 1

            tempdfPi = self.dfPiNotDone.iloc[[a], :]

            if tempdfPi["PROCESS S/N"].values[0] == "MASTER PUMP":
                processData = "MASTER PUMP"
            elif tempdfPi["PROCESS S/N"].values[0] == "RUNNING":
                processData = "RUNNING"

            # piDirectory = (r'\\192.168.2.19\ai_team\AI Program\Outputs')
            # os.chdir(piDirectory)

            # tempdfPi = dfPi.iloc[[a], :]
            # dfPi.loc[dfPi["TIME"] == tempdfPi["TIME"].values[0], "CHECKING"] = "Done"
            # dfPi.to_csv(f"PICompiled.csv", index = False)
            

            excelData2 = {
                        "DATE": tempdfPi["DATE"].values,
                        "TIME": tempdfPi["TIME"].values,
                        "MODEL CODE": tempdfPi["MODEL CODE"].values,
                        "PROCESS S/N": tempdfPi["PROCESS S/N"].values,
                        "S/N": tempdfPi["S/N"].values,
                        "PASS/NG": tempdfPi["PASS/NG"].values,
                        "VOLTAGE MAX (V)": tempdfPi["VOLTAGE MAX (V)"].values,
                        "WATTAGE MAX (W)": tempdfPi["WATTAGE MAX (W)"].values,
                        "CLOSED PRESSURE_MAX (kPa)": tempdfPi["CLOSED PRESSURE_MAX (kPa)"].values,
                        "VOLTAGE Middle (V)": tempdfPi["VOLTAGE Middle (V)"].values,
                        "WATTAGE Middle (W)": tempdfPi["WATTAGE Middle (W)"].values,
                        "AMPERAGE Middle (A)": tempdfPi["AMPERAGE Middle (A)"].values,
                        "CLOSED PRESSURE Middle (kPa)": tempdfPi["CLOSED PRESSURE Middle (kPa)"].values,
                        "dB(A) 1": tempdfPi["dB(A) 1"].values,
                        "dB(A) 2": tempdfPi["dB(A) 2"].values,
                        "dB(A) 3": tempdfPi["dB(A) 3"].values,
                        "VOLTAGE MIN (V)": tempdfPi["VOLTAGE MIN (V)"].values,
                        "WATTAGE MIN (W)": tempdfPi["WATTAGE MIN (W)"].values,
                        "CLOSED PRESSURE MIN (kPa)": tempdfPi["CLOSED PRESSURE MIN (kPa)"].values,
             
                        "Process 1 Model Code" : [processData],
                        "Process 1 S/N" : [processData],
                        "Process 1 ID" : [processData],
                        "Process 1 NAME" : [processData],
                        "Process 1 Regular/Contractual" : [processData],
                        "Process 1 Em2p" : [processData],
                        "Process 1 Em2p Lot No" : [processData],
                        "Process 1 Em2p Inspection 3 Average Data" : [processData],
                        "Process 1 Em2p Inspection 4 Average Data" : [processData],
                        "Process 1 Em2p Inspection 5 Average Data" : [processData],
                        "Process 1 Em2p Inspection 10 Average Data" : [processData],
                        "Process 1 Em2p Inspection 3 Minimum Data" : [processData],
                        "Process 1 Em2p Inspection 4 Minimum Data" : [processData],
                        "Process 1 Em2p Inspection 5 Minimum Data" : [processData],
                        "Process 1 Em2p Inspection 3 Maximum Data" : [processData],
                        "Process 1 Em2p Inspection 4 Maximum Data" : [processData],
                        "Process 1 Em2p Inspection 5 Maximum Data" : [processData],
                        "Process 1 Em3p" : [processData],
                        "Process 1 Em3p Lot No" : [processData],
                        "Process 1 Em3p Inspection 3 Average Data" : [processData],
                        "Process 1 Em3p Inspection 4 Average Data" : [processData],
                        "Process 1 Em3p Inspection 5 Average Data" : [processData],
                        "Process 1 Em3p Inspection 10 Average Data" : [processData],
                        "Process 1 Em3p Inspection 3 Minimum Data" : [processData],
                        "Process 1 Em3p Inspection 4 Minimum Data" : [processData],
                        "Process 1 Em3p Inspection 5 Minimum Data" : [processData],
                        "Process 1 Em3p Inspection 3 Maximum Data" : [processData],
                        "Process 1 Em3p Inspection 4 Maximum Data" : [processData],
                        "Process 1 Em3p Inspection 5 Maximum Data" : [processData],
                        "Process 1 Harness" : [processData],
                        "Process 1 Harness Lot No" : [processData],
                        "Process 1 Frame" : [processData],
                        "Process 1 Frame Lot No" : [processData],
                        "Process 1 Frame Inspection 1 Average Data" : [processData], 
                        "Process 1 Frame Inspection 2 Average Data" : [processData], 
                        "Process 1 Frame Inspection 3 Average Data" : [processData], 
                        "Process 1 Frame Inspection 4 Average Data" : [processData], 
                        "Process 1 Frame Inspection 5 Average Data" : [processData], 
                        "Process 1 Frame Inspection 6 Average Data" : [processData], 
                        "Process 1 Frame Inspection 7 Average Data" : [processData], 
                        "Process 1 Frame Inspection 1 Minimum Data" : [processData], 
                        "Process 1 Frame Inspection 2 Minimum Data" : [processData], 
                        "Process 1 Frame Inspection 3 Minimum Data" : [processData], 
                        "Process 1 Frame Inspection 4 Minimum Data" : [processData], 
                        "Process 1 Frame Inspection 5 Minimum Data" : [processData], 
                        "Process 1 Frame Inspection 6 Minimum Data" : [processData], 
                        "Process 1 Frame Inspection 7 Minimum Data" : [processData], 
                        "Process 1 Frame Inspection 1 Maximum Data" : [processData], 
                        "Process 1 Frame Inspection 2 Maximum Data" : [processData], 
                        "Process 1 Frame Inspection 3 Maximum Data" : [processData], 
                        "Process 1 Frame Inspection 4 Maximum Data" : [processData], 
                        "Process 1 Frame Inspection 5 Maximum Data" : [processData], 
                        "Process 1 Frame Inspection 6 Maximum Data" : [processData], 
                        "Process 1 Frame Inspection 7 Maximum Data" : [processData], 
                        "Process 1 Bushing" : [processData],
                        "Process 1 Bushing Lot No" : [processData],
                        "Process 1 ST" : [processData],
                        "Process 1 Actual Time" : [processData],
                        "Process 1 NG Cause" : [processData],
                        "Process 1 Repaired Action" : [processData],

                        "Process 2 Model Code" : [processData],
                        "Process 2 S/N" : [processData],
                        "Process 2 ID" : [processData],
                        "Process 2 NAME" : [processData],
                        "Process 2 Regular/Contractual" : [processData],
                        "Process 2 M4x40 Screw" : [processData],
                        "Process 2 M4x40 Screw Lot No" : [processData],
                        "Process 2 Rod Blk" : [processData],
                        "Process 2 Rod Blk Lot No" : [processData],
                        "Process 2 Rod Blk Tesla 1 Average Data" : [processData],
                        "Process 2 Rod Blk Tesla 2 Average Data" : [processData],
                        "Process 2 Rod Blk Tesla 3 Average Data" : [processData],
                        "Process 2 Rod Blk Tesla 4 Average Data" : [processData],
                        "Process 2 Rod Blk Tesla 1 Minimum Data" : [processData],
                        "Process 2 Rod Blk Tesla 2 Minimum Data" : [processData],
                        "Process 2 Rod Blk Tesla 3 Minimum Data" : [processData],
                        "Process 2 Rod Blk Tesla 4 Minimum Data" : [processData],
                        "Process 2 Rod Blk Tesla 1 Maximum Data" : [processData],
                        "Process 2 Rod Blk Tesla 2 Maximum Data" : [processData],
                        "Process 2 Rod Blk Tesla 3 Maximum Data" : [processData],
                        "Process 2 Rod Blk Tesla 4 Maximum Data" : [processData],
                        "Process 2 Rod Blk Inspection 1 Average Data" : [processData],
                        "Process 2 Rod Blk Inspection 2 Average Data" : [processData],
                        "Process 2 Rod Blk Inspection 3 Average Data" : [processData],
                        "Process 2 Rod Blk Inspection 4 Average Data" : [processData],
                        "Process 2 Rod Blk Inspection 5 Average Data" : [processData],
                        "Process 2 Rod Blk Inspection 6 Average Data" : [processData],
                        "Process 2 Rod Blk Inspection 8 Average Data" : [processData],
                        "Process 2 Rod Blk Inspection 1 Minimum Data" : [processData],
                        "Process 2 Rod Blk Inspection 2 Minimum Data" : [processData],
                        "Process 2 Rod Blk Inspection 3 Minimum Data" : [processData],
                        "Process 2 Rod Blk Inspection 4 Minimum Data" : [processData],
                        "Process 2 Rod Blk Inspection 5 Minimum Data" : [processData],
                        "Process 2 Rod Blk Inspection 6 Minimum Data" : [processData],
                        "Process 2 Rod Blk Inspection 8 Minimum Data" : [processData],
                        "Process 2 Rod Blk Inspection 1 Maximum Data" : [processData],
                        "Process 2 Rod Blk Inspection 2 Maximum Data" : [processData],
                        "Process 2 Rod Blk Inspection 3 Maximum Data" : [processData],
                        "Process 2 Rod Blk Inspection 4 Maximum Data" : [processData],
                        "Process 2 Rod Blk Inspection 5 Maximum Data" : [processData],
                        "Process 2 Rod Blk Inspection 6 Maximum Data" : [processData],
                        "Process 2 Rod Blk Inspection 8 Maximum Data" : [processData],
                        "Process 2 Df Blk" : [processData],
                        "Process 2 Df Blk Lot No" : [processData],
                        "Process 2 Df Blk Inspection 1 Average Data" : [processData],
                        "Process 2 Df Blk Inspection 2 Average Data" : [processData],
                        "Process 2 Df Blk Inspection 3 Average Data" : [processData],
                        "Process 2 Df Blk Inspection 4 Average Data" : [processData],
                        "Process 2 Df Blk Inspection 1 Minimum Data" : [processData],
                        "Process 2 Df Blk Inspection 2 Minimum Data" : [processData],
                        "Process 2 Df Blk Inspection 3 Minimum Data" : [processData],
                        "Process 2 Df Blk Inspection 4 Minimum Data" : [processData],
                        "Process 2 Df Blk Inspection 1 Maximum Data" : [processData],
                        "Process 2 Df Blk Inspection 2 Maximum Data" : [processData],
                        "Process 2 Df Blk Inspection 3 Maximum Data" : [processData],
                        "Process 2 Df Blk Inspection 4 Maximum Data" : [processData],
                        "Process 2 Df Ring" : [processData],
                        "Process 2 Df Ring Lot No" : [processData],
                        "Process 2 Washer" : [processData],
                        "Process 2 Washer Lot No" : [processData],
                        "Process 2 Lock Nut" : [processData],
                        "Process 2 Lock Nut Lot No" : [processData],
                        "Process 2 ST" : [processData],
                        "Process 2 Actual Time" : [processData],
                        "Process 2 NG Cause" : [processData],
                        "Process 2 Repaired Action" : [processData],

                        "Process 3 Model Code" : [processData],
                        "Process 3 S/N" : [processData],
                        "Process 3 ID" : [processData],
                        "Process 3 NAME" : [processData],
                        "Process 3 Regular/Contractual" : [processData],
                        "Process 3 Frame Gasket" : [processData],
                        "Process 3 Frame Gasket Lot No" : [processData],
                        "Process 3 Casing Block" : [processData],
                        "Process 3 Casing Block Lot No" : [processData],
                        "Process 3 Casing Block Inspection 1 Average Data" : [processData],
                        "Process 3 Casing Block Inspection 1 Minimum Data" : [processData],
                        "Process 3 Casing Block Inspection 1 Maximum Data" : [processData],
                        "Process 3 Casing Gasket" : [processData],
                        "Process 3 Casing Gasket Lot No" : [processData],
                        "Process 3 M4x16 Screw 1" : [processData],
                        "Process 3 M4x16 Screw 1 Lot No" : [processData],
                        "Process 3 M4x16 Screw 2" : [processData],
                        "Process 3 M4x16 Screw 2 Lot No" : [processData],
                        "Process 3 Ball Cushion" : [processData],
                        "Process 3 Ball Cushion Lot No" : [processData],
                        "Process 3 Frame Cover" : [processData],
                        "Process 3 Frame Cover Lot No" : [processData],
                        "Process 3 Partition Board" : [processData],
                        "Process 3 Partition Board Lot No" : [processData],
                        "Process 3 Built In Tube 1" : [processData],
                        "Process 3 Built In Tube 1 Lot No" : [processData],
                        "Process 3 Built In Tube 2" : [processData],
                        "Process 3 Built In Tube 2 Lot No" : [processData],
                        "Process 3 Head Cover" : [processData],
                        "Process 3 Head Cover Lot No" : [processData],
                        "Process 3 Casing Packing" : [processData],
                        "Process 3 Casing Packing Lot No" : [processData],
                        "Process 3 M4x12 Screw" : [processData],
                        "Process 3 M4x12 Screw Lot No" : [processData],
                        "Process 3 Csb L" : [processData],
                        "Process 3 Csb L Lot No" : [processData],
                        "Process 3 Csb R" : [processData],
                        "Process 3 Csb R Lot No" : [processData],
                        "Process 3 Head Packing" : [processData],
                        "Process 3 Head Packing Lot No" : [processData],
                        "Process 3 ST" : [processData],
                        "Process 3 Actual Time" : [processData],
                        "Process 3 NG Cause" : [processData],
                        "Process 3 Repaired Action" : [processData],

                        "Process 4 Model Code" : [processData],
                        "Process 4 S/N" : [processData],
                        "Process 4 ID" : [processData],
                        "Process 4 NAME" : [processData],
                        "Process 4 Regular/Contractual" : [processData],
                        "Process 4 Tank" : [processData],
                        "Process 4 Tank Lot No" : [processData],
                        "Process 4 Upper Housing" : [processData],
                        "Process 4 Upper Housing Lot No" : [processData],
                        "Process 4 Cord Hook" : [processData],
                        "Process 4 Cord Hook Lot No" : [processData],
                        "Process 4 M4x16 Screw" : [processData],
                        "Process 4 M4x16 Screw Lot No" : [processData],
                        "Process 4 Tank Gasket" : [processData],
                        "Process 4 Tank Gasket Lot No" : [processData],
                        "Process 4 Tank Cover" : [processData],
                        "Process 4 Tank Cover Lot No" : [processData],
                        "Process 4 Housing Gasket" : [processData],
                        "Process 4 Housing Gasket Lot No" : [processData],
                        "Process 4 M4x40 Screw" : [processData],
                        "Process 4 M4x40 Screw Lot No" : [processData],
                        "Process 4 PartitionGasket" : [processData],
                        "Process 4 PartitionGasket Lot No" : [processData],
                        "Process 4 M4x12 Screw" : [processData],
                        "Process 4 M4x12 Screw Lot No" : [processData],
                        "Process 4 Muffler" : [processData],
                        "Process 4 Muffler Lot No" : [processData],
                        "Process 4 Muffler Gasket" : [processData],
                        "Process 4 Muffler Gasket Lot No" : [processData],
                        "Process 4 VCR" : [processData],
                        "Process 4 VCR Lot No" : [processData],
                        "Process 4 ST" : [processData],
                        "Process 4 Actual Time" : [processData],
                        "Process 4 NG Cause" : [processData],
                        "Process 4 Repaired Action" : [processData],
                        
                        "Process 5 Model Code" : [processData],
                        "Process 5 S/N" : [processData],
                        "Process 5 ID" : [processData],
                        "Process 5 NAME" : [processData],
                        "Process 5 Regular/Contractual" : [processData],
                        "Process 5 Rating Label" : [processData],
                        "Process 5 Rating Label Lot No" : [processData],
                        "Process 5 ST" : [processData],
                        "Process 5 Actual Time" : [processData],
                        "Process 5 NG Cause" : [processData],
                        "Process 5 Repaired Action" : [processData],
                        
                        "Process 6 Model Code" : [processData],
                        "Process 6 S/N" : [processData],
                        "Process 6 ID" : [processData],
                        "Process 6 NAME" : [processData],
                        "Process 6 Regular/Contractual" : [processData],
                        "Process 6 Vinyl" : [processData],
                        "Process 6 Vinyl Lot No" : [processData],
                        "Process 6 ST" : [processData],
                        "Process 6 Actual Time" : [processData],
                        "Process 6 NG Cause" : [processData],
                        "Process 6 Repaired Action" : [processData]
                    }
            excelData2 = pd.DataFrame(excelData2)
            self.compiledFrame = pd.concat([self.compiledFrame, excelData2], ignore_index=True)

        self.canCompilePI = False

    def start(self):

        self.piRow = 0

        col = [
            "DATE", 
            "TIME", 
            "MODEL CODE", 
            "PROCESS S/N", 
            "S/N", 
            "PASS/NG", 
            "VOLTAGE MAX (V)", 
            "WATTAGE MAX (W)", 
            "CLOSED PRESSURE_MAX (kPa)", 
            "VOLTAGE Middle (V)", 
            "WATTAGE Middle (W)", 
            "AMPERAGE Middle (A)", 
            "CLOSED PRESSURE Middle (kPa)", 
            "dB(A) 1", 
            "dB(A) 2", 
            "dB(A) 3", 
            "VOLTAGE MIN (V)", 
            "WATTAGE MIN (W)", 
            "CLOSED PRESSURE MIN (kPa)",

            "Process 1 Model Code",
            "Process 1 S/N",
            "Process 1 ID",
            "Process 1 NAME",
            "Process 1 Regular/Contractual",
            "Process 1 Em2p",
            "Process 1 Em2p Lot No",
            "Process 1 Em2p Inspection 3 Average Data",
            "Process 1 Em2p Inspection 4 Average Data",
            "Process 1 Em2p Inspection 5 Average Data",
            "Process 1 Em2p Inspection 10 Average Data",
            "Process 1 Em2p Inspection 3 Minimum Data",
            "Process 1 Em2p Inspection 4 Minimum Data",
            "Process 1 Em2p Inspection 5 Minimum Data",
            "Process 1 Em2p Inspection 3 Maximum Data",
            "Process 1 Em2p Inspection 4 Maximum Data",
            "Process 1 Em2p Inspection 5 Maximum Data",
            "Process 1 Em3p",
            "Process 1 Em3p Lot No",
            "Process 1 Em3p Inspection 3 Average Data",
            "Process 1 Em3p Inspection 4 Average Data",
            "Process 1 Em3p Inspection 5 Average Data",
            "Process 1 Em3p Inspection 10 Average Data",
            "Process 1 Em3p Inspection 3 Minimum Data",
            "Process 1 Em3p Inspection 4 Minimum Data",
            "Process 1 Em3p Inspection 5 Minimum Data",
            "Process 1 Em3p Inspection 3 Maximum Data",
            "Process 1 Em3p Inspection 4 Maximum Data",
            "Process 1 Em3p Inspection 5 Maximum Data",
            "Process 1 Harness",
            "Process 1 Harness Lot No",
            "Process 1 Frame",
            "Process 1 Frame Lot No",
            "Process 1 Frame Inspection 1 Average Data", 
            "Process 1 Frame Inspection 2 Average Data", 
            "Process 1 Frame Inspection 3 Average Data", 
            "Process 1 Frame Inspection 4 Average Data", 
            "Process 1 Frame Inspection 5 Average Data", 
            "Process 1 Frame Inspection 6 Average Data", 
            "Process 1 Frame Inspection 7 Average Data", 
            "Process 1 Frame Inspection 1 Minimum Data", 
            "Process 1 Frame Inspection 2 Minimum Data", 
            "Process 1 Frame Inspection 3 Minimum Data", 
            "Process 1 Frame Inspection 4 Minimum Data", 
            "Process 1 Frame Inspection 5 Minimum Data", 
            "Process 1 Frame Inspection 6 Minimum Data", 
            "Process 1 Frame Inspection 7 Minimum Data", 
            "Process 1 Frame Inspection 1 Maximum Data", 
            "Process 1 Frame Inspection 2 Maximum Data", 
            "Process 1 Frame Inspection 3 Maximum Data", 
            "Process 1 Frame Inspection 4 Maximum Data", 
            "Process 1 Frame Inspection 5 Maximum Data", 
            "Process 1 Frame Inspection 6 Maximum Data", 
            "Process 1 Frame Inspection 7 Maximum Data", 
            "Process 1 Bushing",
            "Process 1 Bushing Lot No",
            "Process 1 ST",
            "Process 1 Actual Time",
            "Process 1 NG Cause",
            "Process 1 Repaired Action",

            "Process 2 Model Code",
            "Process 2 S/N",
            "Process 2 ID",
            "Process 2 NAME",
            "Process 2 Regular/Contractual",
            "Process 2 M4x40 Screw",
            "Process 2 M4x40 Screw Lot No",
            "Process 2 Rod Blk",
            "Process 2 Rod Blk Lot No",
            "Process 2 Rod Blk Tesla 1 Average Data",
            "Process 2 Rod Blk Tesla 2 Average Data",
            "Process 2 Rod Blk Tesla 3 Average Data",
            "Process 2 Rod Blk Tesla 4 Average Data",
            "Process 2 Rod Blk Tesla 1 Minimum Data",
            "Process 2 Rod Blk Tesla 2 Minimum Data",
            "Process 2 Rod Blk Tesla 3 Minimum Data",
            "Process 2 Rod Blk Tesla 4 Minimum Data",
            "Process 2 Rod Blk Tesla 1 Maximum Data",
            "Process 2 Rod Blk Tesla 2 Maximum Data",
            "Process 2 Rod Blk Tesla 3 Maximum Data",
            "Process 2 Rod Blk Tesla 4 Maximum Data",
            "Process 2 Rod Blk Inspection 1 Average Data",
            "Process 2 Rod Blk Inspection 2 Average Data",
            "Process 2 Rod Blk Inspection 3 Average Data",
            "Process 2 Rod Blk Inspection 4 Average Data",
            "Process 2 Rod Blk Inspection 5 Average Data",
            "Process 2 Rod Blk Inspection 6 Average Data",
            "Process 2 Rod Blk Inspection 8 Average Data",
            "Process 2 Rod Blk Inspection 1 Minimum Data",
            "Process 2 Rod Blk Inspection 2 Minimum Data",
            "Process 2 Rod Blk Inspection 3 Minimum Data",
            "Process 2 Rod Blk Inspection 4 Minimum Data",
            "Process 2 Rod Blk Inspection 5 Minimum Data",
            "Process 2 Rod Blk Inspection 6 Minimum Data",
            "Process 2 Rod Blk Inspection 8 Minimum Data",
            "Process 2 Rod Blk Inspection 1 Maximum Data",
            "Process 2 Rod Blk Inspection 2 Maximum Data",
            "Process 2 Rod Blk Inspection 3 Maximum Data",
            "Process 2 Rod Blk Inspection 4 Maximum Data",
            "Process 2 Rod Blk Inspection 5 Maximum Data",
            "Process 2 Rod Blk Inspection 6 Maximum Data",
            "Process 2 Rod Blk Inspection 8 Maximum Data",
            "Process 2 Df Blk",
            "Process 2 Df Blk Lot No",
            "Process 2 Df Blk Inspection 1 Average Data",
            "Process 2 Df Blk Inspection 2 Average Data",
            "Process 2 Df Blk Inspection 3 Average Data",
            "Process 2 Df Blk Inspection 4 Average Data",
            "Process 2 Df Blk Inspection 1 Minimum Data",
            "Process 2 Df Blk Inspection 2 Minimum Data",
            "Process 2 Df Blk Inspection 3 Minimum Data",
            "Process 2 Df Blk Inspection 4 Minimum Data",
            "Process 2 Df Blk Inspection 1 Maximum Data",
            "Process 2 Df Blk Inspection 2 Maximum Data",
            "Process 2 Df Blk Inspection 3 Maximum Data",
            "Process 2 Df Blk Inspection 4 Maximum Data",
            "Process 2 Df Ring",
            "Process 2 Df Ring Lot No",
            "Process 2 Washer",
            "Process 2 Washer Lot No",
            "Process 2 Lock Nut",
            "Process 2 Lock Nut Lot No",
            "Process 2 ST",
            "Process 2 Actual Time",
            "Process 2 NG Cause",
            "Process 2 Repaired Action",

            "Process 3 Model Code",
            "Process 3 S/N",
            "Process 3 ID",
            "Process 3 NAME",
            "Process 3 Regular/Contractual",
            "Process 3 Frame Gasket",
            "Process 3 Frame Gasket Lot No",
            "Process 3 Casing Block",
            "Process 3 Casing Block Lot No",
            "Process 3 Casing Block Inspection 1 Average Data",
            "Process 3 Casing Block Inspection 1 Minimum Data",
            "Process 3 Casing Block Inspection 1 Maximum Data",
            "Process 3 Casing Gasket",
            "Process 3 Casing Gasket Lot No",
            "Process 3 M4x16 Screw 1",
            "Process 3 M4x16 Screw 1 Lot No",
            "Process 3 M4x16 Screw 2",
            "Process 3 M4x16 Screw 2 Lot No",
            "Process 3 Ball Cushion",
            "Process 3 Ball Cushion Lot No",
            "Process 3 Frame Cover",
            "Process 3 Frame Cover Lot No",
            "Process 3 Partition Board",
            "Process 3 Partition Board Lot No",
            "Process 3 Built In Tube 1",
            "Process 3 Built In Tube 1 Lot No",
            "Process 3 Built In Tube 2",
            "Process 3 Built In Tube 2 Lot No",
            "Process 3 Head Cover",
            "Process 3 Head Cover Lot No",
            "Process 3 Casing Packing",
            "Process 3 Casing Packing Lot No",
            "Process 3 M4x12 Screw",
            "Process 3 M4x12 Screw Lot No",
            "Process 3 Csb L",
            "Process 3 Csb L Lot No",
            "Process 3 Csb R",
            "Process 3 Csb R Lot No",
            "Process 3 Head Packing",
            "Process 3 Head Packing Lot No",
            "Process 3 ST",
            "Process 3 Actual Time",
            "Process 3 NG Cause",
            "Process 3 Repaired Action",

            "Process 4 Model Code",
            "Process 4 S/N",
            "Process 4 ID",
            "Process 4 NAME",
            "Process 4 Regular/Contractual",
            "Process 4 Tank",
            "Process 4 Tank Lot No",
            "Process 4 Upper Housing",
            "Process 4 Upper Housing Lot No",
            "Process 4 Cord Hook",
            "Process 4 Cord Hook Lot No",
            "Process 4 M4x16 Screw",
            "Process 4 M4x16 Screw Lot No",
            "Process 4 Tank Gasket",
            "Process 4 Tank Gasket Lot No",
            "Process 4 Tank Cover",
            "Process 4 Tank Cover Lot No",
            "Process 4 Housing Gasket",
            "Process 4 Housing Gasket Lot No",
            "Process 4 M4x40 Screw",
            "Process 4 M4x40 Screw Lot No",
            "Process 4 PartitionGasket",
            "Process 4 PartitionGasket Lot No",
            "Process 4 M4x12 Screw",
            "Process 4 M4x12 Screw Lot No",
            "Process 4 Muffler",
            "Process 4 Muffler Lot No",
            "Process 4 Muffler Gasket",
            "Process 4 Muffler Gasket Lot No",
            "Process 4 VCR",
            "Process 4 VCR Lot No",
            "Process 4 ST",
            "Process 4 Actual Time",
            "Process 4 NG Cause",
            "Process 4 Repaired Action",
            
            "Process 5 Model Code",
            "Process 5 S/N",
            "Process 5 ID",
            "Process 5 NAME",
            "Process 5 Regular/Contractual",
            "Process 5 Rating Label",
            "Process 5 Rating Label Lot No",
            "Process 5 ST",
            "Process 5 Actual Time",
            "Process 5 NG Cause",
            "Process 5 Repaired Action",
            
            "Process 6 Model Code",
            "Process 6 S/N",
            "Process 6 ID",
            "Process 6 NAME",
            "Process 6 Regular/Contractual",
            "Process 6 Vinyl",
            "Process 6 Vinyl Lot No",
            "Process 6 ST",
            "Process 6 Actual Time",
            "Process 6 NG Cause",
            "Process 6 Repaired Action"
        ]
        self.compiledFrame = pd.DataFrame(columns=col)

        DateAndTimeManager.GetDateToday()

        try:
            self.CheckPICsv()

            if self.canCompilePI:
                self.CompilePICsv()
                self.WriteCsv(self.compiledFrame)
        except:
            pass

    def WriteCsv(self, data):

        fileDirectory = (r'\\192.168.2.19\ai_team\AI Program\Outputs\CompiledProcess')
        os.chdir(fileDirectory)
        print(os.getcwd())

        print("Creating New File")
        newValue = pd.concat([data], axis = 0, ignore_index = True)
        wireFrame = newValue
        wireFrame.to_csv(f"CompiledProcess{dateToReadDashFormat}.csv", index = False)

# %%
class ProcessCompiler():
    dfVt1 = ""
    dfVt2 = ""
    dfVt3 = ""
    dfVt4 = ""
    dfVt5 = ""
    dfVt6 = ""

    process1Row = 0
    process2Row = 0
    process3Row = 0
    process4Row = 0
    process5Row = 0
    process6Row = 0

    tempDfVt1 = ""
    tempDfVt2 = ""
    tempDfVt3 = ""
    tempDfVt4 = ""
    tempDfVt5 = ""
    tempDfVt6 = ""

    tempdfPi = ""

    ngProcess = ""
    repairedProcess = ""

    process1Status = ""
    process2Status = ""
    process3Status = ""
    process4Status = ""
    process5Status = ""
    process6Status = ""
    isRepairedWithNG = False

    canCompile = False

    isCsvReaded = False

    programRunning = True

    def __init__(self):
        pass
    def ReadCsv(self):
        
        pd.set_option('display.max_columns', None)
        pd.set_option('display.max_rows', None)

        vt1Directory = (r'\\192.168.2.19\ai_team\AI Program\Outputs\FC1 CSV\VT1')
        os.chdir(vt1Directory)
        self.dfVt1 = pd.read_csv('log000_1.csv', encoding='latin1')
        # self.dfVt1.columns = ["Process 1 DATA No", "Process 1 DATE", "Process 1 TIME", "Process 1 Model Code", "Process 1 S/N", "Process 1 ID", "Process 1 NAME", "Process 1 Regular/Contractual", "Process 1 Material 1 Item Code", "Process 1 Material 1 Lot Number", "Process 1 Material 2 Item Code", "Process 1 Material 2 Lot Number", "Process 1 Material 3 Item Code", "Process 1 Material 3 Lot Number", "Process 1 Material 4 Item Code", "Process 1 Material 4 Lot Number", "Process 1 Material 5 Item Code", "Process 1 Material 5 Lot Number", "Process 1 ST", "Process 1 Actual Time", "Process 1 NG Cause", "Process 1 Repaired Action"]
        self.dfVt1.columns = ["Process 1 DATA No",
        "Process 1 DATE",
        "Process 1 TIME",
        "Process 1 Model Code",
        "Process 1 S/N",
        "Process 1 ID",
        "Process 1 NAME",
        "Process 1 Regular/Contractual",
        "Process 1 Em2p",
        "Process 1 Em2p Lot No",
        "Process 1 Em3p",
        "Process 1 Em3p Lot No",
        "Process 1 Harness",
        "Process 1 Harness Lot No",
        "Process 1 Frame",
        "Process 1 Frame Lot No",
        "Process 1 Bushing",
        "Process 1 Bushing Lot No",
        "Process 1 ST",
        "Process 1 Actual Time",
        "Process 1 NG Cause",
        "Process 1 Repaired Action"]

        vt2Directory = (r'\\192.168.2.19\ai_team\AI Program\Outputs\FC1 CSV\VT2')
        os.chdir(vt2Directory)
        self.dfVt2 = pd.read_csv('log000_2.csv', encoding='latin1')
        # self.dfVt2.columns = ["Process 2 DATA No", "Process 2 DATE", "Process 2 TIME", "Process 2 Model Code", "Process 2 S/N", "Process 2 ID", "Process 2 NAME", "Process 2 Regular/Contractual", "Process 2 Material 1 Item Code", "Process 2 Material 1 Lot Number", "Process 2 Material 2 Item Code", "Process 2 Material 2 Lot Number", "Process 2 Material 3 Item Code", "Process 2 Material 3 Lot Number", "Process 2 Material 4 Item Code", "Process 2 Material 4 Lot Number", "Process 2 Material 5 Item Code", "Process 2 Material 5 Lot Number", "Process 2 Material 6 Item Code", "Process 2 Material 6 Item Code.1", "Process 2 ST", "Process 2 Actual Time", "Process 2 NG Cause", "Process 2 Repaired Action"]
        self.dfVt2.columns = ["Process 2 DATA No",
        "Process 2 DATE",
        "Process 2 TIME",
        "Process 2 Model Code",
        "Process 2 S/N",
        "Process 2 ID",
        "Process 2 NAME",
        "Process 2 Regular/Contractual",
        "Process 2 M4x40 Screw",
        "Process 2 M4x40 Screw Lot No",
        "Process 2 Rod Blk",
        "Process 2 Rod Blk Lot No",
        "Process 2 Df Blk",
        "Process 2 Df Blk Lot No",
        "Process 2 Df Ring",
        "Process 2 Df Ring Lot No",
        "Process 2 Washer",
        "Process 2 Washer Lot No",
        "Process 2 Lock Nut",
        "Process 2 Lock Nut Lot No",
        "Process 2 ST",
        "Process 2 Actual Time",
        "Process 2 NG Cause",
        "Process 2 Repaired Action"]

        vt3Directory = (r'\\192.168.2.19\ai_team\AI Program\Outputs\FC1 CSV\VT3')
        os.chdir(vt3Directory)
        self.dfVt3 = pd.read_csv('log000_3.csv', encoding='latin1')
        # self.dfVt3.columns = ["Process 3 DATA No", "Process 3 DATE", "Process 3 TIME", "Process 3 Model Code", "Process 3 S/N", "Process 3 ID", "Process 3 NAME", "Process 3 Regular/Contractual", "Process 3 Material 1 Item Code", "Process 3 Material 1 Lot Number", "Process 3 Material 2 Item Code", "Process 3 Material 2 Lot Number", "Process 3 Material 3 Item Code", "Process 3 Material 3 Lot Number", "Process 3 Material 4 Item Code", "Process 3 Material 4 Lot Number", "Process 3 Material 5 Item Code", "Process 3 Material 5 Lot Number", "Process 3 Material 6 Item Code", "Process 3 Material 6 Lot Number", "Process 3 Material 7 Item Code", "Process 3 Material 7 Lot Number", "Process 3 Material 8 Item Code", "Process 3 Material 8 Lot Number", "Process 3 Material 9 Item Code", "Process 3 Material 9 Lot Number", "Process 3 Material 10 Item Code", "Process 3 Material 10 Lot Number", "Process 3 ST", "Process 3 Actual Time", "Process 3 NG Cause", "Process 3 Repaired Action"]
        self.dfVt3.columns = ["Process 3 DATA No",
        "Process 3 DATE",
        "Process 3 TIME",
        "Process 3 Model Code",
        "Process 3 S/N",
        "Process 3 ID",
        "Process 3 NAME",
        "Process 3 Regular/Contractual",
        "Process 3 Frame Gasket",
        "Process 3 Frame Gasket Lot No",
        "Process 3 Casing Block",
        "Process 3 Casing Block Lot No",
        "Process 3 Casing Gasket",
        "Process 3 Casing Gasket Lot No",
        "Process 3 M4x16 Screw 1",
        "Process 3 M4x16 Screw 1 Lot No",
        "Process 3 M4x16 Screw 2",
        "Process 3 M4x16 Screw 2 Lot No",
        "Process 3 Ball Cushion",
        "Process 3 Ball Cushion Lot No",
        "Process 3 Frame Cover",
        "Process 3 Frame Cover Lot No",
        "Process 3 Partition Board",
        "Process 3 Partition Board Lot No",
        "Process 3 Built In Tube 1",
        "Process 3 Built In Tube 1 Lot No",
        "Process 3 Built In Tube 2",
        "Process 3 Built In Tube 2 Lot No",
        "Process 3 Head Cover",
        "Process 3 Head Cover Lot No",
        "Process 3 Casing Packing",
        "Process 3 Casing Packing Lot No",
        "Process 3 M4x12 Screw",
        "Process 3 M4x12 Screw Lot No",
        "Process 3 Csb L",
        "Process 3 Csb L Lot No",
        "Process 3 Csb R",
        "Process 3 Csb R Lot No",
        "Process 3 Head Packing",
        "Process 3 Head Packing Lot No",
        "Process 3 ST",
        "Process 3 Actual Time",
        "Process 3 NG Cause",
        "Process 3 Repaired Action"]

        vt4Directory = (r'\\192.168.2.19\ai_team\AI Program\Outputs\FC1 CSV\VT4')
        os.chdir(vt4Directory)
        self.dfVt4 = pd.read_csv('log000_4.csv', encoding='latin1')
        # self.dfVt4.columns = ["Process 4 DATA No", "Process 4 DATE", "Process 4 TIME", "Process 4 Model Code", "Process 4 S/N", "Process 4 ID", "Process 4 NAME", "Process 4 Regular/Contractual", "Process 4 Material 1 Item Code", "Process 4 Material 1 Lot Number", "Process 4 Material 2 Item Code", "Process 4 Material 2 Lot Number", "Process 4 Material 3 Item Code", "Process 4 Material 3 Lot Number", "Process 4 Material 4 Item Code", "Process 4 Material 4 Lot Number", "Process 4 Material 5 Item Code", "Process 4 Material 5 Lot Number", "Process 4 Material 6 Item Code", "Process 4 Material 6 Lot Number", "Process 4 Material 7 Item Code", "Process 4 Material 7 Lot Number", "Process 4 Material 8 Item Code", "Process 4 Material 8 Lot Number", "Process 4 ST", "Process 4 Actual Time", "Process 4 NG Cause", "Process 4 Repaired Action"]
        self.dfVt4.columns = ["Process 4 DATA No",
        "Process 4 DATE",
        "Process 4 TIME",
        "Process 4 Model Code",
        "Process 4 S/N",
        "Process 4 ID",
        "Process 4 NAME",
        "Process 4 Regular/Contractual",
        "Process 4 Tank",
        "Process 4 Tank Lot No",
        "Process 4 Upper Housing",
        "Process 4 Upper Housing Lot No",
        "Process 4 Cord Hook",
        "Process 4 Cord Hook Lot No",
        "Process 4 M4x16 Screw",
        "Process 4 M4x16 Screw Lot No",
        "Process 4 Tank Gasket",
        "Process 4 Tank Gasket Lot No",
        "Process 4 Tank Cover",
        "Process 4 Tank Cover Lot No",
        "Process 4 Housing Gasket",
        "Process 4 Housing Gasket Lot No",
        "Process 4 M4x40 Screw",
        "Process 4 M4x40 Screw Lot No",
        "Process 4 PartitionGasket",
        "Process 4 PartitionGasket Lot No",
        "Process 4 M4x12 Screw",
        "Process 4 M4x12 Screw Lot No",
        "Process 4 Muffler",
        "Process 4 Muffler Lot No",
        "Process 4 Muffler Gasket",
        "Process 4 Muffler Gasket Lot No",
        "Process 4 VCR",
        "Process 4 VCR Lot No",
        "Process 4 ST",
        "Process 4 Actual Time",
        "Process 4 NG Cause",
        "Process 4 Repaired Action"]

        vt5Directory = (r'\\192.168.2.19\ai_team\AI Program\Outputs\FC1 CSV\VT5')
        os.chdir(vt5Directory)
        self.dfVt5 = pd.read_csv('log000_5.csv', encoding='latin1')
        # self.dfVt5.columns = ["Process 5 DATA No", "Process 5 DATE", "Process 5 TIME", "Process 5 Model Code", "Process 5 S/N", "Process 5 ID", "Process 5 NAME", "Process 5 Regular/Contractual", "Process 5 Material 1 Item Code", "Process 5 Material 1 Lot Number", "Process 5 ST", "Process 5 Actual Time", "Process 5 NG Cause", "Process 5 Repaired Action"]
        self.dfVt5.columns = ["Process 5 DATA No",
        "Process 5 DATE",
        "Process 5 TIME",
        "Process 5 Model Code",
        "Process 5 S/N",
        "Process 5 ID",
        "Process 5 NAME",
        "Process 5 Regular/Contractual",
        "Process 5 Rating Label",
        "Process 5 Rating Label Lot No",
        "Process 5 ST",
        "Process 5 Actual Time",
        "Process 5 NG Cause",
        "Process 5 Repaired Action"]

        vt6Directory = (r'\\192.168.2.19\ai_team\AI Program\Outputs\FC1 CSV\VT6')
        os.chdir(vt6Directory)
        self.dfVt6 = pd.read_csv('log000_6.csv', encoding='latin1')
        # self.dfVt6.columns = ["Process 6 DATA No", "Process 6 DATE", "Process 6 TIME", "Process 6 Model Code", "Process 6 S/N", "Process 6 ID", "Process 6 NAME", "Process 6 Regular/Contractual", "Process 6 Material 1 Item Code", "Process 6 Material 1 Lot Number", "Process 6 ST", "Process 6 Actual Time", "Process 6 NG Cause", "Process 6 Repaired Action"]
        self.dfVt6.columns = ["Process 6 DATA No",
        "Process 6 DATE",
        "Process 6 TIME",
        "Process 6 Model Code",
        "Process 6 S/N",
        "Process 6 ID",
        "Process 6 NAME",
        "Process 6 Regular/Contractual",
        "Process 6 Vinyl",
        "Process 6 Vinyl Lot No",
        "Process 6 ST",
        "Process 6 Actual Time",
        "Process 6 NG Cause",
        "Process 6 Repaired Action"]

        self.dfVt1 = self.dfVt1[self.dfVt1["Process 1 Regular/Contractual"].str.contains("REG", na = False)]
        self.dfVt1 = self.dfVt1[(self.dfVt1["Process 1 DATE"].isin([dateToRead]))]

        self.dfVt2 = self.dfVt2[self.dfVt2["Process 2 Regular/Contractual"].str.contains("REG", na = False)]
        self.dfVt2 = self.dfVt2[(self.dfVt2["Process 2 DATE"].isin([dateToRead]))]

        self.dfVt3 = self.dfVt3[self.dfVt3["Process 3 Regular/Contractual"].str.contains("REG", na = False)]
        self.dfVt3 = self.dfVt3[(self.dfVt3["Process 3 DATE"].isin([dateToRead]))]

        self.dfVt4 = self.dfVt4[self.dfVt4["Process 4 Regular/Contractual"].str.contains("REG", na = False)]
        self.dfVt4 = self.dfVt4[(self.dfVt4["Process 4 DATE"].isin([dateToRead]))]

        self.dfVt5 = self.dfVt5[self.dfVt5["Process 5 Regular/Contractual"].str.contains("REG", na = False)]
        self.dfVt5 = self.dfVt5[(self.dfVt5["Process 5 DATE"].isin([dateToRead]))]

        self.dfVt6 = self.dfVt6[self.dfVt6["Process 6 Regular/Contractual"].str.contains("REG", na = False)]
        self.dfVt6 = self.dfVt6[(self.dfVt6["Process 6 DATE"].isin([dateToRead]))]

    def start(self):
        while not self.isCsvReaded:
            try:
                self.ReadCsv()
                self.isCsvReaded = True
            except:
                print("Cannot Read Csv Retrying In 1 Seconds")
                self.isCsvReaded = False
                time.sleep(1)

        while self.programRunning:
            self.CsvOrganize()
            if self.canCompile:
                self.CompileCsv()

            print(f"Process 1 S/N{self.tempDfVt1["Process 1 S/N"]}_______________________________________________________________________________")
            print(f"Process 2 S/N{self.tempDfVt2["Process 2 S/N"]}_______________________________________________________________________________")
            print(f"Process 3 S/N{self.tempDfVt3["Process 3 S/N"]}_______________________________________________________________________________")
            print(f"Process 4 S/N{self.tempDfVt4["Process 4 S/N"]}_______________________________________________________________________________")
            print(f"Process 5 S/N{self.tempDfVt5["Process 5 S/N"]}_______________________________________________________________________________")
            print(f"Process 6 S/N{self.tempDfVt6["Process 6 S/N"]}_______________________________________________________________________________")

    def CsvOrganize(self):
        try:
            self.tempDfVt1 = self.dfVt1.iloc[[self.process1Row], :]
            self.tempDfVt2 = self.dfVt2.iloc[[self.process2Row], :]
            self.tempDfVt3 = self.dfVt3.iloc[[self.process3Row], :]
            self.tempDfVt4 = self.dfVt4.iloc[[self.process4Row], :]
            self.tempDfVt5 = self.dfVt5.iloc[[self.process5Row], :]
            self.tempDfVt6 = self.dfVt6.iloc[[self.process6Row], :]

            if self.tempDfVt1["Process 1 Repaired Action"].values[0] == "-" and self.tempDfVt2["Process 2 Repaired Action"].values[0] == "-" and self.tempDfVt3["Process 3 Repaired Action"].values[0] == "-" and self.tempDfVt4["Process 4 Repaired Action"].values[0] == "-" and self.tempDfVt5["Process 5 Repaired Action"].values[0] == "-" and self.tempDfVt6["Process 6 Repaired Action"].values[0] == "-":
                if self.tempDfVt1["Process 1 NG Cause"].values[0] == "-":
                    print("Process1 Good")
                    self.process1Status = "Good"
                    if self.tempDfVt2["Process 2 NG Cause"].values[0] == "-":
                        print("Process2 Good")
                        self.process2Status = "Good"
                        if self.tempDfVt3["Process 3 NG Cause"].values[0] == "-":
                            print("Process3 Good")
                            self.process3Status = "Good"
                            if self.tempDfVt4["Process 4 NG Cause"].values[0] == "-":
                                print("Process4 Good")
                                self.process4Status = "Good"
                                if self.tempDfVt5["Process 5 NG Cause"].values[0] == "-":
                                    print("Process5 Good")
                                    self.process5Status = "Good"
                                    if self.tempDfVt6["Process 6 NG Cause"].values[0] == "-":
                                        print("Process6 Good")
                                        self.process6Status = "Good"
                                    else:
                                        print("Process6 NG")
                                        self.process6Status = "NG"
                                elif self.tempDfVt5["Process 5 NG Cause"].values[0].replace(' ', '') == "NGPRESSURE":
                                    print("Process5 NG PRESSURE")
                                    self.process5Status = "NG PRESSURE"
                                else:
                                    print("Process5 NG")
                                    self.process5Status = "NG"
                            else:
                                print("Process4 NG")
                                self.process4Status = "NG"
                        else:
                            print("Process3 NG")
                            self.process3Status = "NG"
                    else:
                        print("Process2 NG")
                        self.process2Status = "NG"
                else:
                    print("Process1 NG")
                    self.process1Status = "NG"
            else:
                print("Repaired")

                if self.tempDfVt1["Process 1 Repaired Action"].values[0] != "-":
                    self.process1Status = "Repaired"
                    self.process2Status = ""
                    self.process3Status = ""
                    self.process4Status = ""
                    self.process5Status = ""
                    self.process6Status = ""
                if self.tempDfVt2["Process 2 Repaired Action"].values[0] != "-":
                    self.process1Status = ""
                    self.process2Status = "Repaired"
                    self.process3Status = ""
                    self.process4Status = ""
                    self.process5Status = ""
                    self.process6Status = ""
                if self.tempDfVt3["Process 3 Repaired Action"].values[0] != "-":
                    self.process1Status = ""
                    self.process2Status = ""
                    self.process3Status = "Repaired"
                    self.process4Status = ""
                    self.process5Status = ""
                    self.process6Status = ""
                if self.tempDfVt4["Process 4 Repaired Action"].values[0] != "-":
                    self.process1Status = ""
                    self.process2Status = ""
                    self.process3Status = ""
                    self.process4Status = "Repaired"
                    self.process5Status = ""
                    self.process6Status = ""
                if self.tempDfVt5["Process 5 Repaired Action"].values[0] != "-":
                    self.process1Status = ""
                    self.process2Status = ""
                    self.process3Status = ""
                    self.process4Status = ""
                    self.process5Status = "Repaired"
                    self.process6Status = ""
                if self.tempDfVt6["Process 6 Repaired Action"].values[0] != "-":
                    self.process1Status = ""
                    self.process2Status = ""
                    self.process3Status = ""
                    self.process4Status = ""
                    self.process5Status = ""
                    self.process6Status = "Repaired"

                #Checking Again For NG Process
                if self.tempDfVt1["Process 1 NG Cause"].values[0] != "-":
                    self.process1Status = "NG"
                    self.isRepairedWithNG = True
                elif self.tempDfVt2["Process 2 NG Cause"].values[0] != "-":
                    self.process2Status = "NG"
                    self.isRepairedWithNG = True
                elif self.tempDfVt3["Process 3 NG Cause"].values[0] != "-":
                    self.process3Status = "NG"
                    self.isRepairedWithNG = True
                elif self.tempDfVt4["Process 4 NG Cause"].values[0] != "-":
                    self.process4Status = "NG"
                    self.isRepairedWithNG = True
                elif self.tempDfVt5["Process 5 NG Cause"].values[0].replace(' ', '') == "NGPRESSURE":
                    print("Repaired With NG PRESSURE__________________________________________________________________________________________________________________")
                    self.process5Status = "NG PRESSURE"
                    self.isRepairedWithNG = True
                elif self.tempDfVt5["Process 5 NG Cause"].values[0] != "-":
                    self.process5Status = "NG"
                    self.isRepairedWithNG = True
                elif self.tempDfVt6["Process 6 NG Cause"].values[0] != "-":
                    self.process6Status = "NG"
                    self.isRepairedWithNG = True
            self.canCompile = True
        except:
            print("Error")
            self.canCompile = False
            pass

    def CompileCsv(self):
        # ReadPI In PiRow Value
        try:
            self.tempdfPi = piCompiler.dfPi.iloc[[piCompiler.piRow], :]
        except IndexError:
            pass

        DateAndTimeManager.GetDateToday()

        em2p = em2P()
        em2p.readingYear = int(DateAndTimeManager.yearNow)

        em2p.ReadExcel(self.tempDfVt1["Process 1 Em2p"].values)
        em2p.GettingData(self.tempDfVt1["Process 1 Em2p Lot No"].values)

        excelData = {
            "DATE": self.tempdfPi["DATE"].values,
            "TIME": self.tempdfPi["TIME"].values,
            "MODEL CODE": self.tempdfPi["MODEL CODE"].values,
            "PROCESS S/N": self.tempdfPi["PROCESS S/N"].values,
            "S/N": self.tempdfPi["S/N"].values,
            "PASS/NG": self.tempdfPi["PASS/NG"].values,
            "VOLTAGE MAX (V)": self.tempdfPi["VOLTAGE MAX (V)"].values,
            "WATTAGE MAX (W)": self.tempdfPi["WATTAGE MAX (W)"].values,
            "CLOSED PRESSURE_MAX (kPa)": self.tempdfPi["CLOSED PRESSURE_MAX (kPa)"].values,
            "VOLTAGE Middle (V)": self.tempdfPi["VOLTAGE Middle (V)"].values,
            "WATTAGE Middle (W)": self.tempdfPi["WATTAGE Middle (W)"].values,
            "AMPERAGE Middle (A)": self.tempdfPi["AMPERAGE Middle (A)"].values,
            "CLOSED PRESSURE Middle (kPa)": self.tempdfPi["CLOSED PRESSURE Middle (kPa)"].values,
            "dB(A) 1": self.tempdfPi["dB(A) 1"].values,
            "dB(A) 2": self.tempdfPi["dB(A) 2"].values,
            "dB(A) 3": self.tempdfPi["dB(A) 3"].values,
            "VOLTAGE MIN (V)": self.tempdfPi["VOLTAGE MIN (V)"].values,
            "WATTAGE MIN (W)": self.tempdfPi["WATTAGE MIN (W)"].values,
            "CLOSED PRESSURE MIN (kPa)": self.tempdfPi["CLOSED PRESSURE MIN (kPa)"].values,

            "Process 1 Model Code": self.tempDfVt1["Process 1 Model Code"].values,
            "Process 1 S/N": self.tempDfVt1["Process 1 S/N"].values,
            "Process 1 ID": self.tempDfVt1["Process 1 ID"].values,
            "Process 1 NAME": self.tempDfVt1["Process 1 NAME"].values,
            "Process 1 Regular/Contractual": self.tempDfVt1["Process 1 Regular/Contractual"].values,
            "Process 1 Em2p": self.tempDfVt1["Process 1 Em2p"].values,
            "Process 1 Em2p Lot No": self.tempDfVt1["Process 1 Em2p Lot No"].values,
            "Process 1 Em2p Inspection 3 Average Data": em2p.totalAverage3,
            "Process 1 Em2p Inspection 4 Average Data": em2p.totalAverage4,
            "Process 1 Em2p Inspection 5 Average Data": em2p.totalAverage5,
            "Process 1 Em2p Inspection 10 Average Data": em2p.totalAverage10,
            "Process 1 Em2p Inspection 3 Minimum Data": em2p.totalMinimum3,
            "Process 1 Em2p Inspection 4 Minimum Data": em2p.totalMinimum4,
            "Process 1 Em2p Inspection 5 Minimum Data": em2p.totalMinimum5,
            "Process 1 Em2p Inspection 3 Maximum Data": em2p.totalMaximum3,
            "Process 1 Em2p Inspection 4 Maximum Data": em2p.totalMaximum4,
            "Process 1 Em2p Inspection 5 Maximum Data": em2p.totalMaximum5,
            "Process 1 Em3p": self.tempDfVt1["Process 1 Em3p"].values,
            "Process 1 Em3p Lot No": self.tempDfVt1["Process 1 Em3p Lot No"].values,
            "Process 1 Em3p Inspection 3 Average Data": "",
            "Process 1 Em3p Inspection 4 Average Data": "",
            "Process 1 Em3p Inspection 5 Average Data": "",
            "Process 1 Em3p Inspection 10 Average Data": "",
            "Process 1 Em3p Inspection 3 Minimum Data": "",
            "Process 1 Em3p Inspection 4 Minimum Data": "",
            "Process 1 Em3p Inspection 5 Minimum Data": "",
            "Process 1 Em3p Inspection 3 Maximum Data": "",
            "Process 1 Em3p Inspection 4 Maximum Data": "",
            "Process 1 Em3p Inspection 5 Maximum Data": "",
            "Process 1 Harness": self.tempDfVt1["Process 1 Harness"].values,
            "Process 1 Harness Lot No": self.tempDfVt1["Process 1 Harness Lot No"].values,
            "Process 1 Frame": self.tempDfVt1["Process 1 Frame"].values,
            "Process 1 Frame Lot No": self.tempDfVt1["Process 1 Frame Lot No"].values,
            "Process 1 Frame Inspection 1 Average Data": "", 
            "Process 1 Frame Inspection 2 Average Data": "", 
            "Process 1 Frame Inspection 3 Average Data": "", 
            "Process 1 Frame Inspection 4 Average Data": "", 
            "Process 1 Frame Inspection 5 Average Data": "", 
            "Process 1 Frame Inspection 6 Average Data": "", 
            "Process 1 Frame Inspection 7 Average Data": "", 
            "Process 1 Frame Inspection 1 Minimum Data": "", 
            "Process 1 Frame Inspection 2 Minimum Data": "", 
            "Process 1 Frame Inspection 3 Minimum Data": "", 
            "Process 1 Frame Inspection 4 Minimum Data": "", 
            "Process 1 Frame Inspection 5 Minimum Data": "", 
            "Process 1 Frame Inspection 6 Minimum Data": "", 
            "Process 1 Frame Inspection 7 Minimum Data": "", 
            "Process 1 Frame Inspection 1 Maximum Data": "", 
            "Process 1 Frame Inspection 2 Maximum Data": "", 
            "Process 1 Frame Inspection 3 Maximum Data": "", 
            "Process 1 Frame Inspection 4 Maximum Data": "", 
            "Process 1 Frame Inspection 5 Maximum Data": "", 
            "Process 1 Frame Inspection 6 Maximum Data": "", 
            "Process 1 Frame Inspection 7 Maximum Data": "", 
            "Process 1 Bushing": self.tempDfVt1["Process 1 Bushing"].values,
            "Process 1 Bushing Lot No": self.tempDfVt1["Process 1 Bushing Lot No"].values,
            "Process 1 ST": self.tempDfVt1["Process 1 ST"].values,
            "Process 1 Actual Time": self.tempDfVt1["Process 1 Actual Time"].values,
            "Process 1 NG Cause": self.tempDfVt1["Process 1 NG Cause"].values,
            "Process 1 Repaired Action": self.tempDfVt1["Process 1 Repaired Action"].values,

            "Process 2 Model Code": self.tempDfVt2["Process 2 Model Code"].values,
            "Process 2 S/N": self.tempDfVt2["Process 2 S/N"].values,
            "Process 2 ID": self.tempDfVt2["Process 2 ID"].values,
            "Process 2 NAME": self.tempDfVt2["Process 2 NAME"].values,
            "Process 2 Regular/Contractual": self.tempDfVt2["Process 2 Regular/Contractual"].values,
            "Process 2 M4x40 Screw": self.tempDfVt2["Process 2 M4x40 Screw"].values,
            "Process 2 M4x40 Screw Lot No": self.tempDfVt2["Process 2 M4x40 Screw Lot No"].values,
            "Process 2 Rod Blk": self.tempDfVt2["Process 2 Rod Blk"].values,
            "Process 2 Rod Blk Lot No": self.tempDfVt2["Process 2 Rod Blk Lot No"].values,
            "Process 2 Rod Blk Tesla 1 Average Data": "",
            "Process 2 Rod Blk Tesla 2 Average Data": "",
            "Process 2 Rod Blk Tesla 3 Average Data": "",
            "Process 2 Rod Blk Tesla 4 Average Data": "",
            "Process 2 Rod Blk Tesla 1 Minimum Data": "",
            "Process 2 Rod Blk Tesla 2 Minimum Data": "",
            "Process 2 Rod Blk Tesla 3 Minimum Data": "",
            "Process 2 Rod Blk Tesla 4 Minimum Data": "",
            "Process 2 Rod Blk Tesla 1 Maximum Data": "",
            "Process 2 Rod Blk Tesla 2 Maximum Data": "",
            "Process 2 Rod Blk Tesla 3 Maximum Data": "",
            "Process 2 Rod Blk Tesla 4 Maximum Data": "",
            "Process 2 Rod Blk Inspection 1 Average Data": "",
            "Process 2 Rod Blk Inspection 2 Average Data": "",
            "Process 2 Rod Blk Inspection 3 Average Data": "",
            "Process 2 Rod Blk Inspection 4 Average Data": "",
            "Process 2 Rod Blk Inspection 5 Average Data": "",
            "Process 2 Rod Blk Inspection 6 Average Data": "",
            "Process 2 Rod Blk Inspection 8 Average Data": "",
            "Process 2 Rod Blk Inspection 1 Minimum Data": "",
            "Process 2 Rod Blk Inspection 2 Minimum Data": "",
            "Process 2 Rod Blk Inspection 3 Minimum Data": "",
            "Process 2 Rod Blk Inspection 4 Minimum Data": "",
            "Process 2 Rod Blk Inspection 5 Minimum Data": "",
            "Process 2 Rod Blk Inspection 6 Minimum Data": "",
            "Process 2 Rod Blk Inspection 8 Minimum Data": "",
            "Process 2 Rod Blk Inspection 1 Maximum Data": "",
            "Process 2 Rod Blk Inspection 2 Maximum Data": "",
            "Process 2 Rod Blk Inspection 3 Maximum Data": "",
            "Process 2 Rod Blk Inspection 4 Maximum Data": "",
            "Process 2 Rod Blk Inspection 5 Maximum Data": "",
            "Process 2 Rod Blk Inspection 6 Maximum Data": "",
            "Process 2 Rod Blk Inspection 8 Maximum Data": "",
            "Process 2 Df Blk": self.tempDfVt2["Process 2 Df Blk"].values,
            "Process 2 Df Blk Lot No": self.tempDfVt2["Process 2 Df Blk Lot No"].values,
            "Process 2 Df Blk Inspection 1 Average Data": "",
            "Process 2 Df Blk Inspection 2 Average Data": "",
            "Process 2 Df Blk Inspection 3 Average Data": "",
            "Process 2 Df Blk Inspection 4 Average Data": "",
            "Process 2 Df Blk Inspection 1 Minimum Data": "",
            "Process 2 Df Blk Inspection 2 Minimum Data": "",
            "Process 2 Df Blk Inspection 3 Minimum Data": "",
            "Process 2 Df Blk Inspection 4 Minimum Data": "",
            "Process 2 Df Blk Inspection 1 Maximum Data": "",
            "Process 2 Df Blk Inspection 2 Maximum Data": "",
            "Process 2 Df Blk Inspection 3 Maximum Data": "",
            "Process 2 Df Blk Inspection 4 Maximum Data": "",
            "Process 2 Df Ring": self.tempDfVt2["Process 2 Df Ring"].values,
            "Process 2 Df Ring Lot No": self.tempDfVt2["Process 2 Df Ring Lot No"].values,
            "Process 2 Washer": self.tempDfVt2["Process 2 Washer"].values,
            "Process 2 Washer Lot No": self.tempDfVt2["Process 2 Washer Lot No"].values,
            "Process 2 Lock Nut": self.tempDfVt2["Process 2 Lock Nut"].values,
            "Process 2 Lock Nut Lot No": self.tempDfVt2["Process 2 Lock Nut Lot No"].values,
            "Process 2 ST": self.tempDfVt2["Process 2 ST"].values,
            "Process 2 Actual Time": self.tempDfVt2["Process 2 Actual Time"].values,
            "Process 2 NG Cause": self.tempDfVt2["Process 2 NG Cause"].values,
            "Process 2 Repaired Action": self.tempDfVt2["Process 2 Repaired Action"].values,

            "Process 3 Model Code": self.tempDfVt3["Process 3 Model Code"].values,
            "Process 3 S/N": self.tempDfVt3["Process 3 S/N"].values,
            "Process 3 ID": self.tempDfVt3["Process 3 ID"].values,
            "Process 3 NAME": self.tempDfVt3["Process 3 NAME"].values,
            "Process 3 Regular/Contractual": self.tempDfVt3["Process 3 Regular/Contractual"].values,
            "Process 3 Frame Gasket": self.tempDfVt3["Process 3 Frame Gasket"].values,
            "Process 3 Frame Gasket Lot No": self.tempDfVt3["Process 3 Frame Gasket Lot No"].values,
            "Process 3 Casing Block": self.tempDfVt3["Process 3 Casing Block"].values,
            "Process 3 Casing Block Lot No": self.tempDfVt3["Process 3 Casing Block Lot No"].values,
            "Process 3 Casing Block Inspection 1 Average Data": "",
            "Process 3 Casing Block Inspection 1 Minimum Data": "",
            "Process 3 Casing Block Inspection 1 Maximum Data": "",
            "Process 3 Casing Gasket": self.tempDfVt3["Process 3 Casing Gasket"].values,
            "Process 3 Casing Gasket Lot No": self.tempDfVt3["Process 3 Casing Gasket Lot No"].values,
            "Process 3 M4x16 Screw 1": self.tempDfVt3["Process 3 M4x16 Screw 1"].values,
            "Process 3 M4x16 Screw 1 Lot No": self.tempDfVt3["Process 3 M4x16 Screw 1 Lot No"].values,
            "Process 3 M4x16 Screw 2": self.tempDfVt3["Process 3 M4x16 Screw 2"].values,
            "Process 3 M4x16 Screw 2 Lot No": self.tempDfVt3["Process 3 M4x16 Screw 2 Lot No"].values,
            "Process 3 Ball Cushion": self.tempDfVt3["Process 3 Ball Cushion"].values,
            "Process 3 Ball Cushion Lot No": self.tempDfVt3["Process 3 Ball Cushion Lot No"].values,
            "Process 3 Frame Cover": self.tempDfVt3["Process 3 Frame Cover"].values,
            "Process 3 Frame Cover Lot No": self.tempDfVt3["Process 3 Frame Cover Lot No"].values,
            "Process 3 Partition Board": self.tempDfVt3["Process 3 Partition Board"].values,
            "Process 3 Partition Board Lot No": self.tempDfVt3["Process 3 Partition Board Lot No"].values,
            "Process 3 Built In Tube 1": self.tempDfVt3["Process 3 Built In Tube 1"].values,
            "Process 3 Built In Tube 1 Lot No": self.tempDfVt3["Process 3 Built In Tube 1 Lot No"].values,
            "Process 3 Built In Tube 2": self.tempDfVt3["Process 3 Built In Tube 2"].values,
            "Process 3 Built In Tube 2 Lot No": self.tempDfVt3["Process 3 Built In Tube 2 Lot No"].values,
            "Process 3 Head Cover": self.tempDfVt3["Process 3 Head Cover"].values,
            "Process 3 Head Cover Lot No": self.tempDfVt3["Process 3 Head Cover Lot No"].values,
            "Process 3 Casing Packing": self.tempDfVt3["Process 3 Casing Packing"].values,
            "Process 3 Casing Packing Lot No": self.tempDfVt3["Process 3 Casing Packing Lot No"].values,
            "Process 3 M4x12 Screw": self.tempDfVt3["Process 3 M4x12 Screw"].values,
            "Process 3 M4x12 Screw Lot No": self.tempDfVt3["Process 3 M4x12 Screw Lot No"].values,
            "Process 3 Csb L": self.tempDfVt3["Process 3 Csb L"].values,
            "Process 3 Csb L Lot No": self.tempDfVt3["Process 3 Csb L Lot No"].values,
            "Process 3 Csb R": self.tempDfVt3["Process 3 Csb R"].values,
            "Process 3 Csb R Lot No": self.tempDfVt3["Process 3 Csb R Lot No"].values,
            "Process 3 Head Packing": self.tempDfVt3["Process 3 Head Packing"].values,
            "Process 3 Head Packing Lot No": self.tempDfVt3["Process 3 Head Packing Lot No"].values,
            "Process 3 ST": self.tempDfVt3["Process 3 ST"].values,
            "Process 3 Actual Time": self.tempDfVt3["Process 3 Actual Time"].values,
            "Process 3 NG Cause": self.tempDfVt3["Process 3 NG Cause"].values,
            "Process 3 Repaired Action": self.tempDfVt3["Process 3 Repaired Action"].values,

            "Process 4 Model Code": self.tempDfVt4["Process 4 Model Code"].values,
            "Process 4 S/N": self.tempDfVt4["Process 4 S/N"].values,
            "Process 4 ID": self.tempDfVt4["Process 4 ID"].values,
            "Process 4 NAME": self.tempDfVt4["Process 4 NAME"].values,
            "Process 4 Regular/Contractual": self.tempDfVt4["Process 4 Regular/Contractual"].values,
            "Process 4 Tank": self.tempDfVt4["Process 4 Tank"].values,
            "Process 4 Tank Lot No": self.tempDfVt4["Process 4 Tank Lot No"].values,
            "Process 4 Upper Housing": self.tempDfVt4["Process 4 Upper Housing"].values,
            "Process 4 Upper Housing Lot No": self.tempDfVt4["Process 4 Upper Housing Lot No"].values,
            "Process 4 Cord Hook": self.tempDfVt4["Process 4 Cord Hook"].values,
            "Process 4 Cord Hook Lot No": self.tempDfVt4["Process 4 Cord Hook Lot No"].values,
            "Process 4 M4x16 Screw": self.tempDfVt4["Process 4 M4x16 Screw"].values,
            "Process 4 M4x16 Screw Lot No": self.tempDfVt4["Process 4 M4x16 Screw Lot No"].values,
            "Process 4 Tank Gasket": self.tempDfVt4["Process 4 Tank Gasket"].values,
            "Process 4 Tank Gasket Lot No": self.tempDfVt4["Process 4 Tank Gasket Lot No"].values,
            "Process 4 Tank Cover": self.tempDfVt4["Process 4 Tank Cover"].values,
            "Process 4 Tank Cover Lot No": self.tempDfVt4["Process 4 Tank Cover Lot No"].values,
            "Process 4 Housing Gasket": self.tempDfVt4["Process 4 Housing Gasket"].values,
            "Process 4 Housing Gasket Lot No": self.tempDfVt4["Process 4 Housing Gasket Lot No"].values,
            "Process 4 M4x40 Screw": self.tempDfVt4["Process 4 M4x40 Screw"].values,
            "Process 4 M4x40 Screw Lot No": self.tempDfVt4["Process 4 M4x40 Screw Lot No"].values,
            "Process 4 PartitionGasket": self.tempDfVt4["Process 4 PartitionGasket"].values,
            "Process 4 PartitionGasket Lot No": self.tempDfVt4["Process 4 PartitionGasket Lot No"].values,
            "Process 4 M4x12 Screw": self.tempDfVt4["Process 4 M4x12 Screw"].values,
            "Process 4 M4x12 Screw Lot No": self.tempDfVt4["Process 4 M4x12 Screw Lot No"].values,
            "Process 4 Muffler": self.tempDfVt4["Process 4 Muffler"].values,
            "Process 4 Muffler Lot No": self.tempDfVt4["Process 4 Muffler Lot No"].values,
            "Process 4 Muffler Gasket": self.tempDfVt4["Process 4 Muffler Gasket"].values,
            "Process 4 Muffler Gasket Lot No": self.tempDfVt4["Process 4 Muffler Gasket Lot No"].values,
            "Process 4 VCR": self.tempDfVt4["Process 4 VCR"].values,
            "Process 4 VCR Lot No": self.tempDfVt4["Process 4 VCR Lot No"].values,
            "Process 4 ST": self.tempDfVt4["Process 4 ST"].values,
            "Process 4 Actual Time": self.tempDfVt4["Process 4 Actual Time"].values,
            "Process 4 NG Cause": self.tempDfVt4["Process 4 NG Cause"].values,
            "Process 4 Repaired Action": self.tempDfVt4["Process 4 Repaired Action"].values,
            
            "Process 5 Model Code": self.tempDfVt5["Process 5 Model Code"].values,
            "Process 5 S/N": self.tempDfVt5["Process 5 S/N"].values,
            "Process 5 ID": self.tempDfVt5["Process 5 ID"].values,
            "Process 5 NAME": self.tempDfVt5["Process 5 NAME"].values,
            "Process 5 Regular/Contractual": self.tempDfVt5["Process 5 Regular/Contractual"].values,
            "Process 5 Rating Label": self.tempDfVt5["Process 5 Rating Label"].values,
            "Process 5 Rating Label Lot No": self.tempDfVt5["Process 5 Rating Label Lot No"].values,
            "Process 5 ST": self.tempDfVt5["Process 5 ST"].values,
            "Process 5 Actual Time": self.tempDfVt5["Process 5 Actual Time"].values,
            "Process 5 NG Cause": self.tempDfVt5["Process 5 NG Cause"].values,
            "Process 5 Repaired Action": self.tempDfVt5["Process 5 Repaired Action"].values,
            
            "Process 6 Model Code": self.tempDfVt6["Process 6 Model Code"].values,
            "Process 6 S/N": self.tempDfVt6["Process 6 S/N"].values,
            "Process 6 ID": self.tempDfVt6["Process 6 ID"].values,
            "Process 6 NAME": self.tempDfVt6["Process 6 NAME"].values,
            "Process 6 Regular/Contractual": self.tempDfVt6["Process 6 Regular/Contractual"].values,
            "Process 6 Vinyl": self.tempDfVt6["Process 6 Vinyl"].values,
            "Process 6 Vinyl Lot No": self.tempDfVt6["Process 6 Vinyl Lot No"].values,
            "Process 6 ST": self.tempDfVt6["Process 6 ST"].values,
            "Process 6 Actual Time": self.tempDfVt6["Process 6 Actual Time"].values,
            "Process 6 NG Cause": self.tempDfVt6["Process 6 NG Cause"].values,
            "Process 6 Repaired Action": self.tempDfVt6["Process 6 Repaired Action"].values
        }

        excelData = pd.DataFrame(excelData)
        if self.process1Status == "Good":
            self.process1Row += 1
        if self.process2Status == "Good":
            self.process2Row += 1
        if self.process3Status == "Good":
            self.process3Row += 1
        if self.process4Status == "Good":
            self.process4Row += 1
        if self.process5Status == "Good":
            self.process5Row += 1
            piCompiler.piRow += 1
        if self.process6Status == "Good":
            self.process6Row += 1

        # REPAIRED WITH NG
        if self.isRepairedWithNG:
            # REPAIRED AT PROCESS 1
            if self.process1Status == "Repaired":
                if self.process2Status == "NG":
                    self.ngProcess = "NG AT PROCESS2"
                    self.process1Row += 1
                    self.process2Row += 1

                    excelData["Process 3 Model Code"] = self.ngProcess
                    excelData["Process 3 S/N"] = self.ngProcess
                    excelData["Process 3 ID"] = self.ngProcess
                    excelData["Process 3 NAME"] = self.ngProcess
                    excelData["Process 3 Regular/Contractual"] = self.ngProcess
                    excelData["Process 3 Frame Gasket"] = self.ngProcess
                    excelData["Process 3 Frame Gasket Lot No"] = self.ngProcess
                    excelData["Process 3 Casing Block"] = self.ngProcess
                    excelData["Process 3 Casing Block Lot No"] = self.ngProcess
                    excelData["Process 3 Casing Block Inspection 1 Average Data"] = self.ngProcess
                    excelData["Process 3 Casing Block Inspection 1 Minimum Data"] = self.ngProcess
                    excelData["Process 3 Casing Block Inspection 1 Maximum Data"] = self.ngProcess
                    excelData["Process 3 Casing Gasket"] = self.ngProcess
                    excelData["Process 3 Casing Gasket Lot No"] = self.ngProcess
                    excelData["Process 3 M4x16 Screw 1"] = self.ngProcess
                    excelData["Process 3 M4x16 Screw 1 Lot No"] = self.ngProcess
                    excelData["Process 3 M4x16 Screw 2"] = self.ngProcess
                    excelData["Process 3 M4x16 Screw 2 Lot No"] = self.ngProcess
                    excelData["Process 3 Ball Cushion"] = self.ngProcess
                    excelData["Process 3 Ball Cushion Lot No"] = self.ngProcess
                    excelData["Process 3 Frame Cover"] = self.ngProcess
                    excelData["Process 3 Frame Cover Lot No"] = self.ngProcess
                    excelData["Process 3 Partition Board"] = self.ngProcess
                    excelData["Process 3 Partition Board Lot No"] = self.ngProcess
                    excelData["Process 3 Built In Tube 1"] = self.ngProcess
                    excelData["Process 3 Built In Tube 1 Lot No"] = self.ngProcess
                    excelData["Process 3 Built In Tube 2"] = self.ngProcess
                    excelData["Process 3 Built In Tube 2 Lot No"] = self.ngProcess
                    excelData["Process 3 Head Cover"] = self.ngProcess
                    excelData["Process 3 Head Cover Lot No"] = self.ngProcess
                    excelData["Process 3 Casing Packing"] = self.ngProcess
                    excelData["Process 3 Casing Packing Lot No"] = self.ngProcess
                    excelData["Process 3 M4x12 Screw"] = self.ngProcess
                    excelData["Process 3 M4x12 Screw Lot No"] = self.ngProcess
                    excelData["Process 3 Csb L"] = self.ngProcess
                    excelData["Process 3 Csb L Lot No"] = self.ngProcess
                    excelData["Process 3 Csb R"] = self.ngProcess
                    excelData["Process 3 Csb R Lot No"] = self.ngProcess
                    excelData["Process 3 Head Packing"] = self.ngProcess
                    excelData["Process 3 Head Packing Lot No"] = self.ngProcess
                    excelData["Process 3 ST"] = self.ngProcess
                    excelData["Process 3 Actual Time"] = self.ngProcess
                    excelData["Process 3 NG Cause"] = self.ngProcess
                    excelData["Process 3 Repaired Action"] = self.ngProcess

                    excelData["Process 4 Model Code"] = self.ngProcess
                    excelData["Process 4 S/N"] = self.ngProcess
                    excelData["Process 4 ID"] = self.ngProcess
                    excelData["Process 4 NAME"] = self.ngProcess
                    excelData["Process 4 Regular/Contractual"] = self.ngProcess
                    excelData["Process 4 Tank"] = self.ngProcess
                    excelData["Process 4 Tank Lot No"] = self.ngProcess
                    excelData["Process 4 Upper Housing"] = self.ngProcess
                    excelData["Process 4 Upper Housing Lot No"] = self.ngProcess
                    excelData["Process 4 Cord Hook" ] = self.ngProcess
                    excelData["Process 4 Cord Hook Lot No"] = self.ngProcess
                    excelData["Process 4 M4x16 Screw"] = self.ngProcess
                    excelData["Process 4 M4x16 Screw Lot No"] = self.ngProcess
                    excelData["Process 4 Tank Gasket"] = self.ngProcess
                    excelData["Process 4 Tank Gasket Lot No"] = self.ngProcess
                    excelData["Process 4 Tank Cover"] = self.ngProcess
                    excelData["Process 4 Tank Cover Lot No"] = self.ngProcess
                    excelData["Process 4 Housing Gasket"] = self.ngProcess
                    excelData["Process 4 Housing Gasket Lot No"] = self.ngProcess
                    excelData["Process 4 M4x40 Screw"] = self.ngProcess
                    excelData["Process 4 M4x40 Screw Lot No"] = self.ngProcess
                    excelData["Process 4 PartitionGasket"] = self.ngProcess
                    excelData["Process 4 PartitionGasket Lot No"] = self.ngProcess
                    excelData["Process 4 M4x12 Screw"] = self.ngProcess
                    excelData["Process 4 M4x12 Screw Lot No"] = self.ngProcess
                    excelData["Process 4 Muffler"] = self.ngProcess
                    excelData["Process 4 Muffler Lot No"] = self.ngProcess
                    excelData["Process 4 Muffler Gasket"] = self.ngProcess
                    excelData["Process 4 Muffler Gasket Lot No"] = self.ngProcess
                    excelData["Process 4 VCR"] = self.ngProcess
                    excelData["Process 4 VCR Lot No"] = self.ngProcess
                    excelData["Process 4 ST"] = self.ngProcess
                    excelData["Process 4 Actual Time"] = self.ngProcess
                    excelData["Process 4 NG Cause"] = self.ngProcess
                    excelData["Process 4 Repaired Action"] = self.ngProcess
                    
                    excelData["Process 5 Model Code"] = self.ngProcess
                    excelData["Process 5 S/N"] = self.ngProcess
                    excelData["Process 5 ID"] = self.ngProcess
                    excelData["Process 5 NAME"] = self.ngProcess
                    excelData["Process 5 Regular/Contractual"] = self.ngProcess
                    excelData["Process 5 Rating Label"] = self.ngProcess
                    excelData["Process 5 Rating Label Lot No"] = self.ngProcess
                    excelData["Process 5 ST"] = self.ngProcess
                    excelData["Process 5 Actual Time"] = self.ngProcess
                    excelData["Process 5 NG Cause"] = self.ngProcess
                    excelData["Process 5 Repaired Action"] = self.ngProcess
                    
                    excelData["Process 6 Model Code"] = self.ngProcess
                    excelData["Process 6 S/N"] = self.ngProcess
                    excelData["Process 6 ID"] = self.ngProcess
                    excelData["Process 6 NAME"] = self.ngProcess
                    excelData["Process 6 Regular/Contractual"] = self.ngProcess
                    excelData["Process 6 Vinyl"] = self.ngProcess
                    excelData["Process 6 Vinyl Lot No"] = self.ngProcess
                    excelData["Process 6 ST"] = self.ngProcess
                    excelData["Process 6 Actual Time"] = self.ngProcess
                    excelData["Process 6 NG Cause"] = self.ngProcess
                    excelData["Process 6 Repaired Action"] = self.ngProcess

                elif self.process3Status == "NG":
                    self.ngProcess = "NG AT PROCESS3"
                    self.process1Row += 1
                    self.process2Row += 1
                    self.process3Row += 1

                    excelData["Process 4 Model Code"] = self.ngProcess
                    excelData["Process 4 S/N"] = self.ngProcess
                    excelData["Process 4 ID"] = self.ngProcess
                    excelData["Process 4 NAME"] = self.ngProcess
                    excelData["Process 4 Regular/Contractual"] = self.ngProcess
                    excelData["Process 4 Tank"] = self.ngProcess
                    excelData["Process 4 Tank Lot No"] = self.ngProcess
                    excelData["Process 4 Upper Housing"] = self.ngProcess
                    excelData["Process 4 Upper Housing Lot No"] = self.ngProcess
                    excelData["Process 4 Cord Hook" ] = self.ngProcess
                    excelData["Process 4 Cord Hook Lot No"] = self.ngProcess
                    excelData["Process 4 M4x16 Screw"] = self.ngProcess
                    excelData["Process 4 M4x16 Screw Lot No"] = self.ngProcess
                    excelData["Process 4 Tank Gasket"] = self.ngProcess
                    excelData["Process 4 Tank Gasket Lot No"] = self.ngProcess
                    excelData["Process 4 Tank Cover"] = self.ngProcess
                    excelData["Process 4 Tank Cover Lot No"] = self.ngProcess
                    excelData["Process 4 Housing Gasket"] = self.ngProcess
                    excelData["Process 4 Housing Gasket Lot No"] = self.ngProcess
                    excelData["Process 4 M4x40 Screw"] = self.ngProcess
                    excelData["Process 4 M4x40 Screw Lot No"] = self.ngProcess
                    excelData["Process 4 PartitionGasket"] = self.ngProcess
                    excelData["Process 4 PartitionGasket Lot No"] = self.ngProcess
                    excelData["Process 4 M4x12 Screw"] = self.ngProcess
                    excelData["Process 4 M4x12 Screw Lot No"] = self.ngProcess
                    excelData["Process 4 Muffler"] = self.ngProcess
                    excelData["Process 4 Muffler Lot No"] = self.ngProcess
                    excelData["Process 4 Muffler Gasket"] = self.ngProcess
                    excelData["Process 4 Muffler Gasket Lot No"] = self.ngProcess
                    excelData["Process 4 VCR"] = self.ngProcess
                    excelData["Process 4 VCR Lot No"] = self.ngProcess
                    excelData["Process 4 ST"] = self.ngProcess
                    excelData["Process 4 Actual Time"] = self.ngProcess
                    excelData["Process 4 NG Cause"] = self.ngProcess
                    excelData["Process 4 Repaired Action"] = self.ngProcess
                    
                    excelData["Process 5 Model Code"] = self.ngProcess
                    excelData["Process 5 S/N"] = self.ngProcess
                    excelData["Process 5 ID"] = self.ngProcess
                    excelData["Process 5 NAME"] = self.ngProcess
                    excelData["Process 5 Regular/Contractual"] = self.ngProcess
                    excelData["Process 5 Rating Label"] = self.ngProcess
                    excelData["Process 5 Rating Label Lot No"] = self.ngProcess
                    excelData["Process 5 ST"] = self.ngProcess
                    excelData["Process 5 Actual Time"] = self.ngProcess
                    excelData["Process 5 NG Cause"] = self.ngProcess
                    excelData["Process 5 Repaired Action"] = self.ngProcess
                    
                    excelData["Process 6 Model Code"] = self.ngProcess
                    excelData["Process 6 S/N"] = self.ngProcess
                    excelData["Process 6 ID"] = self.ngProcess
                    excelData["Process 6 NAME"] = self.ngProcess
                    excelData["Process 6 Regular/Contractual"] = self.ngProcess
                    excelData["Process 6 Vinyl"] = self.ngProcess
                    excelData["Process 6 Vinyl Lot No"] = self.ngProcess
                    excelData["Process 6 ST"] = self.ngProcess
                    excelData["Process 6 Actual Time"] = self.ngProcess
                    excelData["Process 6 NG Cause"] = self.ngProcess
                    excelData["Process 6 Repaired Action"] = self.ngProcess

                elif self.process4Status == "NG":
                    self.ngProcess = "NG AT PROCESS4"
                    self.process1Row += 1
                    self.process2Row += 1
                    self.process3Row += 1
                    self.process4Row += 1

                    excelData["Process 5 Model Code"] = self.ngProcess
                    excelData["Process 5 S/N"] = self.ngProcess
                    excelData["Process 5 ID"] = self.ngProcess
                    excelData["Process 5 NAME"] = self.ngProcess
                    excelData["Process 5 Regular/Contractual"] = self.ngProcess
                    excelData["Process 5 Rating Label"] = self.ngProcess
                    excelData["Process 5 Rating Label Lot No"] = self.ngProcess
                    excelData["Process 5 ST"] = self.ngProcess
                    excelData["Process 5 Actual Time"] = self.ngProcess
                    excelData["Process 5 NG Cause"] = self.ngProcess
                    excelData["Process 5 Repaired Action"] = self.ngProcess
                    
                    excelData["Process 6 Model Code"] = self.ngProcess
                    excelData["Process 6 S/N"] = self.ngProcess
                    excelData["Process 6 ID"] = self.ngProcess
                    excelData["Process 6 NAME"] = self.ngProcess
                    excelData["Process 6 Regular/Contractual"] = self.ngProcess
                    excelData["Process 6 Vinyl"] = self.ngProcess
                    excelData["Process 6 Vinyl Lot No"] = self.ngProcess
                    excelData["Process 6 ST"] = self.ngProcess
                    excelData["Process 6 Actual Time"] = self.ngProcess
                    excelData["Process 6 NG Cause"] = self.ngProcess
                    excelData["Process 6 Repaired Action"] = self.ngProcess

                elif self.process5Status == "NG PRESSURE":
                    self.ngProcess = "NG PRESSURE AT PROCESS5"
                    self.process1Row += 1
                    self.process2Row += 1
                    self.process3Row += 1
                    self.process4Row += 1
                    self.process5Row += 1
                    piCompiler.piRow += 1

                    excelData["DATE"] = self.ngProcess
                    excelData["TIME"] = self.ngProcess
                    excelData["MODEL CODE"] = self.ngProcess
                    # excelData["PROCESS S/N"] = self.ngProcess
                    excelData["S/N"] = self.ngProcess
                    excelData["PASS/NG"] = self.ngProcess
                    excelData["VOLTAGE MAX (V)"] = self.ngProcess
                    excelData["WATTAGE MAX (W)"] = self.ngProcess
                    excelData["CLOSED PRESSURE_MAX (kPa)"] = self.ngProcess
                    excelData["VOLTAGE Middle (V)"] = self.ngProcess
                    excelData["WATTAGE Middle (W)"] = self.ngProcess
                    excelData["AMPERAGE Middle (A)"] = self.ngProcess
                    excelData["CLOSED PRESSURE Middle (kPa)"] = self.ngProcess
                    excelData["dB(A) 1"] = self.ngProcess
                    excelData["dB(A) 2"] = self.ngProcess
                    excelData["dB(A) 3"] = self.ngProcess
                    excelData["VOLTAGE MIN (V)"] = self.ngProcess
                    excelData["WATTAGE MIN (W)"] = self.ngProcess
                    excelData["CLOSED PRESSURE MIN (kPa)"] = self.ngProcess

                    excelData["Process 6 Model Code"] = self.ngProcess
                    excelData["Process 6 S/N"] = self.ngProcess
                    excelData["Process 6 ID"] = self.ngProcess
                    excelData["Process 6 NAME"] = self.ngProcess
                    excelData["Process 6 Regular/Contractual"] = self.ngProcess
                    excelData["Process 6 Vinyl"] = self.ngProcess
                    excelData["Process 6 Vinyl Lot No"] = self.ngProcess
                    excelData["Process 6 ST"] = self.ngProcess
                    excelData["Process 6 Actual Time"] = self.ngProcess
                    excelData["Process 6 NG Cause"] = self.ngProcess
                    excelData["Process 6 Repaired Action"] = self.ngProcess

                elif self.process5Status == "NG":
                    self.ngProcess = "NG AT PROCESS5"
                    self.process1Row += 1
                    self.process2Row += 1
                    self.process3Row += 1
                    self.process4Row += 1
                    self.process5Row += 1
                    piCompiler.piRow += 1

                    excelData["Process 6 Model Code"] = self.ngProcess
                    excelData["Process 6 S/N"] = self.ngProcess
                    excelData["Process 6 ID"] = self.ngProcess
                    excelData["Process 6 NAME"] = self.ngProcess
                    excelData["Process 6 Regular/Contractual"] = self.ngProcess
                    excelData["Process 6 Vinyl"] = self.ngProcess
                    excelData["Process 6 Vinyl Lot No"] = self.ngProcess
                    excelData["Process 6 ST"] = self.ngProcess
                    excelData["Process 6 Actual Time"] = self.ngProcess
                    excelData["Process 6 NG Cause"] = self.ngProcess
                    excelData["Process 6 Repaired Action"] = self.ngProcess

                elif self.process6Status == "NG":
                    self.ngProcess = "NG AT PROCESS6"
                    self.process1Row += 1
                    self.process2Row += 1
                    self.process3Row += 1
                    self.process4Row += 1
                    self.process5Row += 1
                    self.process6Row += 1
                    piCompiler.piRow += 1

            # REPAIRED AT PROCESS 2
            elif self.process2Status == "Repaired":
                if self.process3Status == "NG":
                    self.repairedProcess = "REPAIRED AT PROCESS2"
                    self.ngProcess = "NG AT PROCESS3"
                    self.process2Row += 1
                    self.process3Row += 1

                    excelData["Process 1 Model Code"] = self.repairedProcess
                    excelData["Process 1 S/N"] = self.repairedProcess
                    excelData["Process 1 ID"] = self.repairedProcess
                    excelData["Process 1 NAME"] = self.repairedProcess
                    excelData["Process 1 Regular/Contractual"] = self.repairedProcess
                    excelData["Process 1 Em2p"] = self.repairedProcess
                    excelData["Process 1 Em2p Lot No"] = self.repairedProcess
                    excelData["Process 1 Em3p"] = self.repairedProcess
                    excelData["Process 1 Em3p Lot No"] = self.repairedProcess
                    excelData["Process 1 Harness"] = self.repairedProcess
                    excelData["Process 1 Harness Lot No"] = self.repairedProcess
                    excelData["Process 1 Frame"] = self.repairedProcess
                    excelData["Process 1 Frame Lot No"] = self.repairedProcess 
                    excelData["Process 1 Bushing"] = self.repairedProcess
                    excelData["Process 1 Bushing Lot No"] = self.repairedProcess
                    excelData["Process 1 ST"] = self.repairedProcess
                    excelData["Process 1 Actual Time"] = self.repairedProcess
                    excelData["Process 1 NG Cause"] = self.repairedProcess
                    excelData["Process 1 Repaired Action"] = self.repairedProcess

                    excelData["Process 4 Model Code"] = self.ngProcess
                    excelData["Process 4 S/N"] = self.ngProcess
                    excelData["Process 4 ID"] = self.ngProcess
                    excelData["Process 4 NAME"] = self.ngProcess
                    excelData["Process 4 Regular/Contractual"] = self.ngProcess
                    excelData["Process 4 Tank"] = self.ngProcess
                    excelData["Process 4 Tank Lot No"] = self.ngProcess
                    excelData["Process 4 Upper Housing"] = self.ngProcess
                    excelData["Process 4 Upper Housing Lot No"] = self.ngProcess
                    excelData["Process 4 Cord Hook" ] = self.ngProcess
                    excelData["Process 4 Cord Hook Lot No"] = self.ngProcess
                    excelData["Process 4 M4x16 Screw"] = self.ngProcess
                    excelData["Process 4 M4x16 Screw Lot No"] = self.ngProcess
                    excelData["Process 4 Tank Gasket"] = self.ngProcess
                    excelData["Process 4 Tank Gasket Lot No"] = self.ngProcess
                    excelData["Process 4 Tank Cover"] = self.ngProcess
                    excelData["Process 4 Tank Cover Lot No"] = self.ngProcess
                    excelData["Process 4 Housing Gasket"] = self.ngProcess
                    excelData["Process 4 Housing Gasket Lot No"] = self.ngProcess
                    excelData["Process 4 M4x40 Screw"] = self.ngProcess
                    excelData["Process 4 M4x40 Screw Lot No"] = self.ngProcess
                    excelData["Process 4 PartitionGasket"] = self.ngProcess
                    excelData["Process 4 PartitionGasket Lot No"] = self.ngProcess
                    excelData["Process 4 M4x12 Screw"] = self.ngProcess
                    excelData["Process 4 M4x12 Screw Lot No"] = self.ngProcess
                    excelData["Process 4 Muffler"] = self.ngProcess
                    excelData["Process 4 Muffler Lot No"] = self.ngProcess
                    excelData["Process 4 Muffler Gasket"] = self.ngProcess
                    excelData["Process 4 Muffler Gasket Lot No"] = self.ngProcess
                    excelData["Process 4 VCR"] = self.ngProcess
                    excelData["Process 4 VCR Lot No"] = self.ngProcess
                    excelData["Process 4 ST"] = self.ngProcess
                    excelData["Process 4 Actual Time"] = self.ngProcess
                    excelData["Process 4 NG Cause"] = self.ngProcess
                    excelData["Process 4 Repaired Action"] = self.ngProcess

                    excelData["Process 5 Model Code"] = self.ngProcess
                    excelData["Process 5 S/N"] = self.ngProcess
                    excelData["Process 5 ID"] = self.ngProcess
                    excelData["Process 5 NAME"] = self.ngProcess
                    excelData["Process 5 Regular/Contractual"] = self.ngProcess
                    excelData["Process 5 Rating Label"] = self.ngProcess
                    excelData["Process 5 Rating Label Lot No"] = self.ngProcess
                    excelData["Process 5 ST"] = self.ngProcess
                    excelData["Process 5 Actual Time"] = self.ngProcess
                    excelData["Process 5 NG Cause"] = self.ngProcess
                    excelData["Process 5 Repaired Action"] = self.ngProcess

                    excelData["Process 6 Model Code"] = self.ngProcess
                    excelData["Process 6 S/N"] = self.ngProcess
                    excelData["Process 6 ID"] = self.ngProcess
                    excelData["Process 6 NAME"] = self.ngProcess
                    excelData["Process 6 Regular/Contractual"] = self.ngProcess
                    excelData["Process 6 Vinyl"] = self.ngProcess
                    excelData["Process 6 Vinyl Lot No"] = self.ngProcess
                    excelData["Process 6 ST"] = self.ngProcess
                    excelData["Process 6 Actual Time"] = self.ngProcess
                    excelData["Process 6 NG Cause"] = self.ngProcess
                    excelData["Process 6 Repaired Action"] = self.ngProcess

                elif self.process4Status == "NG":
                    self.repairedProcess = "REPAIRED AT PROCESS2"
                    self.ngProcess = "NG AT PROCESS4"
                    self.process2Row += 1
                    self.process3Row += 1
                    self.process4Row += 1

                    excelData["Process 1 Model Code"] = self.repairedProcess
                    excelData["Process 1 S/N"] = self.repairedProcess
                    excelData["Process 1 ID"] = self.repairedProcess
                    excelData["Process 1 NAME"] = self.repairedProcess
                    excelData["Process 1 Regular/Contractual"] = self.repairedProcess
                    excelData["Process 1 Em2p"] = self.repairedProcess
                    excelData["Process 1 Em2p Lot No"] = self.repairedProcess
                    excelData["Process 1 Em3p"] = self.repairedProcess
                    excelData["Process 1 Em3p Lot No"] = self.repairedProcess
                    excelData["Process 1 Harness"] = self.repairedProcess
                    excelData["Process 1 Harness Lot No"] = self.repairedProcess
                    excelData["Process 1 Frame"] = self.repairedProcess
                    excelData["Process 1 Frame Lot No"] = self.repairedProcess 
                    excelData["Process 1 Bushing"] = self.repairedProcess
                    excelData["Process 1 Bushing Lot No"] = self.repairedProcess
                    excelData["Process 1 ST"] = self.repairedProcess
                    excelData["Process 1 Actual Time"] = self.repairedProcess
                    excelData["Process 1 NG Cause"] = self.repairedProcess
                    excelData["Process 1 Repaired Action"] = self.repairedProcess 

                    excelData["Process 5 Model Code"] = self.ngProcess
                    excelData["Process 5 S/N"] = self.ngProcess
                    excelData["Process 5 ID"] = self.ngProcess
                    excelData["Process 5 NAME"] = self.ngProcess
                    excelData["Process 5 Regular/Contractual"] = self.ngProcess
                    excelData["Process 5 Rating Label"] = self.ngProcess
                    excelData["Process 5 Rating Label Lot No"] = self.ngProcess
                    excelData["Process 5 ST"] = self.ngProcess
                    excelData["Process 5 Actual Time"] = self.ngProcess
                    excelData["Process 5 NG Cause"] = self.ngProcess
                    excelData["Process 5 Repaired Action"] = self.ngProcess

                    excelData["Process 6 Model Code"] = self.ngProcess
                    excelData["Process 6 S/N"] = self.ngProcess
                    excelData["Process 6 ID"] = self.ngProcess
                    excelData["Process 6 NAME"] = self.ngProcess
                    excelData["Process 6 Regular/Contractual"] = self.ngProcess
                    excelData["Process 6 Vinyl"] = self.ngProcess
                    excelData["Process 6 Vinyl Lot No"] = self.ngProcess
                    excelData["Process 6 ST"] = self.ngProcess
                    excelData["Process 6 Actual Time"] = self.ngProcess
                    excelData["Process 6 NG Cause"] = self.ngProcess
                    excelData["Process 6 Repaired Action"] = self.ngProcess

                elif self.process5Status == "NG PRESSURE":
                    self.repairedProcess = "REPAIRED AT PROCESS2"
                    self.ngProcess = "NG PRESSURE AT PROCESS5"
                    self.process2Row += 1
                    self.process3Row += 1
                    self.process4Row += 1
                    self.process5Row += 1
                    piCompiler.piRow += 1

                    excelData["DATE"] = self.ngProcess
                    excelData["TIME"] = self.ngProcess
                    excelData["MODEL CODE"] = self.ngProcess
                    # excelData["PROCESS S/N"] = self.ngProcess
                    excelData["S/N"] = self.ngProcess
                    excelData["PASS/NG"] = self.ngProcess
                    excelData["VOLTAGE MAX (V)"] = self.ngProcess
                    excelData["WATTAGE MAX (W)"] = self.ngProcess
                    excelData["CLOSED PRESSURE_MAX (kPa)"] = self.ngProcess
                    excelData["VOLTAGE Middle (V)"] = self.ngProcess
                    excelData["WATTAGE Middle (W)"] = self.ngProcess
                    excelData["AMPERAGE Middle (A)"] = self.ngProcess
                    excelData["CLOSED PRESSURE Middle (kPa)"] = self.ngProcess
                    excelData["dB(A) 1"] = self.ngProcess
                    excelData["dB(A) 2"] = self.ngProcess
                    excelData["dB(A) 3"] = self.ngProcess
                    excelData["VOLTAGE MIN (V)"] = self.ngProcess
                    excelData["WATTAGE MIN (W)"] = self.ngProcess
                    excelData["CLOSED PRESSURE MIN (kPa)"] = self.ngProcess

                    excelData["Process 1 Model Code"] = self.repairedProcess
                    excelData["Process 1 S/N"] = self.repairedProcess
                    excelData["Process 1 ID"] = self.repairedProcess
                    excelData["Process 1 NAME"] = self.repairedProcess
                    excelData["Process 1 Regular/Contractual"] = self.repairedProcess
                    excelData["Process 1 Em2p"] = self.repairedProcess
                    excelData["Process 1 Em2p Lot No"] = self.repairedProcess
                    excelData["Process 1 Em3p"] = self.repairedProcess
                    excelData["Process 1 Em3p Lot No"] = self.repairedProcess
                    excelData["Process 1 Harness"] = self.repairedProcess
                    excelData["Process 1 Harness Lot No"] = self.repairedProcess
                    excelData["Process 1 Frame"] = self.repairedProcess
                    excelData["Process 1 Frame Lot No"] = self.repairedProcess 
                    excelData["Process 1 Bushing"] = self.repairedProcess
                    excelData["Process 1 Bushing Lot No"] = self.repairedProcess
                    excelData["Process 1 ST"] = self.repairedProcess
                    excelData["Process 1 Actual Time"] = self.repairedProcess
                    excelData["Process 1 NG Cause"] = self.repairedProcess
                    excelData["Process 1 Repaired Action"] = self.repairedProcess  

                    excelData["Process 6 Model Code"] = self.ngProcess
                    excelData["Process 6 S/N"] = self.ngProcess
                    excelData["Process 6 ID"] = self.ngProcess
                    excelData["Process 6 NAME"] = self.ngProcess
                    excelData["Process 6 Regular/Contractual"] = self.ngProcess
                    excelData["Process 6 Vinyl"] = self.ngProcess
                    excelData["Process 6 Vinyl Lot No"] = self.ngProcess
                    excelData["Process 6 ST"] = self.ngProcess
                    excelData["Process 6 Actual Time"] = self.ngProcess
                    excelData["Process 6 NG Cause"] = self.ngProcess
                    excelData["Process 6 Repaired Action"] = self.ngProcess
                elif self.process5Status == "NG":
                    self.repairedProcess = "REPAIRED AT PROCESS2"
                    self.ngProcess = "NG AT PROCESS5"
                    self.process2Row += 1
                    self.process3Row += 1
                    self.process4Row += 1
                    self.process5Row += 1
                    piCompiler.piRow += 1

                    excelData["Process 1 Model Code"] = self.repairedProcess
                    excelData["Process 1 S/N"] = self.repairedProcess
                    excelData["Process 1 ID"] = self.repairedProcess
                    excelData["Process 1 NAME"] = self.repairedProcess
                    excelData["Process 1 Regular/Contractual"] = self.repairedProcess
                    excelData["Process 1 Em2p"] = self.repairedProcess
                    excelData["Process 1 Em2p Lot No"] = self.repairedProcess
                    excelData["Process 1 Em3p"] = self.repairedProcess
                    excelData["Process 1 Em3p Lot No"] = self.repairedProcess
                    excelData["Process 1 Harness"] = self.repairedProcess
                    excelData["Process 1 Harness Lot No"] = self.repairedProcess
                    excelData["Process 1 Frame"] = self.repairedProcess
                    excelData["Process 1 Frame Lot No"] = self.repairedProcess 
                    excelData["Process 1 Bushing"] = self.repairedProcess
                    excelData["Process 1 Bushing Lot No"] = self.repairedProcess
                    excelData["Process 1 ST"] = self.repairedProcess
                    excelData["Process 1 Actual Time"] = self.repairedProcess
                    excelData["Process 1 NG Cause"] = self.repairedProcess
                    excelData["Process 1 Repaired Action"] = self.repairedProcess  

                    excelData["Process 6 Model Code"] = self.ngProcess
                    excelData["Process 6 S/N"] = self.ngProcess
                    excelData["Process 6 ID"] = self.ngProcess
                    excelData["Process 6 NAME"] = self.ngProcess
                    excelData["Process 6 Regular/Contractual"] = self.ngProcess
                    excelData["Process 6 Vinyl"] = self.ngProcess
                    excelData["Process 6 Vinyl Lot No"] = self.ngProcess
                    excelData["Process 6 ST"] = self.ngProcess
                    excelData["Process 6 Actual Time"] = self.ngProcess
                    excelData["Process 6 NG Cause"] = self.ngProcess
                    excelData["Process 6 Repaired Action"] = self.ngProcess

                elif self.process6Status == "NG":
                    self.repairedProcess = "REPAIRED AT PROCESS2"
                    
                    self.process2Row += 1
                    self.process3Row += 1
                    self.process4Row += 1
                    self.process5Row += 1
                    self.process6Row += 1
                    piCompiler.piRow += 1

                    excelData["Process 1 Model Code"] = self.repairedProcess
                    excelData["Process 1 S/N"] = self.repairedProcess
                    excelData["Process 1 ID"] = self.repairedProcess
                    excelData["Process 1 NAME"] = self.repairedProcess
                    excelData["Process 1 Regular/Contractual"] = self.repairedProcess
                    excelData["Process 1 Em2p"] = self.repairedProcess
                    excelData["Process 1 Em2p Lot No"] = self.repairedProcess
                    excelData["Process 1 Em3p"] = self.repairedProcess
                    excelData["Process 1 Em3p Lot No"] = self.repairedProcess
                    excelData["Process 1 Harness"] = self.repairedProcess
                    excelData["Process 1 Harness Lot No"] = self.repairedProcess
                    excelData["Process 1 Frame"] = self.repairedProcess
                    excelData["Process 1 Frame Lot No"] = self.repairedProcess 
                    excelData["Process 1 Bushing"] = self.repairedProcess
                    excelData["Process 1 Bushing Lot No"] = self.repairedProcess
                    excelData["Process 1 ST"] = self.repairedProcess
                    excelData["Process 1 Actual Time"] = self.repairedProcess
                    excelData["Process 1 NG Cause"] = self.repairedProcess
                    excelData["Process 1 Repaired Action"] = self.repairedProcess  

            elif self.process3Status == "Repaired":
                if self.process4Status == "NG":
                    self.repairedProcess = "REPAIRED AT PROCESS3"
                    self.ngProcess = "NG AT PROCESS4"
                    self.process3Row += 1
                    self.process4Row += 1

                    excelData["Process 1 Model Code"] = self.repairedProcess
                    excelData["Process 1 S/N"] = self.repairedProcess
                    excelData["Process 1 ID"] = self.repairedProcess
                    excelData["Process 1 NAME"] = self.repairedProcess
                    excelData["Process 1 Regular/Contractual"] = self.repairedProcess
                    excelData["Process 1 Em2p"] = self.repairedProcess
                    excelData["Process 1 Em2p Lot No"] = self.repairedProcess
                    excelData["Process 1 Em3p"] = self.repairedProcess
                    excelData["Process 1 Em3p Lot No"] = self.repairedProcess
                    excelData["Process 1 Harness"] = self.repairedProcess
                    excelData["Process 1 Harness Lot No"] = self.repairedProcess
                    excelData["Process 1 Frame"] = self.repairedProcess
                    excelData["Process 1 Frame Lot No"] = self.repairedProcess 
                    excelData["Process 1 Bushing"] = self.repairedProcess
                    excelData["Process 1 Bushing Lot No"] = self.repairedProcess
                    excelData["Process 1 ST"] = self.repairedProcess
                    excelData["Process 1 Actual Time"] = self.repairedProcess
                    excelData["Process 1 NG Cause"] = self.repairedProcess
                    excelData["Process 1 Repaired Action"] = self.repairedProcess  

                    excelData["Process 2 Model Code"] = self.repairedProcess
                    excelData["Process 2 S/N"] = self.repairedProcess
                    excelData["Process 2 ID"] = self.repairedProcess
                    excelData["Process 2 NAME"] = self.repairedProcess
                    excelData["Process 2 Regular/Contractual"] = self.repairedProcess
                    excelData["Process 2 M4x40 Screw"] = self.repairedProcess
                    excelData["Process 2 M4x40 Screw Lot No"] = self.repairedProcess
                    excelData["Process 2 Rod Blk"] = self.repairedProcess
                    excelData["Process 2 Rod Blk Lot No"] = self.repairedProcess
                    excelData["Process 2 Df Blk"] = self.repairedProcess
                    excelData["Process 2 Df Blk Lot No"] = self.repairedProcess
                    excelData["Process 2 Df Ring"] = self.repairedProcess
                    excelData["Process 2 Df Ring Lot No"] = self.repairedProcess
                    excelData["Process 2 Washer"] = self.repairedProcess
                    excelData["Process 2 Washer Lot No"] = self.repairedProcess
                    excelData["Process 2 Lock Nut"] = self.repairedProcess
                    excelData["Process 2 Lock Nut Lot No"] = self.repairedProcess
                    excelData["Process 2 ST"] = self.repairedProcess
                    excelData["Process 2 Actual Time"] = self.repairedProcess
                    excelData["Process 2 NG Cause"] = self.repairedProcess
                    excelData["Process 2 Repaired Action"] = self.repairedProcess

                    excelData["Process 5 Model Code"] = self.ngProcess
                    excelData["Process 5 S/N"] = self.ngProcess
                    excelData["Process 5 ID"] = self.ngProcess
                    excelData["Process 5 NAME"] = self.ngProcess
                    excelData["Process 5 Regular/Contractual"] = self.ngProcess
                    excelData["Process 5 Rating Label"] = self.ngProcess
                    excelData["Process 5 Rating Label Lot No"] = self.ngProcess
                    excelData["Process 5 ST"] = self.ngProcess
                    excelData["Process 5 Actual Time"] = self.ngProcess
                    excelData["Process 5 NG Cause"] = self.ngProcess
                    excelData["Process 5 Repaired Action"] = self.ngProcess

                    excelData["Process 6 Model Code"] = self.ngProcess
                    excelData["Process 6 S/N"] = self.ngProcess
                    excelData["Process 6 ID"] = self.ngProcess
                    excelData["Process 6 NAME"] = self.ngProcess
                    excelData["Process 6 Regular/Contractual"] = self.ngProcess
                    excelData["Process 6 Vinyl"] = self.ngProcess
                    excelData["Process 6 Vinyl Lot No"] = self.ngProcess
                    excelData["Process 6 ST"] = self.ngProcess
                    excelData["Process 6 Actual Time"] = self.ngProcess
                    excelData["Process 6 NG Cause"] = self.ngProcess
                    excelData["Process 6 Repaired Action"] = self.ngProcess

                elif self.process5Status == "NG PRESSURE":
                    self.repairedProcess = "REPAIRED AT PROCESS3"
                    self.ngProcess = "NG PRESSURE AT PROCESS5"
                    self.process3Row += 1
                    self.process4Row += 1
                    self.process5Row += 1
                    piCompiler.piRow += 1

                    excelData["DATE"] = self.ngProcess
                    excelData["TIME"] = self.ngProcess
                    excelData["MODEL CODE"] = self.ngProcess
                    # excelData["PROCESS S/N"] = self.ngProcess
                    excelData["S/N"] = self.ngProcess
                    excelData["PASS/NG"] = self.ngProcess
                    excelData["VOLTAGE MAX (V)"] = self.ngProcess
                    excelData["WATTAGE MAX (W)"] = self.ngProcess
                    excelData["CLOSED PRESSURE_MAX (kPa)"] = self.ngProcess
                    excelData["VOLTAGE Middle (V)"] = self.ngProcess
                    excelData["WATTAGE Middle (W)"] = self.ngProcess
                    excelData["AMPERAGE Middle (A)"] = self.ngProcess
                    excelData["CLOSED PRESSURE Middle (kPa)"] = self.ngProcess
                    excelData["dB(A) 1"] = self.ngProcess
                    excelData["dB(A) 2"] = self.ngProcess
                    excelData["dB(A) 3"] = self.ngProcess
                    excelData["VOLTAGE MIN (V)"] = self.ngProcess
                    excelData["WATTAGE MIN (W)"] = self.ngProcess
                    excelData["CLOSED PRESSURE MIN (kPa)"] = self.ngProcess

                    excelData["Process 1 Model Code"] = self.repairedProcess
                    excelData["Process 1 S/N"] = self.repairedProcess
                    excelData["Process 1 ID"] = self.repairedProcess
                    excelData["Process 1 NAME"] = self.repairedProcess
                    excelData["Process 1 Regular/Contractual"] = self.repairedProcess
                    excelData["Process 1 Em2p"] = self.repairedProcess
                    excelData["Process 1 Em2p Lot No"] = self.repairedProcess
                    excelData["Process 1 Em3p"] = self.repairedProcess
                    excelData["Process 1 Em3p Lot No"] = self.repairedProcess
                    excelData["Process 1 Harness"] = self.repairedProcess
                    excelData["Process 1 Harness Lot No"] = self.repairedProcess
                    excelData["Process 1 Frame"] = self.repairedProcess
                    excelData["Process 1 Frame Lot No"] = self.repairedProcess 
                    excelData["Process 1 Bushing"] = self.repairedProcess
                    excelData["Process 1 Bushing Lot No"] = self.repairedProcess
                    excelData["Process 1 ST"] = self.repairedProcess
                    excelData["Process 1 Actual Time"] = self.repairedProcess
                    excelData["Process 1 NG Cause"] = self.repairedProcess
                    excelData["Process 1 Repaired Action"] = self.repairedProcess  

                    excelData["Process 2 Model Code"] = self.repairedProcess
                    excelData["Process 2 S/N"] = self.repairedProcess
                    excelData["Process 2 ID"] = self.repairedProcess
                    excelData["Process 2 NAME"] = self.repairedProcess
                    excelData["Process 2 Regular/Contractual"] = self.repairedProcess
                    excelData["Process 2 M4x40 Screw"] = self.repairedProcess
                    excelData["Process 2 M4x40 Screw Lot No"] = self.repairedProcess
                    excelData["Process 2 Rod Blk"] = self.repairedProcess
                    excelData["Process 2 Rod Blk Lot No"] = self.repairedProcess
                    excelData["Process 2 Df Blk"] = self.repairedProcess
                    excelData["Process 2 Df Blk Lot No"] = self.repairedProcess
                    excelData["Process 2 Df Ring"] = self.repairedProcess
                    excelData["Process 2 Df Ring Lot No"] = self.repairedProcess
                    excelData["Process 2 Washer"] = self.repairedProcess
                    excelData["Process 2 Washer Lot No"] = self.repairedProcess
                    excelData["Process 2 Lock Nut"] = self.repairedProcess
                    excelData["Process 2 Lock Nut Lot No"] = self.repairedProcess
                    excelData["Process 2 ST"] = self.repairedProcess
                    excelData["Process 2 Actual Time"] = self.repairedProcess
                    excelData["Process 2 NG Cause"] = self.repairedProcess
                    excelData["Process 2 Repaired Action"] = self.repairedProcess

                    excelData["Process 6 Model Code"] = self.ngProcess
                    excelData["Process 6 S/N"] = self.ngProcess
                    excelData["Process 6 ID"] = self.ngProcess
                    excelData["Process 6 NAME"] = self.ngProcess
                    excelData["Process 6 Regular/Contractual"] = self.ngProcess
                    excelData["Process 6 Vinyl"] = self.ngProcess
                    excelData["Process 6 Vinyl Lot No"] = self.ngProcess
                    excelData["Process 6 ST"] = self.ngProcess
                    excelData["Process 6 Actual Time"] = self.ngProcess
                    excelData["Process 6 NG Cause"] = self.ngProcess
                    excelData["Process 6 Repaired Action"] = self.ngProcess

                elif self.process5Status == "NG":
                    self.repairedProcess = "REPAIRED AT PROCESS3"
                    self.ngProcess = "NG AT PROCESS5"
                    self.process3Row += 1
                    self.process4Row += 1
                    self.process5Row += 1
                    piCompiler.piRow += 1

                    excelData["Process 1 Model Code"] = self.repairedProcess
                    excelData["Process 1 S/N"] = self.repairedProcess
                    excelData["Process 1 ID"] = self.repairedProcess
                    excelData["Process 1 NAME"] = self.repairedProcess
                    excelData["Process 1 Regular/Contractual"] = self.repairedProcess
                    excelData["Process 1 Em2p"] = self.repairedProcess
                    excelData["Process 1 Em2p Lot No"] = self.repairedProcess
                    excelData["Process 1 Em3p"] = self.repairedProcess
                    excelData["Process 1 Em3p Lot No"] = self.repairedProcess
                    excelData["Process 1 Harness"] = self.repairedProcess
                    excelData["Process 1 Harness Lot No"] = self.repairedProcess
                    excelData["Process 1 Frame"] = self.repairedProcess
                    excelData["Process 1 Frame Lot No"] = self.repairedProcess 
                    excelData["Process 1 Bushing"] = self.repairedProcess
                    excelData["Process 1 Bushing Lot No"] = self.repairedProcess
                    excelData["Process 1 ST"] = self.repairedProcess
                    excelData["Process 1 Actual Time"] = self.repairedProcess
                    excelData["Process 1 NG Cause"] = self.repairedProcess
                    excelData["Process 1 Repaired Action"] = self.repairedProcess  

                    excelData["Process 2 Model Code"] = self.repairedProcess
                    excelData["Process 2 S/N"] = self.repairedProcess
                    excelData["Process 2 ID"] = self.repairedProcess
                    excelData["Process 2 NAME"] = self.repairedProcess
                    excelData["Process 2 Regular/Contractual"] = self.repairedProcess
                    excelData["Process 2 M4x40 Screw"] = self.repairedProcess
                    excelData["Process 2 M4x40 Screw Lot No"] = self.repairedProcess
                    excelData["Process 2 Rod Blk"] = self.repairedProcess
                    excelData["Process 2 Rod Blk Lot No"] = self.repairedProcess
                    excelData["Process 2 Df Blk"] = self.repairedProcess
                    excelData["Process 2 Df Blk Lot No"] = self.repairedProcess
                    excelData["Process 2 Df Ring"] = self.repairedProcess
                    excelData["Process 2 Df Ring Lot No"] = self.repairedProcess
                    excelData["Process 2 Washer"] = self.repairedProcess
                    excelData["Process 2 Washer Lot No"] = self.repairedProcess
                    excelData["Process 2 Lock Nut"] = self.repairedProcess
                    excelData["Process 2 Lock Nut Lot No"] = self.repairedProcess
                    excelData["Process 2 ST"] = self.repairedProcess
                    excelData["Process 2 Actual Time"] = self.repairedProcess
                    excelData["Process 2 NG Cause"] = self.repairedProcess
                    excelData["Process 2 Repaired Action"] = self.repairedProcess

                    excelData["Process 6 Model Code"] = self.ngProcess
                    excelData["Process 6 S/N"] = self.ngProcess
                    excelData["Process 6 ID"] = self.ngProcess
                    excelData["Process 6 NAME"] = self.ngProcess
                    excelData["Process 6 Regular/Contractual"] = self.ngProcess
                    excelData["Process 6 Vinyl"] = self.ngProcess
                    excelData["Process 6 Vinyl Lot No"] = self.ngProcess
                    excelData["Process 6 ST"] = self.ngProcess
                    excelData["Process 6 Actual Time"] = self.ngProcess
                    excelData["Process 6 NG Cause"] = self.ngProcess
                    excelData["Process 6 Repaired Action"] = self.ngProcess

                elif self.process6Status == "NG":
                    self.repairedProcess = "REPAIRED AT PROCESS3"
                    self.ngProcess = "NG AT PROCESS6"
                    self.process3Row += 1
                    self.process4Row += 1
                    self.process5Row += 1
                    self.process6Row += 1
                    piCompiler.piRow += 1

                    excelData["Process 1 Model Code"] = self.repairedProcess
                    excelData["Process 1 S/N"] = self.repairedProcess
                    excelData["Process 1 ID"] = self.repairedProcess
                    excelData["Process 1 NAME"] = self.repairedProcess
                    excelData["Process 1 Regular/Contractual"] = self.repairedProcess
                    excelData["Process 1 Em2p"] = self.repairedProcess
                    excelData["Process 1 Em2p Lot No"] = self.repairedProcess
                    excelData["Process 1 Em3p"] = self.repairedProcess
                    excelData["Process 1 Em3p Lot No"] = self.repairedProcess
                    excelData["Process 1 Harness"] = self.repairedProcess
                    excelData["Process 1 Harness Lot No"] = self.repairedProcess
                    excelData["Process 1 Frame"] = self.repairedProcess
                    excelData["Process 1 Frame Lot No"] = self.repairedProcess 
                    excelData["Process 1 Bushing"] = self.repairedProcess
                    excelData["Process 1 Bushing Lot No"] = self.repairedProcess
                    excelData["Process 1 ST"] = self.repairedProcess
                    excelData["Process 1 Actual Time"] = self.repairedProcess
                    excelData["Process 1 NG Cause"] = self.repairedProcess
                    excelData["Process 1 Repaired Action"] = self.repairedProcess  

                    excelData["Process 2 Model Code"] = self.repairedProcess
                    excelData["Process 2 S/N"] = self.repairedProcess
                    excelData["Process 2 ID"] = self.repairedProcess
                    excelData["Process 2 NAME"] = self.repairedProcess
                    excelData["Process 2 Regular/Contractual"] = self.repairedProcess
                    excelData["Process 2 M4x40 Screw"] = self.repairedProcess
                    excelData["Process 2 M4x40 Screw Lot No"] = self.repairedProcess
                    excelData["Process 2 Rod Blk"] = self.repairedProcess
                    excelData["Process 2 Rod Blk Lot No"] = self.repairedProcess
                    excelData["Process 2 Df Blk"] = self.repairedProcess
                    excelData["Process 2 Df Blk Lot No"] = self.repairedProcess
                    excelData["Process 2 Df Ring"] = self.repairedProcess
                    excelData["Process 2 Df Ring Lot No"] = self.repairedProcess
                    excelData["Process 2 Washer"] = self.repairedProcess
                    excelData["Process 2 Washer Lot No"] = self.repairedProcess
                    excelData["Process 2 Lock Nut"] = self.repairedProcess
                    excelData["Process 2 Lock Nut Lot No"] = self.repairedProcess
                    excelData["Process 2 ST"] = self.repairedProcess
                    excelData["Process 2 Actual Time"] = self.repairedProcess
                    excelData["Process 2 NG Cause"] = self.repairedProcess
                    excelData["Process 2 Repaired Action"] = self.repairedProcess

            elif self.process4Status == "Repaired":
                if self.process5Status == "NG PRESSURE":
                    self.repairedProcess = "REPAIRED AT PROCESS4"
                    self.ngProcess = "NG PRESSURE AT PROCESS5"
                    self.process4Row += 1
                    self.process5Row += 1
                    piCompiler.piRow += 1

                    excelData["DATE"] = self.ngProcess
                    excelData["TIME"] = self.ngProcess
                    excelData["MODEL CODE"] = self.ngProcess
                    # excelData["PROCESS S/N"] = self.ngProcess
                    excelData["S/N"] = self.ngProcess
                    excelData["PASS/NG"] = self.ngProcess
                    excelData["VOLTAGE MAX (V)"] = self.ngProcess
                    excelData["WATTAGE MAX (W)"] = self.ngProcess
                    excelData["CLOSED PRESSURE_MAX (kPa)"] = self.ngProcess
                    excelData["VOLTAGE Middle (V)"] = self.ngProcess
                    excelData["WATTAGE Middle (W)"] = self.ngProcess
                    excelData["AMPERAGE Middle (A)"] = self.ngProcess
                    excelData["CLOSED PRESSURE Middle (kPa)"] = self.ngProcess
                    excelData["dB(A) 1"] = self.ngProcess
                    excelData["dB(A) 2"] = self.ngProcess
                    excelData["dB(A) 3"] = self.ngProcess
                    excelData["VOLTAGE MIN (V)"] = self.ngProcess
                    excelData["WATTAGE MIN (W)"] = self.ngProcess
                    excelData["CLOSED PRESSURE MIN (kPa)"] = self.ngProcess

                    excelData["Process 1 Model Code"] = self.repairedProcess
                    excelData["Process 1 S/N"] = self.repairedProcess
                    excelData["Process 1 ID"] = self.repairedProcess
                    excelData["Process 1 NAME"] = self.repairedProcess
                    excelData["Process 1 Regular/Contractual"] = self.repairedProcess
                    excelData["Process 1 Em2p"] = self.repairedProcess
                    excelData["Process 1 Em2p Lot No"] = self.repairedProcess
                    excelData["Process 1 Em3p"] = self.repairedProcess
                    excelData["Process 1 Em3p Lot No"] = self.repairedProcess
                    excelData["Process 1 Harness"] = self.repairedProcess
                    excelData["Process 1 Harness Lot No"] = self.repairedProcess
                    excelData["Process 1 Frame"] = self.repairedProcess
                    excelData["Process 1 Frame Lot No"] = self.repairedProcess 
                    excelData["Process 1 Bushing"] = self.repairedProcess
                    excelData["Process 1 Bushing Lot No"] = self.repairedProcess
                    excelData["Process 1 ST"] = self.repairedProcess
                    excelData["Process 1 Actual Time"] = self.repairedProcess
                    excelData["Process 1 NG Cause"] = self.repairedProcess
                    excelData["Process 1 Repaired Action"] = self.repairedProcess  

                    excelData["Process 2 Model Code"] = self.repairedProcess
                    excelData["Process 2 S/N"] = self.repairedProcess
                    excelData["Process 2 ID"] = self.repairedProcess
                    excelData["Process 2 NAME"] = self.repairedProcess
                    excelData["Process 2 Regular/Contractual"] = self.repairedProcess
                    excelData["Process 2 M4x40 Screw"] = self.repairedProcess
                    excelData["Process 2 M4x40 Screw Lot No"] = self.repairedProcess
                    excelData["Process 2 Rod Blk"] = self.repairedProcess
                    excelData["Process 2 Rod Blk Lot No"] = self.repairedProcess
                    excelData["Process 2 Df Blk"] = self.repairedProcess
                    excelData["Process 2 Df Blk Lot No"] = self.repairedProcess
                    excelData["Process 2 Df Ring"] = self.repairedProcess
                    excelData["Process 2 Df Ring Lot No"] = self.repairedProcess
                    excelData["Process 2 Washer"] = self.repairedProcess
                    excelData["Process 2 Washer Lot No"] = self.repairedProcess
                    excelData["Process 2 Lock Nut"] = self.repairedProcess
                    excelData["Process 2 Lock Nut Lot No"] = self.repairedProcess
                    excelData["Process 2 ST"] = self.repairedProcess
                    excelData["Process 2 Actual Time"] = self.repairedProcess
                    excelData["Process 2 NG Cause"] = self.repairedProcess
                    excelData["Process 2 Repaired Action"] = self.repairedProcess

                    excelData["Process 3 Model Code"] = self.ngProcess
                    excelData["Process 3 S/N"] = self.ngProcess
                    excelData["Process 3 ID"] = self.ngProcess
                    excelData["Process 3 NAME"] = self.ngProcess
                    excelData["Process 3 Regular/Contractual"] = self.ngProcess
                    excelData["Process 3 Frame Gasket"] = self.ngProcess
                    excelData["Process 3 Frame Gasket Lot No"] = self.ngProcess
                    excelData["Process 3 Casing Block"] = self.ngProcess
                    excelData["Process 3 Casing Block Lot No"] = self.ngProcess
                    excelData["Process 3 Casing Block Inspection 1 Average Data"] = self.ngProcess
                    excelData["Process 3 Casing Block Inspection 1 Minimum Data"] = self.ngProcess
                    excelData["Process 3 Casing Block Inspection 1 Maximum Data"] = self.ngProcess
                    excelData["Process 3 Casing Gasket"] = self.ngProcess
                    excelData["Process 3 Casing Gasket Lot No"] = self.ngProcess
                    excelData["Process 3 M4x16 Screw 1"] = self.ngProcess
                    excelData["Process 3 M4x16 Screw 1 Lot No"] = self.ngProcess
                    excelData["Process 3 M4x16 Screw 2"] = self.ngProcess
                    excelData["Process 3 M4x16 Screw 2 Lot No"] = self.ngProcess
                    excelData["Process 3 Ball Cushion"] = self.ngProcess
                    excelData["Process 3 Ball Cushion Lot No"] = self.ngProcess
                    excelData["Process 3 Frame Cover"] = self.ngProcess
                    excelData["Process 3 Frame Cover Lot No"] = self.ngProcess
                    excelData["Process 3 Partition Board"] = self.ngProcess
                    excelData["Process 3 Partition Board Lot No"] = self.ngProcess
                    excelData["Process 3 Built In Tube 1"] = self.ngProcess
                    excelData["Process 3 Built In Tube 1 Lot No"] = self.ngProcess
                    excelData["Process 3 Built In Tube 2"] = self.ngProcess
                    excelData["Process 3 Built In Tube 2 Lot No"] = self.ngProcess
                    excelData["Process 3 Head Cover"] = self.ngProcess
                    excelData["Process 3 Head Cover Lot No"] = self.ngProcess
                    excelData["Process 3 Casing Packing"] = self.ngProcess
                    excelData["Process 3 Casing Packing Lot No"] = self.ngProcess
                    excelData["Process 3 M4x12 Screw"] = self.ngProcess
                    excelData["Process 3 M4x12 Screw Lot No"] = self.ngProcess
                    excelData["Process 3 Csb L"] = self.ngProcess
                    excelData["Process 3 Csb L Lot No"] = self.ngProcess
                    excelData["Process 3 Csb R"] = self.ngProcess
                    excelData["Process 3 Csb R Lot No"] = self.ngProcess
                    excelData["Process 3 Head Packing"] = self.ngProcess
                    excelData["Process 3 Head Packing Lot No"] = self.ngProcess
                    excelData["Process 3 ST"] = self.ngProcess
                    excelData["Process 3 Actual Time"] = self.ngProcess
                    excelData["Process 3 NG Cause"] = self.ngProcess
                    excelData["Process 3 Repaired Action"] = self.ngProcess

                    excelData["Process 6 Model Code"] = self.ngProcess
                    excelData["Process 6 S/N"] = self.ngProcess
                    excelData["Process 6 ID"] = self.ngProcess
                    excelData["Process 6 NAME"] = self.ngProcess
                    excelData["Process 6 Regular/Contractual"] = self.ngProcess
                    excelData["Process 6 Vinyl"] = self.ngProcess
                    excelData["Process 6 Vinyl Lot No"] = self.ngProcess
                    excelData["Process 6 ST"] = self.ngProcess
                    excelData["Process 6 Actual Time"] = self.ngProcess
                    excelData["Process 6 NG Cause"] = self.ngProcess
                    excelData["Process 6 Repaired Action"] = self.ngProcess

                elif self.process5Status == "NG":
                    self.repairedProcess = "REPAIRED AT PROCESS4"
                    self.ngProcess = "NG AT PROCESS5"
                    self.process4Row += 1
                    self.process5Row += 1
                    piCompiler.piRow += 1

                    excelData["Process 1 Model Code"] = self.repairedProcess
                    excelData["Process 1 S/N"] = self.repairedProcess
                    excelData["Process 1 ID"] = self.repairedProcess
                    excelData["Process 1 NAME"] = self.repairedProcess
                    excelData["Process 1 Regular/Contractual"] = self.repairedProcess
                    excelData["Process 1 Em2p"] = self.repairedProcess
                    excelData["Process 1 Em2p Lot No"] = self.repairedProcess
                    excelData["Process 1 Em3p"] = self.repairedProcess
                    excelData["Process 1 Em3p Lot No"] = self.repairedProcess
                    excelData["Process 1 Harness"] = self.repairedProcess
                    excelData["Process 1 Harness Lot No"] = self.repairedProcess
                    excelData["Process 1 Frame"] = self.repairedProcess
                    excelData["Process 1 Frame Lot No"] = self.repairedProcess 
                    excelData["Process 1 Bushing"] = self.repairedProcess
                    excelData["Process 1 Bushing Lot No"] = self.repairedProcess
                    excelData["Process 1 ST"] = self.repairedProcess
                    excelData["Process 1 Actual Time"] = self.repairedProcess
                    excelData["Process 1 NG Cause"] = self.repairedProcess
                    excelData["Process 1 Repaired Action"] = self.repairedProcess  

                    excelData["Process 2 Model Code"] = self.repairedProcess
                    excelData["Process 2 S/N"] = self.repairedProcess
                    excelData["Process 2 ID"] = self.repairedProcess
                    excelData["Process 2 NAME"] = self.repairedProcess
                    excelData["Process 2 Regular/Contractual"] = self.repairedProcess
                    excelData["Process 2 M4x40 Screw"] = self.repairedProcess
                    excelData["Process 2 M4x40 Screw Lot No"] = self.repairedProcess
                    excelData["Process 2 Rod Blk"] = self.repairedProcess
                    excelData["Process 2 Rod Blk Lot No"] = self.repairedProcess
                    excelData["Process 2 Df Blk"] = self.repairedProcess
                    excelData["Process 2 Df Blk Lot No"] = self.repairedProcess
                    excelData["Process 2 Df Ring"] = self.repairedProcess
                    excelData["Process 2 Df Ring Lot No"] = self.repairedProcess
                    excelData["Process 2 Washer"] = self.repairedProcess
                    excelData["Process 2 Washer Lot No"] = self.repairedProcess
                    excelData["Process 2 Lock Nut"] = self.repairedProcess
                    excelData["Process 2 Lock Nut Lot No"] = self.repairedProcess
                    excelData["Process 2 ST"] = self.repairedProcess
                    excelData["Process 2 Actual Time"] = self.repairedProcess
                    excelData["Process 2 NG Cause"] = self.repairedProcess
                    excelData["Process 2 Repaired Action"] = self.repairedProcess

                    excelData["Process 3 Model Code"] = self.ngProcess
                    excelData["Process 3 S/N"] = self.ngProcess
                    excelData["Process 3 ID"] = self.ngProcess
                    excelData["Process 3 NAME"] = self.ngProcess
                    excelData["Process 3 Regular/Contractual"] = self.ngProcess
                    excelData["Process 3 Frame Gasket"] = self.ngProcess
                    excelData["Process 3 Frame Gasket Lot No"] = self.ngProcess
                    excelData["Process 3 Casing Block"] = self.ngProcess
                    excelData["Process 3 Casing Block Lot No"] = self.ngProcess
                    excelData["Process 3 Casing Block Inspection 1 Average Data"] = self.ngProcess
                    excelData["Process 3 Casing Block Inspection 1 Minimum Data"] = self.ngProcess
                    excelData["Process 3 Casing Block Inspection 1 Maximum Data"] = self.ngProcess
                    excelData["Process 3 Casing Gasket"] = self.ngProcess
                    excelData["Process 3 Casing Gasket Lot No"] = self.ngProcess
                    excelData["Process 3 M4x16 Screw 1"] = self.ngProcess
                    excelData["Process 3 M4x16 Screw 1 Lot No"] = self.ngProcess
                    excelData["Process 3 M4x16 Screw 2"] = self.ngProcess
                    excelData["Process 3 M4x16 Screw 2 Lot No"] = self.ngProcess
                    excelData["Process 3 Ball Cushion"] = self.ngProcess
                    excelData["Process 3 Ball Cushion Lot No"] = self.ngProcess
                    excelData["Process 3 Frame Cover"] = self.ngProcess
                    excelData["Process 3 Frame Cover Lot No"] = self.ngProcess
                    excelData["Process 3 Partition Board"] = self.ngProcess
                    excelData["Process 3 Partition Board Lot No"] = self.ngProcess
                    excelData["Process 3 Built In Tube 1"] = self.ngProcess
                    excelData["Process 3 Built In Tube 1 Lot No"] = self.ngProcess
                    excelData["Process 3 Built In Tube 2"] = self.ngProcess
                    excelData["Process 3 Built In Tube 2 Lot No"] = self.ngProcess
                    excelData["Process 3 Head Cover"] = self.ngProcess
                    excelData["Process 3 Head Cover Lot No"] = self.ngProcess
                    excelData["Process 3 Casing Packing"] = self.ngProcess
                    excelData["Process 3 Casing Packing Lot No"] = self.ngProcess
                    excelData["Process 3 M4x12 Screw"] = self.ngProcess
                    excelData["Process 3 M4x12 Screw Lot No"] = self.ngProcess
                    excelData["Process 3 Csb L"] = self.ngProcess
                    excelData["Process 3 Csb L Lot No"] = self.ngProcess
                    excelData["Process 3 Csb R"] = self.ngProcess
                    excelData["Process 3 Csb R Lot No"] = self.ngProcess
                    excelData["Process 3 Head Packing"] = self.ngProcess
                    excelData["Process 3 Head Packing Lot No"] = self.ngProcess
                    excelData["Process 3 ST"] = self.ngProcess
                    excelData["Process 3 Actual Time"] = self.ngProcess
                    excelData["Process 3 NG Cause"] = self.ngProcess
                    excelData["Process 3 Repaired Action"] = self.ngProcess

                    excelData["Process 6 Model Code"] = self.ngProcess
                    excelData["Process 6 S/N"] = self.ngProcess
                    excelData["Process 6 ID"] = self.ngProcess
                    excelData["Process 6 NAME"] = self.ngProcess
                    excelData["Process 6 Regular/Contractual"] = self.ngProcess
                    excelData["Process 6 Vinyl"] = self.ngProcess
                    excelData["Process 6 Vinyl Lot No"] = self.ngProcess
                    excelData["Process 6 ST"] = self.ngProcess
                    excelData["Process 6 Actual Time"] = self.ngProcess
                    excelData["Process 6 NG Cause"] = self.ngProcess
                    excelData["Process 6 Repaired Action"] = self.ngProcess

                elif self.process6Status == "NG":
                    self.repairedProcess = "REPAIRED AT PROCESS4"
                    self.process4Row += 1
                    self.process5Row += 1
                    self.process6Row += 1
                    piCompiler.piRow += 1

                    excelData["Process 1 Model Code"] = self.repairedProcess
                    excelData["Process 1 S/N"] = self.repairedProcess
                    excelData["Process 1 ID"] = self.repairedProcess
                    excelData["Process 1 NAME"] = self.repairedProcess
                    excelData["Process 1 Regular/Contractual"] = self.repairedProcess
                    excelData["Process 1 Em2p"] = self.repairedProcess
                    excelData["Process 1 Em2p Lot No"] = self.repairedProcess
                    excelData["Process 1 Em3p"] = self.repairedProcess
                    excelData["Process 1 Em3p Lot No"] = self.repairedProcess
                    excelData["Process 1 Harness"] = self.repairedProcess
                    excelData["Process 1 Harness Lot No"] = self.repairedProcess
                    excelData["Process 1 Frame"] = self.repairedProcess
                    excelData["Process 1 Frame Lot No"] = self.repairedProcess 
                    excelData["Process 1 Bushing"] = self.repairedProcess
                    excelData["Process 1 Bushing Lot No"] = self.repairedProcess
                    excelData["Process 1 ST"] = self.repairedProcess
                    excelData["Process 1 Actual Time"] = self.repairedProcess
                    excelData["Process 1 NG Cause"] = self.repairedProcess
                    excelData["Process 1 Repaired Action"] = self.repairedProcess  

                    excelData["Process 2 Model Code"] = self.repairedProcess
                    excelData["Process 2 S/N"] = self.repairedProcess
                    excelData["Process 2 ID"] = self.repairedProcess
                    excelData["Process 2 NAME"] = self.repairedProcess
                    excelData["Process 2 Regular/Contractual"] = self.repairedProcess
                    excelData["Process 2 M4x40 Screw"] = self.repairedProcess
                    excelData["Process 2 M4x40 Screw Lot No"] = self.repairedProcess
                    excelData["Process 2 Rod Blk"] = self.repairedProcess
                    excelData["Process 2 Rod Blk Lot No"] = self.repairedProcess
                    excelData["Process 2 Df Blk"] = self.repairedProcess
                    excelData["Process 2 Df Blk Lot No"] = self.repairedProcess
                    excelData["Process 2 Df Ring"] = self.repairedProcess
                    excelData["Process 2 Df Ring Lot No"] = self.repairedProcess
                    excelData["Process 2 Washer"] = self.repairedProcess
                    excelData["Process 2 Washer Lot No"] = self.repairedProcess
                    excelData["Process 2 Lock Nut"] = self.repairedProcess
                    excelData["Process 2 Lock Nut Lot No"] = self.repairedProcess
                    excelData["Process 2 ST"] = self.repairedProcess
                    excelData["Process 2 Actual Time"] = self.repairedProcess
                    excelData["Process 2 NG Cause"] = self.repairedProcess
                    excelData["Process 2 Repaired Action"] = self.repairedProcess

                    excelData["Process 3 Model Code"] = self.ngProcess
                    excelData["Process 3 S/N"] = self.ngProcess
                    excelData["Process 3 ID"] = self.ngProcess
                    excelData["Process 3 NAME"] = self.ngProcess
                    excelData["Process 3 Regular/Contractual"] = self.ngProcess
                    excelData["Process 3 Frame Gasket"] = self.ngProcess
                    excelData["Process 3 Frame Gasket Lot No"] = self.ngProcess
                    excelData["Process 3 Casing Block"] = self.ngProcess
                    excelData["Process 3 Casing Block Lot No"] = self.ngProcess
                    excelData["Process 3 Casing Block Inspection 1 Average Data"] = self.ngProcess
                    excelData["Process 3 Casing Block Inspection 1 Minimum Data"] = self.ngProcess
                    excelData["Process 3 Casing Block Inspection 1 Maximum Data"] = self.ngProcess
                    excelData["Process 3 Casing Gasket"] = self.ngProcess
                    excelData["Process 3 Casing Gasket Lot No"] = self.ngProcess
                    excelData["Process 3 M4x16 Screw 1"] = self.ngProcess
                    excelData["Process 3 M4x16 Screw 1 Lot No"] = self.ngProcess
                    excelData["Process 3 M4x16 Screw 2"] = self.ngProcess
                    excelData["Process 3 M4x16 Screw 2 Lot No"] = self.ngProcess
                    excelData["Process 3 Ball Cushion"] = self.ngProcess
                    excelData["Process 3 Ball Cushion Lot No"] = self.ngProcess
                    excelData["Process 3 Frame Cover"] = self.ngProcess
                    excelData["Process 3 Frame Cover Lot No"] = self.ngProcess
                    excelData["Process 3 Partition Board"] = self.ngProcess
                    excelData["Process 3 Partition Board Lot No"] = self.ngProcess
                    excelData["Process 3 Built In Tube 1"] = self.ngProcess
                    excelData["Process 3 Built In Tube 1 Lot No"] = self.ngProcess
                    excelData["Process 3 Built In Tube 2"] = self.ngProcess
                    excelData["Process 3 Built In Tube 2 Lot No"] = self.ngProcess
                    excelData["Process 3 Head Cover"] = self.ngProcess
                    excelData["Process 3 Head Cover Lot No"] = self.ngProcess
                    excelData["Process 3 Casing Packing"] = self.ngProcess
                    excelData["Process 3 Casing Packing Lot No"] = self.ngProcess
                    excelData["Process 3 M4x12 Screw"] = self.ngProcess
                    excelData["Process 3 M4x12 Screw Lot No"] = self.ngProcess
                    excelData["Process 3 Csb L"] = self.ngProcess
                    excelData["Process 3 Csb L Lot No"] = self.ngProcess
                    excelData["Process 3 Csb R"] = self.ngProcess
                    excelData["Process 3 Csb R Lot No"] = self.ngProcess
                    excelData["Process 3 Head Packing"] = self.ngProcess
                    excelData["Process 3 Head Packing Lot No"] = self.ngProcess
                    excelData["Process 3 ST"] = self.ngProcess
                    excelData["Process 3 Actual Time"] = self.ngProcess
                    excelData["Process 3 NG Cause"] = self.ngProcess
                    excelData["Process 3 Repaired Action"] = self.ngProcess

            elif self.process5Status == "Repaired":
                if self.process6Status == "NG":
                    self.repairedProcess = "REPAIRED AT PROCESS5"
                    self.process5Row += 1
                    self.process6Row += 1
                    piCompiler.piRow += 1

                    excelData["Process 1 Model Code"] = self.repairedProcess
                    excelData["Process 1 S/N"] = self.repairedProcess
                    excelData["Process 1 ID"] = self.repairedProcess
                    excelData["Process 1 NAME"] = self.repairedProcess
                    excelData["Process 1 Regular/Contractual"] = self.repairedProcess
                    excelData["Process 1 Em2p"] = self.repairedProcess
                    excelData["Process 1 Em2p Lot No"] = self.repairedProcess
                    excelData["Process 1 Em3p"] = self.repairedProcess
                    excelData["Process 1 Em3p Lot No"] = self.repairedProcess
                    excelData["Process 1 Harness"] = self.repairedProcess
                    excelData["Process 1 Harness Lot No"] = self.repairedProcess
                    excelData["Process 1 Frame"] = self.repairedProcess
                    excelData["Process 1 Frame Lot No"] = self.repairedProcess 
                    excelData["Process 1 Bushing"] = self.repairedProcess
                    excelData["Process 1 Bushing Lot No"] = self.repairedProcess
                    excelData["Process 1 ST"] = self.repairedProcess
                    excelData["Process 1 Actual Time"] = self.repairedProcess
                    excelData["Process 1 NG Cause"] = self.repairedProcess
                    excelData["Process 1 Repaired Action"] = self.repairedProcess  

                    excelData["Process 2 Model Code"] = self.repairedProcess
                    excelData["Process 2 S/N"] = self.repairedProcess
                    excelData["Process 2 ID"] = self.repairedProcess
                    excelData["Process 2 NAME"] = self.repairedProcess
                    excelData["Process 2 Regular/Contractual"] = self.repairedProcess
                    excelData["Process 2 M4x40 Screw"] = self.repairedProcess
                    excelData["Process 2 M4x40 Screw Lot No"] = self.repairedProcess
                    excelData["Process 2 Rod Blk"] = self.repairedProcess
                    excelData["Process 2 Rod Blk Lot No"] = self.repairedProcess
                    excelData["Process 2 Df Blk"] = self.repairedProcess
                    excelData["Process 2 Df Blk Lot No"] = self.repairedProcess
                    excelData["Process 2 Df Ring"] = self.repairedProcess
                    excelData["Process 2 Df Ring Lot No"] = self.repairedProcess
                    excelData["Process 2 Washer"] = self.repairedProcess
                    excelData["Process 2 Washer Lot No"] = self.repairedProcess
                    excelData["Process 2 Lock Nut"] = self.repairedProcess
                    excelData["Process 2 Lock Nut Lot No"] = self.repairedProcess
                    excelData["Process 2 ST"] = self.repairedProcess
                    excelData["Process 2 Actual Time"] = self.repairedProcess
                    excelData["Process 2 NG Cause"] = self.repairedProcess
                    excelData["Process 2 Repaired Action"] = self.repairedProcess

                    excelData["Process 3 Model Code"] = self.ngProcess
                    excelData["Process 3 S/N"] = self.ngProcess
                    excelData["Process 3 ID"] = self.ngProcess
                    excelData["Process 3 NAME"] = self.ngProcess
                    excelData["Process 3 Regular/Contractual"] = self.ngProcess
                    excelData["Process 3 Frame Gasket"] = self.ngProcess
                    excelData["Process 3 Frame Gasket Lot No"] = self.ngProcess
                    excelData["Process 3 Casing Block"] = self.ngProcess
                    excelData["Process 3 Casing Block Lot No"] = self.ngProcess
                    excelData["Process 3 Casing Block Inspection 1 Average Data"] = self.ngProcess
                    excelData["Process 3 Casing Block Inspection 1 Minimum Data"] = self.ngProcess
                    excelData["Process 3 Casing Block Inspection 1 Maximum Data"] = self.ngProcess
                    excelData["Process 3 Casing Gasket"] = self.ngProcess
                    excelData["Process 3 Casing Gasket Lot No"] = self.ngProcess
                    excelData["Process 3 M4x16 Screw 1"] = self.ngProcess
                    excelData["Process 3 M4x16 Screw 1 Lot No"] = self.ngProcess
                    excelData["Process 3 M4x16 Screw 2"] = self.ngProcess
                    excelData["Process 3 M4x16 Screw 2 Lot No"] = self.ngProcess
                    excelData["Process 3 Ball Cushion"] = self.ngProcess
                    excelData["Process 3 Ball Cushion Lot No"] = self.ngProcess
                    excelData["Process 3 Frame Cover"] = self.ngProcess
                    excelData["Process 3 Frame Cover Lot No"] = self.ngProcess
                    excelData["Process 3 Partition Board"] = self.ngProcess
                    excelData["Process 3 Partition Board Lot No"] = self.ngProcess
                    excelData["Process 3 Built In Tube 1"] = self.ngProcess
                    excelData["Process 3 Built In Tube 1 Lot No"] = self.ngProcess
                    excelData["Process 3 Built In Tube 2"] = self.ngProcess
                    excelData["Process 3 Built In Tube 2 Lot No"] = self.ngProcess
                    excelData["Process 3 Head Cover"] = self.ngProcess
                    excelData["Process 3 Head Cover Lot No"] = self.ngProcess
                    excelData["Process 3 Casing Packing"] = self.ngProcess
                    excelData["Process 3 Casing Packing Lot No"] = self.ngProcess
                    excelData["Process 3 M4x12 Screw"] = self.ngProcess
                    excelData["Process 3 M4x12 Screw Lot No"] = self.ngProcess
                    excelData["Process 3 Csb L"] = self.ngProcess
                    excelData["Process 3 Csb L Lot No"] = self.ngProcess
                    excelData["Process 3 Csb R"] = self.ngProcess
                    excelData["Process 3 Csb R Lot No"] = self.ngProcess
                    excelData["Process 3 Head Packing"] = self.ngProcess
                    excelData["Process 3 Head Packing Lot No"] = self.ngProcess
                    excelData["Process 3 ST"] = self.ngProcess
                    excelData["Process 3 Actual Time"] = self.ngProcess
                    excelData["Process 3 NG Cause"] = self.ngProcess
                    excelData["Process 3 Repaired Action"] = self.ngProcess

                    excelData["Process 4 Model Code"] = self.ngProcess
                    excelData["Process 4 S/N"] = self.ngProcess
                    excelData["Process 4 ID"] = self.ngProcess
                    excelData["Process 4 NAME"] = self.ngProcess
                    excelData["Process 4 Regular/Contractual"] = self.ngProcess
                    excelData["Process 4 Tank"] = self.ngProcess
                    excelData["Process 4 Tank Lot No"] = self.ngProcess
                    excelData["Process 4 Upper Housing"] = self.ngProcess
                    excelData["Process 4 Upper Housing Lot No"] = self.ngProcess
                    excelData["Process 4 Cord Hook" ] = self.ngProcess
                    excelData["Process 4 Cord Hook Lot No"] = self.ngProcess
                    excelData["Process 4 M4x16 Screw"] = self.ngProcess
                    excelData["Process 4 M4x16 Screw Lot No"] = self.ngProcess
                    excelData["Process 4 Tank Gasket"] = self.ngProcess
                    excelData["Process 4 Tank Gasket Lot No"] = self.ngProcess
                    excelData["Process 4 Tank Cover"] = self.ngProcess
                    excelData["Process 4 Tank Cover Lot No"] = self.ngProcess
                    excelData["Process 4 Housing Gasket"] = self.ngProcess
                    excelData["Process 4 Housing Gasket Lot No"] = self.ngProcess
                    excelData["Process 4 M4x40 Screw"] = self.ngProcess
                    excelData["Process 4 M4x40 Screw Lot No"] = self.ngProcess
                    excelData["Process 4 PartitionGasket"] = self.ngProcess
                    excelData["Process 4 PartitionGasket Lot No"] = self.ngProcess
                    excelData["Process 4 M4x12 Screw"] = self.ngProcess
                    excelData["Process 4 M4x12 Screw Lot No"] = self.ngProcess
                    excelData["Process 4 Muffler"] = self.ngProcess
                    excelData["Process 4 Muffler Lot No"] = self.ngProcess
                    excelData["Process 4 Muffler Gasket"] = self.ngProcess
                    excelData["Process 4 Muffler Gasket Lot No"] = self.ngProcess
                    excelData["Process 4 VCR"] = self.ngProcess
                    excelData["Process 4 VCR Lot No"] = self.ngProcess
                    excelData["Process 4 ST"] = self.ngProcess
                    excelData["Process 4 Actual Time"] = self.ngProcess
                    excelData["Process 4 NG Cause"] = self.ngProcess
                    excelData["Process 4 Repaired Action"] = self.ngProcess
                
            self.process1Status = ""
            self.process2Status = ""
            self.process3Status = ""
            self.process4Status = ""
            self.process5Status = ""
            self.process6Status = ""

        if self.process1Status == "NG":
            self.ngProcess = "NG AT PROCESS1"
            self.process1Row += 1

            excelData["DATE"] = self.ngProcess
            excelData["TIME"] = self.ngProcess
            excelData["MODEL CODE"] = self.ngProcess
            excelData["PROCESS S/N"] = self.ngProcess
            excelData["S/N"] = self.ngProcess
            excelData["PASS/NG"] = self.ngProcess
            excelData["VOLTAGE MAX (V)"] = self.ngProcess
            excelData["WATTAGE MAX (W)"] = self.ngProcess
            excelData["CLOSED PRESSURE_MAX (kPa)"] = self.ngProcess
            excelData["VOLTAGE Middle (V)"] = self.ngProcess
            excelData["WATTAGE Middle (W)"] = self.ngProcess
            excelData["AMPERAGE Middle (A)"] = self.ngProcess
            excelData["CLOSED PRESSURE Middle (kPa)"] = self.ngProcess
            excelData["dB(A) 1"] = self.ngProcess
            excelData["dB(A) 2"] = self.ngProcess
            excelData["dB(A) 3"] = self.ngProcess
            excelData["VOLTAGE MIN (V)"] = self.ngProcess
            excelData["WATTAGE MIN (W)"] = self.ngProcess
            excelData["CLOSED PRESSURE MIN (kPa)"] = self.ngProcess

            excelData["Process 2 Model Code"] = self.ngProcess
            excelData["Process 2 S/N"] = self.ngProcess
            excelData["Process 2 ID"] = self.ngProcess
            excelData["Process 2 NAME"] = self.ngProcess
            excelData["Process 2 Regular/Contractual"] = self.ngProcess
            excelData["Process 2 M4x40 Screw"] = self.ngProcess
            excelData["Process 2 M4x40 Screw Lot No"] = self.ngProcess
            excelData["Process 2 Rod Blk"] = self.ngProcess
            excelData["Process 2 Rod Blk Lot No"] = self.ngProcess
            excelData["Process 2 Df Blk"] = self.ngProcess
            excelData["Process 2 Df Blk Lot No"] = self.ngProcess
            excelData["Process 2 Df Ring"] = self.ngProcess
            excelData["Process 2 Df Ring Lot No"] = self.ngProcess
            excelData["Process 2 Washer"] = self.ngProcess
            excelData["Process 2 Washer Lot No"] = self.ngProcess
            excelData["Process 2 Lock Nut"] = self.ngProcess
            excelData["Process 2 Lock Nut Lot No"] = self.ngProcess
            excelData["Process 2 ST"] = self.ngProcess
            excelData["Process 2 Actual Time"] = self.ngProcess
            excelData["Process 2 NG Cause"] = self.ngProcess
            excelData["Process 2 Repaired Action"] = self.ngProcess

            excelData["Process 3 Model Code"] = self.ngProcess
            excelData["Process 3 S/N"] = self.ngProcess
            excelData["Process 3 ID"] = self.ngProcess
            excelData["Process 3 NAME"] = self.ngProcess
            excelData["Process 3 Regular/Contractual"] = self.ngProcess
            excelData["Process 3 Frame Gasket"] = self.ngProcess
            excelData["Process 3 Frame Gasket Lot No"] = self.ngProcess
            excelData["Process 3 Casing Block"] = self.ngProcess
            excelData["Process 3 Casing Block Lot No"] = self.ngProcess
            excelData["Process 3 Casing Block Inspection 1 Average Data"] = self.ngProcess
            excelData["Process 3 Casing Block Inspection 1 Minimum Data"] = self.ngProcess
            excelData["Process 3 Casing Block Inspection 1 Maximum Data"] = self.ngProcess
            excelData["Process 3 Casing Gasket"] = self.ngProcess
            excelData["Process 3 Casing Gasket Lot No"] = self.ngProcess
            excelData["Process 3 M4x16 Screw 1"] = self.ngProcess
            excelData["Process 3 M4x16 Screw 1 Lot No"] = self.ngProcess
            excelData["Process 3 M4x16 Screw 2"] = self.ngProcess
            excelData["Process 3 M4x16 Screw 2 Lot No"] = self.ngProcess
            excelData["Process 3 Ball Cushion"] = self.ngProcess
            excelData["Process 3 Ball Cushion Lot No"] = self.ngProcess
            excelData["Process 3 Frame Cover"] = self.ngProcess
            excelData["Process 3 Frame Cover Lot No"] = self.ngProcess
            excelData["Process 3 Partition Board"] = self.ngProcess
            excelData["Process 3 Partition Board Lot No"] = self.ngProcess
            excelData["Process 3 Built In Tube 1"] = self.ngProcess
            excelData["Process 3 Built In Tube 1 Lot No"] = self.ngProcess
            excelData["Process 3 Built In Tube 2"] = self.ngProcess
            excelData["Process 3 Built In Tube 2 Lot No"] = self.ngProcess
            excelData["Process 3 Head Cover"] = self.ngProcess
            excelData["Process 3 Head Cover Lot No"] = self.ngProcess
            excelData["Process 3 Casing Packing"] = self.ngProcess
            excelData["Process 3 Casing Packing Lot No"] = self.ngProcess
            excelData["Process 3 M4x12 Screw"] = self.ngProcess
            excelData["Process 3 M4x12 Screw Lot No"] = self.ngProcess
            excelData["Process 3 Csb L"] = self.ngProcess
            excelData["Process 3 Csb L Lot No"] = self.ngProcess
            excelData["Process 3 Csb R"] = self.ngProcess
            excelData["Process 3 Csb R Lot No"] = self.ngProcess
            excelData["Process 3 Head Packing"] = self.ngProcess
            excelData["Process 3 Head Packing Lot No"] = self.ngProcess
            excelData["Process 3 ST"] = self.ngProcess
            excelData["Process 3 Actual Time"] = self.ngProcess
            excelData["Process 3 NG Cause"] = self.ngProcess
            excelData["Process 3 Repaired Action"] = self.ngProcess

            excelData["Process 4 Model Code"] = self.ngProcess
            excelData["Process 4 S/N"] = self.ngProcess
            excelData["Process 4 ID"] = self.ngProcess
            excelData["Process 4 NAME"] = self.ngProcess
            excelData["Process 4 Regular/Contractual"] = self.ngProcess
            excelData["Process 4 Tank"] = self.ngProcess
            excelData["Process 4 Tank Lot No"] = self.ngProcess
            excelData["Process 4 Upper Housing"] = self.ngProcess
            excelData["Process 4 Upper Housing Lot No"] = self.ngProcess
            excelData["Process 4 Cord Hook" ] = self.ngProcess
            excelData["Process 4 Cord Hook Lot No"] = self.ngProcess
            excelData["Process 4 M4x16 Screw"] = self.ngProcess
            excelData["Process 4 M4x16 Screw Lot No"] = self.ngProcess
            excelData["Process 4 Tank Gasket"] = self.ngProcess
            excelData["Process 4 Tank Gasket Lot No"] = self.ngProcess
            excelData["Process 4 Tank Cover"] = self.ngProcess
            excelData["Process 4 Tank Cover Lot No"] = self.ngProcess
            excelData["Process 4 Housing Gasket"] = self.ngProcess
            excelData["Process 4 Housing Gasket Lot No"] = self.ngProcess
            excelData["Process 4 M4x40 Screw"] = self.ngProcess
            excelData["Process 4 M4x40 Screw Lot No"] = self.ngProcess
            excelData["Process 4 PartitionGasket"] = self.ngProcess
            excelData["Process 4 PartitionGasket Lot No"] = self.ngProcess
            excelData["Process 4 M4x12 Screw"] = self.ngProcess
            excelData["Process 4 M4x12 Screw Lot No"] = self.ngProcess
            excelData["Process 4 Muffler"] = self.ngProcess
            excelData["Process 4 Muffler Lot No"] = self.ngProcess
            excelData["Process 4 Muffler Gasket"] = self.ngProcess
            excelData["Process 4 Muffler Gasket Lot No"] = self.ngProcess
            excelData["Process 4 VCR"] = self.ngProcess
            excelData["Process 4 VCR Lot No"] = self.ngProcess
            excelData["Process 4 ST"] = self.ngProcess
            excelData["Process 4 Actual Time"] = self.ngProcess
            excelData["Process 4 NG Cause"] = self.ngProcess
            excelData["Process 4 Repaired Action"] = self.ngProcess

            excelData["Process 5 Model Code"] = self.ngProcess
            excelData["Process 5 S/N"] = self.ngProcess
            excelData["Process 5 ID"] = self.ngProcess
            excelData["Process 5 NAME"] = self.ngProcess
            excelData["Process 5 Regular/Contractual"] = self.ngProcess
            excelData["Process 5 Rating Label"] = self.ngProcess
            excelData["Process 5 Rating Label Lot No"] = self.ngProcess
            excelData["Process 5 ST"] = self.ngProcess
            excelData["Process 5 Actual Time"] = self.ngProcess
            excelData["Process 5 NG Cause"] = self.ngProcess
            excelData["Process 5 Repaired Action"] = self.ngProcess

            excelData["Process 6 Model Code"] = self.ngProcess
            excelData["Process 6 S/N"] = self.ngProcess
            excelData["Process 6 ID"] = self.ngProcess
            excelData["Process 6 NAME"] = self.ngProcess
            excelData["Process 6 Regular/Contractual"] = self.ngProcess
            excelData["Process 6 Vinyl"] = self.ngProcess
            excelData["Process 6 Vinyl Lot No"] = self.ngProcess
            excelData["Process 6 ST"] = self.ngProcess
            excelData["Process 6 Actual Time"] = self.ngProcess
            excelData["Process 6 NG Cause"] = self.ngProcess
            excelData["Process 6 Repaired Action"] = self.ngProcess
                
        if self.process2Status == "NG":
            print("ng")
            self.ngProcess = "NG AT PROCESS2"
            self.process2Row += 1

            excelData["DATE"] = self.ngProcess
            excelData["TIME"] = self.ngProcess
            excelData["MODEL CODE"] = self.ngProcess
            excelData["PROCESS S/N"] = self.ngProcess
            excelData["S/N"] = self.ngProcess
            excelData["PASS/NG"] = self.ngProcess
            excelData["VOLTAGE MAX (V)"] = self.ngProcess
            excelData["WATTAGE MAX (W)"] = self.ngProcess
            excelData["CLOSED PRESSURE_MAX (kPa)"] = self.ngProcess
            excelData["VOLTAGE Middle (V)"] = self.ngProcess
            excelData["WATTAGE Middle (W)"] = self.ngProcess
            excelData["AMPERAGE Middle (A)"] = self.ngProcess
            excelData["CLOSED PRESSURE Middle (kPa)"] = self.ngProcess
            excelData["dB(A) 1"] = self.ngProcess
            excelData["dB(A) 2"] = self.ngProcess
            excelData["dB(A) 3"] = self.ngProcess
            excelData["VOLTAGE MIN (V)"] = self.ngProcess
            excelData["WATTAGE MIN (W)"] = self.ngProcess
            excelData["CLOSED PRESSURE MIN (kPa)"] = self.ngProcess
    
            excelData["Process 3 Model Code"] = self.ngProcess
            excelData["Process 3 S/N"] = self.ngProcess
            excelData["Process 3 ID"] = self.ngProcess
            excelData["Process 3 NAME"] = self.ngProcess
            excelData["Process 3 Regular/Contractual"] = self.ngProcess
            excelData["Process 3 Frame Gasket"] = self.ngProcess
            excelData["Process 3 Frame Gasket Lot No"] = self.ngProcess
            excelData["Process 3 Casing Block"] = self.ngProcess
            excelData["Process 3 Casing Block Lot No"] = self.ngProcess
            excelData["Process 3 Casing Block Inspection 1 Average Data"] = self.ngProcess
            excelData["Process 3 Casing Block Inspection 1 Minimum Data"] = self.ngProcess
            excelData["Process 3 Casing Block Inspection 1 Maximum Data"] = self.ngProcess
            excelData["Process 3 Casing Gasket"] = self.ngProcess
            excelData["Process 3 Casing Gasket Lot No"] = self.ngProcess
            excelData["Process 3 M4x16 Screw 1"] = self.ngProcess
            excelData["Process 3 M4x16 Screw 1 Lot No"] = self.ngProcess
            excelData["Process 3 M4x16 Screw 2"] = self.ngProcess
            excelData["Process 3 M4x16 Screw 2 Lot No"] = self.ngProcess
            excelData["Process 3 Ball Cushion"] = self.ngProcess
            excelData["Process 3 Ball Cushion Lot No"] = self.ngProcess
            excelData["Process 3 Frame Cover"] = self.ngProcess
            excelData["Process 3 Frame Cover Lot No"] = self.ngProcess
            excelData["Process 3 Partition Board"] = self.ngProcess
            excelData["Process 3 Partition Board Lot No"] = self.ngProcess
            excelData["Process 3 Built In Tube 1"] = self.ngProcess
            excelData["Process 3 Built In Tube 1 Lot No"] = self.ngProcess
            excelData["Process 3 Built In Tube 2"] = self.ngProcess
            excelData["Process 3 Built In Tube 2 Lot No"] = self.ngProcess
            excelData["Process 3 Head Cover"] = self.ngProcess
            excelData["Process 3 Head Cover Lot No"] = self.ngProcess
            excelData["Process 3 Casing Packing"] = self.ngProcess
            excelData["Process 3 Casing Packing Lot No"] = self.ngProcess
            excelData["Process 3 M4x12 Screw"] = self.ngProcess
            excelData["Process 3 M4x12 Screw Lot No"] = self.ngProcess
            excelData["Process 3 Csb L"] = self.ngProcess
            excelData["Process 3 Csb L Lot No"] = self.ngProcess
            excelData["Process 3 Csb R"] = self.ngProcess
            excelData["Process 3 Csb R Lot No"] = self.ngProcess
            excelData["Process 3 Head Packing"] = self.ngProcess
            excelData["Process 3 Head Packing Lot No"] = self.ngProcess
            excelData["Process 3 ST"] = self.ngProcess
            excelData["Process 3 Actual Time"] = self.ngProcess
            excelData["Process 3 NG Cause"] = self.ngProcess
            excelData["Process 3 Repaired Action"] = self.ngProcess

            excelData["Process 4 Model Code"] = self.ngProcess
            excelData["Process 4 S/N"] = self.ngProcess
            excelData["Process 4 ID"] = self.ngProcess
            excelData["Process 4 NAME"] = self.ngProcess
            excelData["Process 4 Regular/Contractual"] = self.ngProcess
            excelData["Process 4 Tank"] = self.ngProcess
            excelData["Process 4 Tank Lot No"] = self.ngProcess
            excelData["Process 4 Upper Housing"] = self.ngProcess
            excelData["Process 4 Upper Housing Lot No"] = self.ngProcess
            excelData["Process 4 Cord Hook" ] = self.ngProcess
            excelData["Process 4 Cord Hook Lot No"] = self.ngProcess
            excelData["Process 4 M4x16 Screw"] = self.ngProcess
            excelData["Process 4 M4x16 Screw Lot No"] = self.ngProcess
            excelData["Process 4 Tank Gasket"] = self.ngProcess
            excelData["Process 4 Tank Gasket Lot No"] = self.ngProcess
            excelData["Process 4 Tank Cover"] = self.ngProcess
            excelData["Process 4 Tank Cover Lot No"] = self.ngProcess
            excelData["Process 4 Housing Gasket"] = self.ngProcess
            excelData["Process 4 Housing Gasket Lot No"] = self.ngProcess
            excelData["Process 4 M4x40 Screw"] = self.ngProcess
            excelData["Process 4 M4x40 Screw Lot No"] = self.ngProcess
            excelData["Process 4 PartitionGasket"] = self.ngProcess
            excelData["Process 4 PartitionGasket Lot No"] = self.ngProcess
            excelData["Process 4 M4x12 Screw"] = self.ngProcess
            excelData["Process 4 M4x12 Screw Lot No"] = self.ngProcess
            excelData["Process 4 Muffler"] = self.ngProcess
            excelData["Process 4 Muffler Lot No"] = self.ngProcess
            excelData["Process 4 Muffler Gasket"] = self.ngProcess
            excelData["Process 4 Muffler Gasket Lot No"] = self.ngProcess
            excelData["Process 4 VCR"] = self.ngProcess
            excelData["Process 4 VCR Lot No"] = self.ngProcess
            excelData["Process 4 ST"] = self.ngProcess
            excelData["Process 4 Actual Time"] = self.ngProcess
            excelData["Process 4 NG Cause"] = self.ngProcess
            excelData["Process 4 Repaired Action"] = self.ngProcess

            excelData["Process 5 Model Code"] = self.ngProcess
            excelData["Process 5 S/N"] = self.ngProcess
            excelData["Process 5 ID"] = self.ngProcess
            excelData["Process 5 NAME"] = self.ngProcess
            excelData["Process 5 Regular/Contractual"] = self.ngProcess
            excelData["Process 5 Rating Label"] = self.ngProcess
            excelData["Process 5 Rating Label Lot No"] = self.ngProcess
            excelData["Process 5 ST"] = self.ngProcess
            excelData["Process 5 Actual Time"] = self.ngProcess
            excelData["Process 5 NG Cause"] = self.ngProcess
            excelData["Process 5 Repaired Action"] = self.ngProcess

            excelData["Process 6 Model Code"] = self.ngProcess
            excelData["Process 6 S/N"] = self.ngProcess
            excelData["Process 6 ID"] = self.ngProcess
            excelData["Process 6 NAME"] = self.ngProcess
            excelData["Process 6 Regular/Contractual"] = self.ngProcess
            excelData["Process 6 Vinyl"] = self.ngProcess
            excelData["Process 6 Vinyl Lot No"] = self.ngProcess
            excelData["Process 6 ST"] = self.ngProcess
            excelData["Process 6 Actual Time"] = self.ngProcess
            excelData["Process 6 NG Cause"] = self.ngProcess
            excelData["Process 6 Repaired Action"] = self.ngProcess

        if self.process3Status == "NG":
            self.ngProcess = "NG AT PROCESS3"
            self.process3Row += 1

            excelData["DATE"] = self.ngProcess
            excelData["TIME"] = self.ngProcess
            excelData["MODEL CODE"] = self.ngProcess
            excelData["PROCESS S/N"] = self.ngProcess
            excelData["S/N"] = self.ngProcess
            excelData["PASS/NG"] = self.ngProcess
            excelData["VOLTAGE MAX (V)"] = self.ngProcess
            excelData["WATTAGE MAX (W)"] = self.ngProcess
            excelData["CLOSED PRESSURE_MAX (kPa)"] = self.ngProcess
            excelData["VOLTAGE Middle (V)"] = self.ngProcess
            excelData["WATTAGE Middle (W)"] = self.ngProcess
            excelData["AMPERAGE Middle (A)"] = self.ngProcess
            excelData["CLOSED PRESSURE Middle (kPa)"] = self.ngProcess
            excelData["dB(A) 1"] = self.ngProcess
            excelData["dB(A) 2"] = self.ngProcess
            excelData["dB(A) 3"] = self.ngProcess
            excelData["VOLTAGE MIN (V)"] = self.ngProcess
            excelData["WATTAGE MIN (W)"] = self.ngProcess
            excelData["CLOSED PRESSURE MIN (kPa)"] = self.ngProcess

            excelData["Process 4 Model Code"] = self.ngProcess
            excelData["Process 4 S/N"] = self.ngProcess
            excelData["Process 4 ID"] = self.ngProcess
            excelData["Process 4 NAME"] = self.ngProcess
            excelData["Process 4 Regular/Contractual"] = self.ngProcess
            excelData["Process 4 Tank"] = self.ngProcess
            excelData["Process 4 Tank Lot No"] = self.ngProcess
            excelData["Process 4 Upper Housing"] = self.ngProcess
            excelData["Process 4 Upper Housing Lot No"] = self.ngProcess
            excelData["Process 4 Cord Hook" ] = self.ngProcess
            excelData["Process 4 Cord Hook Lot No"] = self.ngProcess
            excelData["Process 4 M4x16 Screw"] = self.ngProcess
            excelData["Process 4 M4x16 Screw Lot No"] = self.ngProcess
            excelData["Process 4 Tank Gasket"] = self.ngProcess
            excelData["Process 4 Tank Gasket Lot No"] = self.ngProcess
            excelData["Process 4 Tank Cover"] = self.ngProcess
            excelData["Process 4 Tank Cover Lot No"] = self.ngProcess
            excelData["Process 4 Housing Gasket"] = self.ngProcess
            excelData["Process 4 Housing Gasket Lot No"] = self.ngProcess
            excelData["Process 4 M4x40 Screw"] = self.ngProcess
            excelData["Process 4 M4x40 Screw Lot No"] = self.ngProcess
            excelData["Process 4 PartitionGasket"] = self.ngProcess
            excelData["Process 4 PartitionGasket Lot No"] = self.ngProcess
            excelData["Process 4 M4x12 Screw"] = self.ngProcess
            excelData["Process 4 M4x12 Screw Lot No"] = self.ngProcess
            excelData["Process 4 Muffler"] = self.ngProcess
            excelData["Process 4 Muffler Lot No"] = self.ngProcess
            excelData["Process 4 Muffler Gasket"] = self.ngProcess
            excelData["Process 4 Muffler Gasket Lot No"] = self.ngProcess
            excelData["Process 4 VCR"] = self.ngProcess
            excelData["Process 4 VCR Lot No"] = self.ngProcess
            excelData["Process 4 ST"] = self.ngProcess
            excelData["Process 4 Actual Time"] = self.ngProcess
            excelData["Process 4 NG Cause"] = self.ngProcess
            excelData["Process 4 Repaired Action"] = self.ngProcess

            excelData["Process 5 Model Code"] = self.ngProcess
            excelData["Process 5 S/N"] = self.ngProcess
            excelData["Process 5 ID"] = self.ngProcess
            excelData["Process 5 NAME"] = self.ngProcess
            excelData["Process 5 Regular/Contractual"] = self.ngProcess
            excelData["Process 5 Rating Label"] = self.ngProcess
            excelData["Process 5 Rating Label Lot No"] = self.ngProcess
            excelData["Process 5 ST"] = self.ngProcess
            excelData["Process 5 Actual Time"] = self.ngProcess
            excelData["Process 5 NG Cause"] = self.ngProcess
            excelData["Process 5 Repaired Action"] = self.ngProcess

            excelData["Process 6 Model Code"] = self.ngProcess
            excelData["Process 6 S/N"] = self.ngProcess
            excelData["Process 6 ID"] = self.ngProcess
            excelData["Process 6 NAME"] = self.ngProcess
            excelData["Process 6 Regular/Contractual"] = self.ngProcess
            excelData["Process 6 Vinyl"] = self.ngProcess
            excelData["Process 6 Vinyl Lot No"] = self.ngProcess
            excelData["Process 6 ST"] = self.ngProcess
            excelData["Process 6 Actual Time"] = self.ngProcess
            excelData["Process 6 NG Cause"] = self.ngProcess
            excelData["Process 6 Repaired Action"] = self.ngProcess

        if self.process4Status == "NG":
            self.ngProcess = "NG AT PROCESS4"
            self.process4Row += 1

            excelData["DATE"] = self.ngProcess
            excelData["TIME"] = self.ngProcess
            excelData["MODEL CODE"] = self.ngProcess
            excelData["PROCESS S/N"] = self.ngProcess
            excelData["S/N"] = self.ngProcess
            excelData["PASS/NG"] = self.ngProcess
            excelData["VOLTAGE MAX (V)"] = self.ngProcess
            excelData["WATTAGE MAX (W)"] = self.ngProcess
            excelData["CLOSED PRESSURE_MAX (kPa)"] = self.ngProcess
            excelData["VOLTAGE Middle (V)"] = self.ngProcess
            excelData["WATTAGE Middle (W)"] = self.ngProcess
            excelData["AMPERAGE Middle (A)"] = self.ngProcess
            excelData["CLOSED PRESSURE Middle (kPa)"] = self.ngProcess
            excelData["dB(A) 1"] = self.ngProcess
            excelData["dB(A) 2"] = self.ngProcess
            excelData["dB(A) 3"] = self.ngProcess
            excelData["VOLTAGE MIN (V)"] = self.ngProcess
            excelData["WATTAGE MIN (W)"] = self.ngProcess
            excelData["CLOSED PRESSURE MIN (kPa)"] = self.ngProcess

            excelData["Process 5 Model Code"] = self.ngProcess
            excelData["Process 5 S/N"] = self.ngProcess
            excelData["Process 5 ID"] = self.ngProcess
            excelData["Process 5 NAME"] = self.ngProcess
            excelData["Process 5 Regular/Contractual"] = self.ngProcess
            excelData["Process 5 Rating Label"] = self.ngProcess
            excelData["Process 5 Rating Label Lot No"] = self.ngProcess
            excelData["Process 5 ST"] = self.ngProcess
            excelData["Process 5 Actual Time"] = self.ngProcess
            excelData["Process 5 NG Cause"] = self.ngProcess
            excelData["Process 5 Repaired Action"] = self.ngProcess

            excelData["Process 6 Model Code"] = self.ngProcess
            excelData["Process 6 S/N"] = self.ngProcess
            excelData["Process 6 ID"] = self.ngProcess
            excelData["Process 6 NAME"] = self.ngProcess
            excelData["Process 6 Regular/Contractual"] = self.ngProcess
            excelData["Process 6 Vinyl"] = self.ngProcess
            excelData["Process 6 Vinyl Lot No"] = self.ngProcess
            excelData["Process 6 ST"] = self.ngProcess
            excelData["Process 6 Actual Time"] = self.ngProcess
            excelData["Process 6 NG Cause"] = self.ngProcess
            excelData["Process 6 Repaired Action"] = self.ngProcess

        if self.process5Status == "NG PRESSURE":
            self.ngProcess = "NG PRESSURE AT PROCESS5"
            self.process5Row += 1
            piCompiler.piRow += 1

            excelData["DATE"] = self.ngProcess
            excelData["TIME"] = self.ngProcess
            excelData["MODEL CODE"] = self.ngProcess
            excelData["PROCESS S/N"] = self.ngProcess
            excelData["S/N"] = self.ngProcess
            excelData["PASS/NG"] = self.ngProcess
            excelData["VOLTAGE MAX (V)"] = self.ngProcess
            excelData["WATTAGE MAX (W)"] = self.ngProcess
            excelData["CLOSED PRESSURE_MAX (kPa)"] = self.ngProcess
            excelData["VOLTAGE Middle (V)"] = self.ngProcess
            excelData["WATTAGE Middle (W)"] = self.ngProcess
            excelData["AMPERAGE Middle (A)"] = self.ngProcess
            excelData["CLOSED PRESSURE Middle (kPa)"] = self.ngProcess
            excelData["dB(A) 1"] = self.ngProcess
            excelData["dB(A) 2"] = self.ngProcess
            excelData["dB(A) 3"] = self.ngProcess
            excelData["VOLTAGE MIN (V)"] = self.ngProcess
            excelData["WATTAGE MIN (W)"] = self.ngProcess
            excelData["CLOSED PRESSURE MIN (kPa)"] = self.ngProcess

            excelData["Process 6 Model Code"] = self.ngProcess
            excelData["Process 6 S/N"] = self.ngProcess
            excelData["Process 6 ID"] = self.ngProcess
            excelData["Process 6 NAME"] = self.ngProcess
            excelData["Process 6 Regular/Contractual"] = self.ngProcess
            excelData["Process 6 Vinyl"] = self.ngProcess
            excelData["Process 6 Vinyl Lot No"] = self.ngProcess
            excelData["Process 6 ST"] = self.ngProcess
            excelData["Process 6 Actual Time"] = self.ngProcess
            excelData["Process 6 NG Cause"] = self.ngProcess
            excelData["Process 6 Repaired Action"] = self.ngProcess

        if self.process5Status == "NG":
            self.ngProcess = "NG AT PROCESS5"
            self.process5Row += 1
            piCompiler.piRow += 1

            # excelData["DATE"] = ngProcess
            # excelData["TIME"] = ngProcess
            # excelData["MODEL CODE"] = ngProcess
            # excelData["PROCESS S/N"] = ngProcess
            # excelData["S/N"] = ngProcess
            # excelData["PASS/NG"] = ngProcess
            # excelData["VOLTAGE MAX (V)"] = ngProcess
            # excelData["WATTAGE MAX (W)"] = ngProcess
            # excelData["CLOSED PRESSURE_MAX (kPa)"] = ngProcess
            # excelData["VOLTAGE Middle (V)"] = ngProcess
            # excelData["WATTAGE Middle (W)"] = ngProcess
            # excelData["AMPERAGE Middle (A)"] = ngProcess
            # excelData["CLOSED PRESSURE Middle (kPa)"] = ngProcess
            # excelData["dB(A) 1"] = ngProcess
            # excelData["dB(A) 2"] = ngProcess
            # excelData["dB(A) 3"] = ngProcess
            # excelData["VOLTAGE MIN (V)"] = ngProcess
            # excelData["WATTAGE MIN (W)"] = ngProcess
            # excelData["CLOSED PRESSURE MIN (kPa)"] = ngProcess

            excelData["Process 6 Model Code"] = self.ngProcess
            excelData["Process 6 S/N"] = self.ngProcess
            excelData["Process 6 ID"] = self.ngProcess
            excelData["Process 6 NAME"] = self.ngProcess
            excelData["Process 6 Regular/Contractual"] = self.ngProcess
            excelData["Process 6 Vinyl"] = self.ngProcess
            excelData["Process 6 Vinyl Lot No"] = self.ngProcess
            excelData["Process 6 ST"] = self.ngProcess
            excelData["Process 6 Actual Time"] = self.ngProcess
            excelData["Process 6 NG Cause"] = self.ngProcess
            excelData["Process 6 Repaired Action"] = self.ngProcess

        if self.process6Status == "NG":
            self.ngProcess = "NG AT PROCESS6"
            self.process6Row += 1

            excelData["DATE"] = self.ngProcess
            excelData["TIME"] = self.ngProcess
            excelData["MODEL CODE"] = self.ngProcess
            excelData["PROCESS S/N"] = self.ngProcess
            excelData["S/N"] = self.ngProcess
            excelData["PASS/NG"] = self.ngProcess
            excelData["VOLTAGE MAX (V)"] = self.ngProcess
            excelData["WATTAGE MAX (W)"] = self.ngProcess
            excelData["CLOSED PRESSURE_MAX (kPa)"] = self.ngProcess
            excelData["VOLTAGE Middle (V)"] = self.ngProcess
            excelData["WATTAGE Middle (W)"] = self.ngProcess
            excelData["AMPERAGE Middle (A)"] = self.ngProcess
            excelData["CLOSED PRESSURE Middle (kPa)"] = self.ngProcess
            excelData["dB(A) 1"] = self.ngProcess
            excelData["dB(A) 2"] = self.ngProcess
            excelData["dB(A) 3"] = self.ngProcess
            excelData["VOLTAGE MIN (V)"] = self.ngProcess
            excelData["WATTAGE MIN (W)"] = self.ngProcess
            excelData["CLOSED PRESSURE MIN (kPa)"] = self.ngProcess

        if self.process1Status == "Repaired":
            self.repairedProcess = "REPAIRED AT PROCESS1"
            self.process1Row += 1
            self.process2Row += 1
            self.process3Row += 1
            self.process4Row += 1
            self.process5Row += 1
            self.process6Row += 1
            piCompiler.piRow += 1

        if self.process2Status == "Repaired":
            self.repairedProcess = "REPAIRED AT PROCESS2"
            self.process2Row += 1
            self.process3Row += 1
            self.process4Row += 1
            self.process5Row += 1
            self.process6Row += 1
            piCompiler.piRow += 1

            # excelData["DATE"] = repairedProcess
            # excelData["TIME"] = repairedProcess
            # excelData["MODEL CODE"] = repairedProcess
            # excelData["PROCESS S/N"] = repairedProcess
            # excelData["S/N"] = repairedProcess
            # excelData["PASS/NG"] = repairedProcess
            # excelData["VOLTAGE MAX (V)"] = repairedProcess
            # excelData["WATTAGE MAX (W)"] = repairedProcess
            # excelData["CLOSED PRESSURE_MAX (kPa)"] = repairedProcess
            # excelData["VOLTAGE Middle (V)"] = repairedProcess
            # excelData["WATTAGE Middle (W)"] = repairedProcess
            # excelData["AMPERAGE Middle (A)"] = repairedProcess
            # excelData["CLOSED PRESSURE Middle (kPa)"] = repairedProcess
            # excelData["dB(A) 1"] = repairedProcess
            # excelData["dB(A) 2"] = repairedProcess
            # excelData["dB(A) 3"] = repairedProcess
            # excelData["VOLTAGE MIN (V)"] = repairedProcess
            # excelData["WATTAGE MIN (W)"] = repairedProcess
            # excelData["CLOSED PRESSURE MIN (kPa)"] = repairedProcess

            excelData["Process 1 Model Code"] = self.repairedProcess
            excelData["Process 1 S/N"] = self.repairedProcess
            excelData["Process 1 ID"] = self.repairedProcess
            excelData["Process 1 NAME"] = self.repairedProcess
            excelData["Process 1 Regular/Contractual"] = self.repairedProcess
            excelData["Process 1 Em2p"] = self.repairedProcess
            excelData["Process 1 Em2p Lot No"] = self.repairedProcess
            excelData["Process 1 Em3p"] = self.repairedProcess
            excelData["Process 1 Em3p Lot No"] = self.repairedProcess
            excelData["Process 1 Harness"] = self.repairedProcess
            excelData["Process 1 Harness Lot No"] = self.repairedProcess
            excelData["Process 1 Frame"] = self.repairedProcess
            excelData["Process 1 Frame Lot No"] = self.repairedProcess 
            excelData["Process 1 Bushing"] = self.repairedProcess
            excelData["Process 1 Bushing Lot No"] = self.repairedProcess
            excelData["Process 1 ST"] = self.repairedProcess
            excelData["Process 1 Actual Time"] = self.repairedProcess
            excelData["Process 1 NG Cause"] = self.repairedProcess
            excelData["Process 1 Repaired Action"] = self.repairedProcess  

        if self.process3Status == "Repaired":
            self.repairedProcess = "REPAIRED AT PROCESS3"
            self.process3Row += 1
            self.process4Row += 1
            self.process5Row += 1
            self.process6Row += 1
            piCompiler.piRow += 1

            # excelData["DATE"] = repairedProcess
            # excelData["TIME"] = repairedProcess
            # excelData["MODEL CODE"] = repairedProcess
            # excelData["PROCESS S/N"] = repairedProcess
            # excelData["S/N"] = repairedProcess
            # excelData["PASS/NG"] = repairedProcess
            # excelData["VOLTAGE MAX (V)"] = repairedProcess
            # excelData["WATTAGE MAX (W)"] = repairedProcess
            # excelData["CLOSED PRESSURE_MAX (kPa)"] = repairedProcess
            # excelData["VOLTAGE Middle (V)"] = repairedProcess
            # excelData["WATTAGE Middle (W)"] = repairedProcess
            # excelData["AMPERAGE Middle (A)"] = repairedProcess
            # excelData["CLOSED PRESSURE Middle (kPa)"] = repairedProcess
            # excelData["dB(A) 1"] = repairedProcess
            # excelData["dB(A) 2"] = repairedProcess
            # excelData["dB(A) 3"] = repairedProcess
            # excelData["VOLTAGE MIN (V)"] = repairedProcess
            # excelData["WATTAGE MIN (W)"] = repairedProcess
            # excelData["CLOSED PRESSURE MIN (kPa)"] = repairedProcess

            excelData["Process 1 Model Code"] = self.repairedProcess
            excelData["Process 1 S/N"] = self.repairedProcess
            excelData["Process 1 ID"] = self.repairedProcess
            excelData["Process 1 NAME"] = self.repairedProcess
            excelData["Process 1 Regular/Contractual"] = self.repairedProcess
            excelData["Process 1 Em2p"] = self.repairedProcess
            excelData["Process 1 Em2p Lot No"] = self.repairedProcess
            excelData["Process 1 Em3p"] = self.repairedProcess
            excelData["Process 1 Em3p Lot No"] = self.repairedProcess
            excelData["Process 1 Harness"] = self.repairedProcess
            excelData["Process 1 Harness Lot No"] = self.repairedProcess
            excelData["Process 1 Frame"] = self.repairedProcess
            excelData["Process 1 Frame Lot No"] = self.repairedProcess 
            excelData["Process 1 Bushing"] = self.repairedProcess
            excelData["Process 1 Bushing Lot No"] = self.repairedProcess
            excelData["Process 1 ST"] = self.repairedProcess
            excelData["Process 1 Actual Time"] = self.repairedProcess
            excelData["Process 1 NG Cause"] = self.repairedProcess
            excelData["Process 1 Repaired Action"] = self.repairedProcess  

            excelData["Process 2 Model Code"] = self.repairedProcess
            excelData["Process 2 S/N"] = self.repairedProcess
            excelData["Process 2 ID"] = self.repairedProcess
            excelData["Process 2 NAME"] = self.repairedProcess
            excelData["Process 2 Regular/Contractual"] = self.repairedProcess
            excelData["Process 2 M4x40 Screw"] = self.repairedProcess
            excelData["Process 2 M4x40 Screw Lot No"] = self.repairedProcess
            excelData["Process 2 Rod Blk"] = self.repairedProcess
            excelData["Process 2 Rod Blk Lot No"] = self.repairedProcess
            excelData["Process 2 Df Blk"] = self.repairedProcess
            excelData["Process 2 Df Blk Lot No"] = self.repairedProcess
            excelData["Process 2 Df Ring"] = self.repairedProcess
            excelData["Process 2 Df Ring Lot No"] = self.repairedProcess
            excelData["Process 2 Washer"] = self.repairedProcess
            excelData["Process 2 Washer Lot No"] = self.repairedProcess
            excelData["Process 2 Lock Nut"] = self.repairedProcess
            excelData["Process 2 Lock Nut Lot No"] = self.repairedProcess
            excelData["Process 2 ST"] = self.repairedProcess
            excelData["Process 2 Actual Time"] = self.repairedProcess
            excelData["Process 2 NG Cause"] = self.repairedProcess
            excelData["Process 2 Repaired Action"] = self.repairedProcess

        if self.process4Status == "Repaired":
            self.repairedProcess = "REPAIRED AT PROCESS4"
            self.process4Row += 1
            self.process5Row += 1
            self.process6Row += 1
            piCompiler.piRow += 1

            # excelData["DATE"] = repairedProcess
            # excelData["TIME"] = repairedProcess
            # excelData["MODEL CODE"] = repairedProcess
            # excelData["PROCESS S/N"] = repairedProcess
            # excelData["S/N"] = repairedProcess
            # excelData["PASS/NG"] = repairedProcess
            # excelData["VOLTAGE MAX (V)"] = repairedProcess
            # excelData["WATTAGE MAX (W)"] = repairedProcess
            # excelData["CLOSED PRESSURE_MAX (kPa)"] = repairedProcess
            # excelData["VOLTAGE Middle (V)"] = repairedProcess
            # excelData["WATTAGE Middle (W)"] = repairedProcess
            # excelData["AMPERAGE Middle (A)"] = repairedProcess
            # excelData["CLOSED PRESSURE Middle (kPa)"] = repairedProcess
            # excelData["dB(A) 1"] = repairedProcess
            # excelData["dB(A) 2"] = repairedProcess
            # excelData["dB(A) 3"] = repairedProcess
            # excelData["VOLTAGE MIN (V)"] = repairedProcess
            # excelData["WATTAGE MIN (W)"] = repairedProcess
            # excelData["CLOSED PRESSURE MIN (kPa)"] = repairedProcess

            excelData["Process 1 Model Code"] = self.repairedProcess
            excelData["Process 1 S/N"] = self.repairedProcess
            excelData["Process 1 ID"] = self.repairedProcess
            excelData["Process 1 NAME"] = self.repairedProcess
            excelData["Process 1 Regular/Contractual"] = self.repairedProcess
            excelData["Process 1 Em2p"] = self.repairedProcess
            excelData["Process 1 Em2p Lot No"] = self.repairedProcess
            excelData["Process 1 Em3p"] = self.repairedProcess
            excelData["Process 1 Em3p Lot No"] = self.repairedProcess
            excelData["Process 1 Harness"] = self.repairedProcess
            excelData["Process 1 Harness Lot No"] = self.repairedProcess
            excelData["Process 1 Frame"] = self.repairedProcess
            excelData["Process 1 Frame Lot No"] = self.repairedProcess 
            excelData["Process 1 Bushing"] = self.repairedProcess
            excelData["Process 1 Bushing Lot No"] = self.repairedProcess
            excelData["Process 1 ST"] = self.repairedProcess
            excelData["Process 1 Actual Time"] = self.repairedProcess
            excelData["Process 1 NG Cause"] = self.repairedProcess
            excelData["Process 1 Repaired Action"] = self.repairedProcess  

            excelData["Process 2 Model Code"] = self.repairedProcess
            excelData["Process 2 S/N"] = self.repairedProcess
            excelData["Process 2 ID"] = self.repairedProcess
            excelData["Process 2 NAME"] = self.repairedProcess
            excelData["Process 2 Regular/Contractual"] = self.repairedProcess
            excelData["Process 2 M4x40 Screw"] = self.repairedProcess
            excelData["Process 2 M4x40 Screw Lot No"] = self.repairedProcess
            excelData["Process 2 Rod Blk"] = self.repairedProcess
            excelData["Process 2 Rod Blk Lot No"] = self.repairedProcess
            excelData["Process 2 Df Blk"] = self.repairedProcess
            excelData["Process 2 Df Blk Lot No"] = self.repairedProcess
            excelData["Process 2 Df Ring"] = self.repairedProcess
            excelData["Process 2 Df Ring Lot No"] = self.repairedProcess
            excelData["Process 2 Washer"] = self.repairedProcess
            excelData["Process 2 Washer Lot No"] = self.repairedProcess
            excelData["Process 2 Lock Nut"] = self.repairedProcess
            excelData["Process 2 Lock Nut Lot No"] = self.repairedProcess
            excelData["Process 2 ST"] = self.repairedProcess
            excelData["Process 2 Actual Time"] = self.repairedProcess
            excelData["Process 2 NG Cause"] = self.repairedProcess
            excelData["Process 2 Repaired Action"] = self.repairedProcess

            excelData["Process 3 Model Code"] = self.repairedProcess
            excelData["Process 3 S/N"] = self.repairedProcess
            excelData["Process 3 ID"] = self.repairedProcess
            excelData["Process 3 NAME"] = self.repairedProcess
            excelData["Process 3 Regular/Contractual"] = self.repairedProcess
            excelData["Process 3 Frame Gasket"] = self.repairedProcess
            excelData["Process 3 Frame Gasket Lot No"] = self.repairedProcess
            excelData["Process 3 Casing Block"] = self.repairedProcess
            excelData["Process 3 Casing Block Lot No"] = self.repairedProcess
            excelData["Process 3 Casing Block Inspection 1 Average Data"] = self.repairedProcess
            excelData["Process 3 Casing Block Inspection 1 Minimum Data"] = self.repairedProcess
            excelData["Process 3 Casing Block Inspection 1 Maximum Data"] = self.repairedProcess
            excelData["Process 3 Casing Gasket"] = self.repairedProcess
            excelData["Process 3 Casing Gasket Lot No"] = self.repairedProcess
            excelData["Process 3 M4x16 Screw 1"] = self.repairedProcess
            excelData["Process 3 M4x16 Screw 1 Lot No"] = self.repairedProcess
            excelData["Process 3 M4x16 Screw 2"] = self.repairedProcess
            excelData["Process 3 M4x16 Screw 2 Lot No"] = self.repairedProcess
            excelData["Process 3 Ball Cushion"] = self.repairedProcess
            excelData["Process 3 Ball Cushion Lot No"] = self.repairedProcess
            excelData["Process 3 Frame Cover"] = self.repairedProcess
            excelData["Process 3 Frame Cover Lot No"] = self.repairedProcess
            excelData["Process 3 Partition Board"] = self.repairedProcess
            excelData["Process 3 Partition Board Lot No"] = self.repairedProcess
            excelData["Process 3 Built In Tube 1"] = self.repairedProcess
            excelData["Process 3 Built In Tube 1 Lot No"] = self.repairedProcess
            excelData["Process 3 Built In Tube 2"] = self.repairedProcess
            excelData["Process 3 Built In Tube 2 Lot No"] = self.repairedProcess
            excelData["Process 3 Head Cover"] = self.repairedProcess
            excelData["Process 3 Head Cover Lot No"] = self.repairedProcess
            excelData["Process 3 Casing Packing"] = self.repairedProcess
            excelData["Process 3 Casing Packing Lot No"] = self.repairedProcess
            excelData["Process 3 M4x12 Screw"] = self.repairedProcess
            excelData["Process 3 M4x12 Screw Lot No"] = self.repairedProcess
            excelData["Process 3 Csb L"] = self.repairedProcess
            excelData["Process 3 Csb L Lot No"] = self.repairedProcess
            excelData["Process 3 Csb R"] = self.repairedProcess
            excelData["Process 3 Csb R Lot No"] = self.repairedProcess
            excelData["Process 3 Head Packing"] = self.repairedProcess
            excelData["Process 3 Head Packing Lot No"] = self.repairedProcess
            excelData["Process 3 ST"] = self.repairedProcess
            excelData["Process 3 Actual Time"] = self.repairedProcess
            excelData["Process 3 NG Cause"] = self.repairedProcess
            excelData["Process 3 Repaired Action"] = self.repairedProcess

        if self.process5Status == "Repaired":
            self.repairedProcess = "RE PI"
            self.process5Row += 1
            self.process6Row += 1
            piCompiler.piRow += 1

            # excelData["DATE"] = repairedProcess
            # excelData["TIME"] = repairedProcess
            # excelData["MODEL CODE"] = repairedProcess
            # excelData["PROCESS S/N"] = repairedProcess
            # excelData["S/N"] = repairedProcess
            # excelData["PASS/NG"] = repairedProcess
            # excelData["VOLTAGE MAX (V)"] = repairedProcess
            # excelData["WATTAGE MAX (W)"] = repairedProcess
            # excelData["CLOSED PRESSURE_MAX (kPa)"] = repairedProcess
            # excelData["VOLTAGE Middle (V)"] = repairedProcess
            # excelData["WATTAGE Middle (W)"] = repairedProcess
            # excelData["AMPERAGE Middle (A)"] = repairedProcess
            # excelData["CLOSED PRESSURE Middle (kPa)"] = repairedProcess
            # excelData["dB(A) 1"] = repairedProcess
            # excelData["dB(A) 2"] = repairedProcess
            # excelData["dB(A) 3"] = repairedProcess
            # excelData["VOLTAGE MIN (V)"] = repairedProcess
            # excelData["WATTAGE MIN (W)"] = repairedProcess
            # excelData["CLOSED PRESSURE MIN (kPa)"] = repairedProcess

            excelData["Process 1 Model Code"] = self.repairedProcess
            excelData["Process 1 S/N"] = self.repairedProcess
            excelData["Process 1 ID"] = self.repairedProcess
            excelData["Process 1 NAME"] = self.repairedProcess
            excelData["Process 1 Regular/Contractual"] = self.repairedProcess
            excelData["Process 1 Em2p"] = self.repairedProcess
            excelData["Process 1 Em2p Lot No"] = self.repairedProcess
            excelData["Process 1 Em3p"] = self.repairedProcess
            excelData["Process 1 Em3p Lot No"] = self.repairedProcess
            excelData["Process 1 Harness"] = self.repairedProcess
            excelData["Process 1 Harness Lot No"] = self.repairedProcess
            excelData["Process 1 Frame"] = self.repairedProcess
            excelData["Process 1 Frame Lot No"] = self.repairedProcess 
            excelData["Process 1 Bushing"] = self.repairedProcess
            excelData["Process 1 Bushing Lot No"] = self.repairedProcess
            excelData["Process 1 ST"] = self.repairedProcess
            excelData["Process 1 Actual Time"] = self.repairedProcess
            excelData["Process 1 NG Cause"] = self.repairedProcess
            excelData["Process 1 Repaired Action"] = self.repairedProcess  

            excelData["Process 2 Model Code"] = self.repairedProcess
            excelData["Process 2 S/N"] = self.repairedProcess
            excelData["Process 2 ID"] = self.repairedProcess
            excelData["Process 2 NAME"] = self.repairedProcess
            excelData["Process 2 Regular/Contractual"] = self.repairedProcess
            excelData["Process 2 M4x40 Screw"] = self.repairedProcess
            excelData["Process 2 M4x40 Screw Lot No"] = self.repairedProcess
            excelData["Process 2 Rod Blk"] = self.repairedProcess
            excelData["Process 2 Rod Blk Lot No"] = self.repairedProcess
            excelData["Process 2 Df Blk"] = self.repairedProcess
            excelData["Process 2 Df Blk Lot No"] = self.repairedProcess
            excelData["Process 2 Df Ring"] = self.repairedProcess
            excelData["Process 2 Df Ring Lot No"] = self.repairedProcess
            excelData["Process 2 Washer"] = self.repairedProcess
            excelData["Process 2 Washer Lot No"] = self.repairedProcess
            excelData["Process 2 Lock Nut"] = self.repairedProcess
            excelData["Process 2 Lock Nut Lot No"] = self.repairedProcess
            excelData["Process 2 ST"] = self.repairedProcess
            excelData["Process 2 Actual Time"] = self.repairedProcess
            excelData["Process 2 NG Cause"] = self.repairedProcess
            excelData["Process 2 Repaired Action"] = self.repairedProcess

            excelData["Process 3 Model Code"] = self.repairedProcess
            excelData["Process 3 S/N"] = self.repairedProcess
            excelData["Process 3 ID"] = self.repairedProcess
            excelData["Process 3 NAME"] = self.repairedProcess
            excelData["Process 3 Regular/Contractual"] = self.repairedProcess
            excelData["Process 3 Frame Gasket"] = self.repairedProcess
            excelData["Process 3 Frame Gasket Lot No"] = self.repairedProcess
            excelData["Process 3 Casing Block"] = self.repairedProcess
            excelData["Process 3 Casing Block Lot No"] = self.repairedProcess
            excelData["Process 3 Casing Block Inspection 1 Average Data"] = self.repairedProcess
            excelData["Process 3 Casing Block Inspection 1 Minimum Data"] = self.repairedProcess
            excelData["Process 3 Casing Block Inspection 1 Maximum Data"] = self.repairedProcess
            excelData["Process 3 Casing Gasket"] = self.repairedProcess
            excelData["Process 3 Casing Gasket Lot No"] = self.repairedProcess
            excelData["Process 3 M4x16 Screw 1"] = self.repairedProcess
            excelData["Process 3 M4x16 Screw 1 Lot No"] = self.repairedProcess
            excelData["Process 3 M4x16 Screw 2"] = self.repairedProcess
            excelData["Process 3 M4x16 Screw 2 Lot No"] = self.repairedProcess
            excelData["Process 3 Ball Cushion"] = self.repairedProcess
            excelData["Process 3 Ball Cushion Lot No"] = self.repairedProcess
            excelData["Process 3 Frame Cover"] = self.repairedProcess
            excelData["Process 3 Frame Cover Lot No"] = self.repairedProcess
            excelData["Process 3 Partition Board"] = self.repairedProcess
            excelData["Process 3 Partition Board Lot No"] = self.repairedProcess
            excelData["Process 3 Built In Tube 1"] = self.repairedProcess
            excelData["Process 3 Built In Tube 1 Lot No"] = self.repairedProcess
            excelData["Process 3 Built In Tube 2"] = self.repairedProcess
            excelData["Process 3 Built In Tube 2 Lot No"] = self.repairedProcess
            excelData["Process 3 Head Cover"] = self.repairedProcess
            excelData["Process 3 Head Cover Lot No"] = self.repairedProcess
            excelData["Process 3 Casing Packing"] = self.repairedProcess
            excelData["Process 3 Casing Packing Lot No"] = self.repairedProcess
            excelData["Process 3 M4x12 Screw"] = self.repairedProcess
            excelData["Process 3 M4x12 Screw Lot No"] = self.repairedProcess
            excelData["Process 3 Csb L"] = self.repairedProcess
            excelData["Process 3 Csb L Lot No"] = self.repairedProcess
            excelData["Process 3 Csb R"] = self.repairedProcess
            excelData["Process 3 Csb R Lot No"] = self.repairedProcess
            excelData["Process 3 Head Packing"] = self.repairedProcess
            excelData["Process 3 Head Packing Lot No"] = self.repairedProcess
            excelData["Process 3 ST"] = self.repairedProcess
            excelData["Process 3 Actual Time"] = self.repairedProcess
            excelData["Process 3 NG Cause"] = self.repairedProcess
            excelData["Process 3 Repaired Action"] = self.repairedProcess
            
            excelData["Process 4 Model Code"] = self.repairedProcess
            excelData["Process 4 S/N"] = self.repairedProcess
            excelData["Process 4 ID"] = self.repairedProcess
            excelData["Process 4 NAME"] = self.repairedProcess
            excelData["Process 4 Regular/Contractual"] = self.repairedProcess
            excelData["Process 4 Tank"] = self.repairedProcess
            excelData["Process 4 Tank Lot No"] = self.repairedProcess
            excelData["Process 4 Upper Housing"] = self.repairedProcess
            excelData["Process 4 Upper Housing Lot No"] = self.repairedProcess
            excelData["Process 4 Cord Hook" ] = self.repairedProcess
            excelData["Process 4 Cord Hook Lot No"] = self.repairedProcess
            excelData["Process 4 M4x16 Screw"] = self.repairedProcess
            excelData["Process 4 M4x16 Screw Lot No"] = self.repairedProcess
            excelData["Process 4 Tank Gasket"] = self.repairedProcess
            excelData["Process 4 Tank Gasket Lot No"] = self.repairedProcess
            excelData["Process 4 Tank Cover"] = self.repairedProcess
            excelData["Process 4 Tank Cover Lot No"] = self.repairedProcess
            excelData["Process 4 Housing Gasket"] = self.repairedProcess
            excelData["Process 4 Housing Gasket Lot No"] = self.repairedProcess
            excelData["Process 4 M4x40 Screw"] = self.repairedProcess
            excelData["Process 4 M4x40 Screw Lot No"] = self.repairedProcess
            excelData["Process 4 PartitionGasket"] = self.repairedProcess
            excelData["Process 4 PartitionGasket Lot No"] = self.repairedProcess
            excelData["Process 4 M4x12 Screw"] = self.repairedProcess
            excelData["Process 4 M4x12 Screw Lot No"] = self.repairedProcess
            excelData["Process 4 Muffler"] = self.repairedProcess
            excelData["Process 4 Muffler Lot No"] = self.repairedProcess
            excelData["Process 4 Muffler Gasket"] = self.repairedProcess
            excelData["Process 4 Muffler Gasket Lot No"] = self.repairedProcess
            excelData["Process 4 VCR"] = self.repairedProcess
            excelData["Process 4 VCR Lot No"] = self.repairedProcess
            excelData["Process 4 ST"] = self.repairedProcess
            excelData["Process 4 Actual Time"] = self.repairedProcess
            excelData["Process 4 NG Cause"] = self.repairedProcess
            excelData["Process 4 Repaired Action"] = self.repairedProcess

        if self.process6Status == "Repaired":
            self.repairedProcess = "REPAIRED AT PROCESS6"
            self.process6Row += 1
            piCompiler.piRow += 1

            # excelData["DATE"] = repairedProcess
            # excelData["TIME"] = repairedProcess
            # excelData["MODEL CODE"] = repairedProcess
            # excelData["PROCESS S/N"] = repairedProcess
            # excelData["S/N"] = repairedProcess
            # excelData["PASS/NG"] = repairedProcess
            # excelData["VOLTAGE MAX (V)"] = repairedProcess
            # excelData["WATTAGE MAX (W)"] = repairedProcess
            # excelData["CLOSED PRESSURE_MAX (kPa)"] = repairedProcess
            # excelData["VOLTAGE Middle (V)"] = repairedProcess
            # excelData["WATTAGE Middle (W)"] = repairedProcess
            # excelData["AMPERAGE Middle (A)"] = repairedProcess
            # excelData["CLOSED PRESSURE Middle (kPa)"] = repairedProcess
            # excelData["dB(A) 1"] = repairedProcess
            # excelData["dB(A) 2"] = repairedProcess
            # excelData["dB(A) 3"] = repairedProcess
            # excelData["VOLTAGE MIN (V)"] = repairedProcess
            # excelData["WATTAGE MIN (W)"] = repairedProcess
            # excelData["CLOSED PRESSURE MIN (kPa)"] = repairedProcess

            excelData["Process 1 Model Code"] = self.repairedProcess
            excelData["Process 1 S/N"] = self.repairedProcess
            excelData["Process 1 ID"] = self.repairedProcess
            excelData["Process 1 NAME"] = self.repairedProcess
            excelData["Process 1 Regular/Contractual"] = self.repairedProcess
            excelData["Process 1 Em2p"] = self.repairedProcess
            excelData["Process 1 Em2p Lot No"] = self.repairedProcess
            excelData["Process 1 Em3p"] = self.repairedProcess
            excelData["Process 1 Em3p Lot No"] = self.repairedProcess
            excelData["Process 1 Harness"] = self.repairedProcess
            excelData["Process 1 Harness Lot No"] = self.repairedProcess
            excelData["Process 1 Frame"] = self.repairedProcess
            excelData["Process 1 Frame Lot No"] = self.repairedProcess 
            excelData["Process 1 Bushing"] = self.repairedProcess
            excelData["Process 1 Bushing Lot No"] = self.repairedProcess
            excelData["Process 1 ST"] = self.repairedProcess
            excelData["Process 1 Actual Time"] = self.repairedProcess
            excelData["Process 1 NG Cause"] = self.repairedProcess
            excelData["Process 1 Repaired Action"] = self.repairedProcess  

            excelData["Process 2 Model Code"] = self.repairedProcess
            excelData["Process 2 S/N"] = self.repairedProcess
            excelData["Process 2 ID"] = self.repairedProcess
            excelData["Process 2 NAME"] = self.repairedProcess
            excelData["Process 2 Regular/Contractual"] = self.repairedProcess
            excelData["Process 2 M4x40 Screw"] = self.repairedProcess
            excelData["Process 2 M4x40 Screw Lot No"] = self.repairedProcess
            excelData["Process 2 Rod Blk"] = self.repairedProcess
            excelData["Process 2 Rod Blk Lot No"] = self.repairedProcess
            excelData["Process 2 Df Blk"] = self.repairedProcess
            excelData["Process 2 Df Blk Lot No"] = self.repairedProcess
            excelData["Process 2 Df Ring"] = self.repairedProcess
            excelData["Process 2 Df Ring Lot No"] = self.repairedProcess
            excelData["Process 2 Washer"] = self.repairedProcess
            excelData["Process 2 Washer Lot No"] = self.repairedProcess
            excelData["Process 2 Lock Nut"] = self.repairedProcess
            excelData["Process 2 Lock Nut Lot No"] = self.repairedProcess
            excelData["Process 2 ST"] = self.repairedProcess
            excelData["Process 2 Actual Time"] = self.repairedProcess
            excelData["Process 2 NG Cause"] = self.repairedProcess
            excelData["Process 2 Repaired Action"] = self.repairedProcess

            excelData["Process 3 Model Code"] = self.repairedProcess
            excelData["Process 3 S/N"] = self.repairedProcess
            excelData["Process 3 ID"] = self.repairedProcess
            excelData["Process 3 NAME"] = self.repairedProcess
            excelData["Process 3 Regular/Contractual"] = self.repairedProcess
            excelData["Process 3 Frame Gasket"] = self.repairedProcess
            excelData["Process 3 Frame Gasket Lot No"] = self.repairedProcess
            excelData["Process 3 Casing Block"] = self.repairedProcess
            excelData["Process 3 Casing Block Lot No"] = self.repairedProcess
            excelData["Process 3 Casing Block Inspection 1 Average Data"] = self.repairedProcess
            excelData["Process 3 Casing Block Inspection 1 Minimum Data"] = self.repairedProcess
            excelData["Process 3 Casing Block Inspection 1 Maximum Data"] = self.repairedProcess
            excelData["Process 3 Casing Gasket"] = self.repairedProcess
            excelData["Process 3 Casing Gasket Lot No"] = self.repairedProcess
            excelData["Process 3 M4x16 Screw 1"] = self.repairedProcess
            excelData["Process 3 M4x16 Screw 1 Lot No"] = self.repairedProcess
            excelData["Process 3 M4x16 Screw 2"] = self.repairedProcess
            excelData["Process 3 M4x16 Screw 2 Lot No"] = self.repairedProcess
            excelData["Process 3 Ball Cushion"] = self.repairedProcess
            excelData["Process 3 Ball Cushion Lot No"] = self.repairedProcess
            excelData["Process 3 Frame Cover"] = self.repairedProcess
            excelData["Process 3 Frame Cover Lot No"] = self.repairedProcess
            excelData["Process 3 Partition Board"] = self.repairedProcess
            excelData["Process 3 Partition Board Lot No"] = self.repairedProcess
            excelData["Process 3 Built In Tube 1"] = self.repairedProcess
            excelData["Process 3 Built In Tube 1 Lot No"] = self.repairedProcess
            excelData["Process 3 Built In Tube 2"] = self.repairedProcess
            excelData["Process 3 Built In Tube 2 Lot No"] = self.repairedProcess
            excelData["Process 3 Head Cover"] = self.repairedProcess
            excelData["Process 3 Head Cover Lot No"] = self.repairedProcess
            excelData["Process 3 Casing Packing"] = self.repairedProcess
            excelData["Process 3 Casing Packing Lot No"] = self.repairedProcess
            excelData["Process 3 M4x12 Screw"] = self.repairedProcess
            excelData["Process 3 M4x12 Screw Lot No"] = self.repairedProcess
            excelData["Process 3 Csb L"] = self.repairedProcess
            excelData["Process 3 Csb L Lot No"] = self.repairedProcess
            excelData["Process 3 Csb R"] = self.repairedProcess
            excelData["Process 3 Csb R Lot No"] = self.repairedProcess
            excelData["Process 3 Head Packing"] = self.repairedProcess
            excelData["Process 3 Head Packing Lot No"] = self.repairedProcess
            excelData["Process 3 ST"] = self.repairedProcess
            excelData["Process 3 Actual Time"] = self.repairedProcess
            excelData["Process 3 NG Cause"] = self.repairedProcess
            excelData["Process 3 Repaired Action"] = self.repairedProcess
            
            excelData["Process 4 Model Code"] = self.repairedProcess
            excelData["Process 4 S/N"] = self.repairedProcess
            excelData["Process 4 ID"] = self.repairedProcess
            excelData["Process 4 NAME"] = self.repairedProcess
            excelData["Process 4 Regular/Contractual"] = self.repairedProcess
            excelData["Process 4 Tank"] = self.repairedProcess
            excelData["Process 4 Tank Lot No"] = self.repairedProcess
            excelData["Process 4 Upper Housing"] = self.repairedProcess
            excelData["Process 4 Upper Housing Lot No"] = self.repairedProcess
            excelData["Process 4 Cord Hook" ] = self.repairedProcess
            excelData["Process 4 Cord Hook Lot No"] = self.repairedProcess
            excelData["Process 4 M4x16 Screw"] = self.repairedProcess
            excelData["Process 4 M4x16 Screw Lot No"] = self.repairedProcess
            excelData["Process 4 Tank Gasket"] = self.repairedProcess
            excelData["Process 4 Tank Gasket Lot No"] = self.repairedProcess
            excelData["Process 4 Tank Cover"] = self.repairedProcess
            excelData["Process 4 Tank Cover Lot No"] = self.repairedProcess
            excelData["Process 4 Housing Gasket"] = self.repairedProcess
            excelData["Process 4 Housing Gasket Lot No"] = self.repairedProcess
            excelData["Process 4 M4x40 Screw"] = self.repairedProcess
            excelData["Process 4 M4x40 Screw Lot No"] = self.repairedProcess
            excelData["Process 4 PartitionGasket"] = self.repairedProcess
            excelData["Process 4 PartitionGasket Lot No"] = self.repairedProcess
            excelData["Process 4 M4x12 Screw"] = self.repairedProcess
            excelData["Process 4 M4x12 Screw Lot No"] = self.repairedProcess
            excelData["Process 4 Muffler"] = self.repairedProcess
            excelData["Process 4 Muffler Lot No"] = self.repairedProcess
            excelData["Process 4 Muffler Gasket"] = self.repairedProcess
            excelData["Process 4 Muffler Gasket Lot No"] = self.repairedProcess
            excelData["Process 4 VCR"] = self.repairedProcess
            excelData["Process 4 VCR Lot No"] = self.repairedProcess
            excelData["Process 4 ST"] = self.repairedProcess
            excelData["Process 4 Actual Time"] = self.repairedProcess
            excelData["Process 4 NG Cause"] = self.repairedProcess
            excelData["Process 4 Repaired Action"] = self.repairedProcess

            excelData["Process 5 Model Code"] = self.repairedProcess
            excelData["Process 5 S/N"] = self.repairedProcess
            excelData["Process 5 ID"] = self.repairedProcess
            excelData["Process 5 NAME"] = self.repairedProcess
            excelData["Process 5 Regular/Contractual"] = self.repairedProcess
            excelData["Process 5 Rating Label"] = self.repairedProcess
            excelData["Process 5 Rating Label Lot No"] = self.repairedProcess
            excelData["Process 5 ST"] = self.repairedProcess
            excelData["Process 5 Actual Time"] = self.repairedProcess
            excelData["Process 5 NG Cause"] = self.repairedProcess
            excelData["Process 5 Repaired Action"] = self.repairedProcess
            
        piCompiler.compiledFrame = pd.concat([piCompiler.compiledFrame, excelData], ignore_index=True)

# %%
class UI():
    def __init__(self):
        pass

# %%
#Compile PI
piCompiler = PiCompiler()
piCompiler.start()

# %%
processCompiler = ProcessCompiler()
processCompiler.start()

# %%
piCompiler.compiledFrame

# %%
def StopProgram():
    global programRunning
    global autoRun
    programRunning = False
    autoRun = False

    root.destroy()

# %%
def start():
    global compiledFrame
    global canCompile
    global isCsvReaded
    global readCount
    global programRunning
    global process1Row
    global process2Row
    global process3Row
    global process4Row
    global process5Row
    global process6Row
    global piRow

    #GUI
    global compileButton
    global loadingText

    process1Row = 0
    process2Row = 0
    process3Row = 0
    process4Row = 0
    process5Row = 0
    process6Row = 0
    piRow = 0
    programRunning = True
    isCsvReaded = False

    setDate()

    compileButton.config(text= loadingText)
    compileButton.config(state= "disabled")

    col = [
        "DATE", 
        "TIME", 
        "MODEL CODE", 
        "PROCESS S/N", 
        "S/N", 
        "PASS/NG", 
        "VOLTAGE MAX (V)", 
        "WATTAGE MAX (W)", 
        "CLOSED PRESSURE_MAX (kPa)", 
        "VOLTAGE Middle (V)", 
        "WATTAGE Middle (W)", 
        "AMPERAGE Middle (A)", 
        "CLOSED PRESSURE Middle (kPa)", 
        "dB(A) 1", 
        "dB(A) 2", 
        "dB(A) 3", 
        "VOLTAGE MIN (V)", 
        "WATTAGE MIN (W)", 
        "CLOSED PRESSURE MIN (kPa)",

        "Process 1 Model Code", 
        "Process 1 S/N", 
        "Process 1 ID", 
        "Process 1 NAME", 
        "Process 1 Regular/Contractual", 
        "Process 1 Material 1 Item Code", 
        "Process 1 Material 1 Lot Number", 
        "Process 1 Material 1 Inspection 3 Average Data",
        "Process 1 Material 1 Inspection 4 Average Data",
        "Process 1 Material 1 Inspection 5 Average Data",
        "Process 1 Material 1 Inspection 10 Average Data",
        "Process 1 Material 1 Inspection 3 Minimum Data",
        "Process 1 Material 1 Inspection 4 Minimum Data",
        "Process 1 Material 1 Inspection 5 Minimum Data",
        "Process 1 Material 1 Inspection 3 Maximum Data",
        "Process 1 Material 1 Inspection 4 Maximum Data",
        "Process 1 Material 1 Inspection 5 Maximum Data",
        "Process 1 Material 2 Item Code", 
        "Process 1 Material 2 Lot Number", 
        "Process 1 Material 2 Inspection 3 Average Data",
        "Process 1 Material 2 Inspection 4 Average Data",
        "Process 1 Material 2 Inspection 5 Average Data",
        "Process 1 Material 2 Inspection 10 Average Data",
        "Process 1 Material 2 Inspection 3 Minimum Data",
        "Process 1 Material 2 Inspection 4 Minimum Data",
        "Process 1 Material 2 Inspection 5 Minimum Data",
        "Process 1 Material 2 Inspection 3 Maximum Data",
        "Process 1 Material 2 Inspection 4 Maximum Data",
        "Process 1 Material 2 Inspection 5 Maximum Data",
        "Process 1 Material 3 Item Code", 
        "Process 1 Material 3 Lot Number", 
        "Process 1 Material 4 Item Code", 
        "Process 1 Material 4 Lot Number", 
        "Process 1 Material 4 Inspection 1 Average Data", 
        "Process 1 Material 4 Inspection 2 Average Data", 
        "Process 1 Material 4 Inspection 3 Average Data", 
        "Process 1 Material 4 Inspection 4 Average Data", 
        "Process 1 Material 4 Inspection 5 Average Data", 
        "Process 1 Material 4 Inspection 6 Average Data", 
        "Process 1 Material 4 Inspection 7 Average Data", 
        "Process 1 Material 4 Inspection 1 Minimum Data", 
        "Process 1 Material 4 Inspection 2 Minimum Data", 
        "Process 1 Material 4 Inspection 3 Minimum Data", 
        "Process 1 Material 4 Inspection 4 Minimum Data", 
        "Process 1 Material 4 Inspection 5 Minimum Data", 
        "Process 1 Material 4 Inspection 6 Minimum Data", 
        "Process 1 Material 4 Inspection 7 Minimum Data", 
        "Process 1 Material 4 Inspection 1 Maximum Data", 
        "Process 1 Material 4 Inspection 2 Maximum Data", 
        "Process 1 Material 4 Inspection 3 Maximum Data", 
        "Process 1 Material 4 Inspection 4 Maximum Data", 
        "Process 1 Material 4 Inspection 5 Maximum Data", 
        "Process 1 Material 4 Inspection 6 Maximum Data", 
        "Process 1 Material 4 Inspection 7 Maximum Data", 
        "Process 1 Material 5 Item Code", 
        "Process 1 Material 5 Lot Number", 
        "Process 1 ST", 
        "Process 1 Actual Time", 
        "Process 1 NG Cause", 
        "Process 1 Repaired Action",

        "Process 2 Model Code",
        "Process 2 S/N",
        "Process 2 ID",
        "Process 2 NAME",
        "Process 2 Regular/Contractual",
        "Process 2 Material 1 Item Code",
        "Process 2 Material 1 Lot Number",
        "Process 2 Material 2 Item Code",
        "Process 2 Material 2 Lot Number",
        "Process 2 Material 2 Tesla 1 Average Data",
        "Process 2 Material 2 Tesla 2 Average Data",
        "Process 2 Material 2 Tesla 3 Average Data",
        "Process 2 Material 2 Tesla 4 Average Data",
        "Process 2 Material 2 Tesla 1 Minimum Data",
        "Process 2 Material 2 Tesla 2 Minimum Data",
        "Process 2 Material 2 Tesla 3 Minimum Data",
        "Process 2 Material 2 Tesla 4 Minimum Data",
        "Process 2 Material 2 Tesla 1 Maximum Data",
        "Process 2 Material 2 Tesla 2 Maximum Data",
        "Process 2 Material 2 Tesla 3 Maximum Data",
        "Process 2 Material 2 Tesla 4 Maximum Data",
        "Process 2 Material 2 Inspection 1 Average Data",
        "Process 2 Material 2 Inspection 2 Average Data",
        "Process 2 Material 2 Inspection 3 Average Data",
        "Process 2 Material 2 Inspection 4 Average Data",
        "Process 2 Material 2 Inspection 5 Average Data",
        "Process 2 Material 2 Inspection 6 Average Data",
        "Process 2 Material 2 Inspection 8 Average Data",
        "Process 2 Material 2 Inspection 1 Minimum Data",
        "Process 2 Material 2 Inspection 2 Minimum Data",
        "Process 2 Material 2 Inspection 3 Minimum Data",
        "Process 2 Material 2 Inspection 4 Minimum Data",
        "Process 2 Material 2 Inspection 5 Minimum Data",
        "Process 2 Material 2 Inspection 6 Minimum Data",
        "Process 2 Material 2 Inspection 8 Minimum Data",
        "Process 2 Material 2 Inspection 1 Maximum Data",
        "Process 2 Material 2 Inspection 2 Maximum Data",
        "Process 2 Material 2 Inspection 3 Maximum Data",
        "Process 2 Material 2 Inspection 4 Maximum Data",
        "Process 2 Material 2 Inspection 5 Maximum Data",
        "Process 2 Material 2 Inspection 6 Maximum Data",
        "Process 2 Material 2 Inspection 8 Maximum Data",
        "Process 2 Material 3 Item Code",
        "Process 2 Material 3 Lot Number",
        "Process 2 Material 3 Inspection 1 Average Data",
        "Process 2 Material 3 Inspection 2 Average Data",
        "Process 2 Material 3 Inspection 3 Average Data",
        "Process 2 Material 3 Inspection 4 Average Data",
        "Process 2 Material 3 Inspection 1 Minimum Data",
        "Process 2 Material 3 Inspection 2 Minimum Data",
        "Process 2 Material 3 Inspection 3 Minimum Data",
        "Process 2 Material 3 Inspection 4 Minimum Data",
        "Process 2 Material 3 Inspection 1 Maximum Data",
        "Process 2 Material 3 Inspection 2 Maximum Data",
        "Process 2 Material 3 Inspection 3 Maximum Data",
        "Process 2 Material 3 Inspection 4 Maximum Data",
        "Process 2 Material 4 Item Code",
        "Process 2 Material 4 Lot Number",
        "Process 2 Material 5 Item Code",
        "Process 2 Material 5 Lot Number",
        "Process 2 Material 6 Item Code",
        "Process 2 Material 6 Item Code.1",
        "Process 2 ST",
        "Process 2 Actual Time",
        "Process 2 NG Cause",
        "Process 2 Repaired Action",

        "Process 3 Model Code",
        "Process 3 S/N",
        "Process 3 ID",
        "Process 3 NAME",
        "Process 3 Regular/Contractual",
        "Process 3 Material 1 Item Code",
        "Process 3 Material 1 Lot Number",
        "Process 3 Material 2 Item Code",
        "Process 3 Material 2 Lot Number",
        "Process 3 Material 2 Inspection 1 Average Data",
        "Process 3 Material 2 Inspection 1 Minimum Data",
        "Process 3 Material 2 Inspection 1 Maximum Data",
        "Process 3 Material 3 Item Code",
        "Process 3 Material 3 Lot Number",
        "Process 3 Material 4 Item Code",
        "Process 3 Material 4 Lot Number",
        "Process 3 Material 5 Item Code",
        "Process 3 Material 5 Lot Number",
        "Process 3 Material 6 Item Code",
        "Process 3 Material 6 Lot Number",
        "Process 3 Material 7 Item Code",
        "Process 3 Material 7 Lot Number",
        "Process 3 Material 8 Item Code",
        "Process 3 Material 8 Lot Number",
        "Process 3 Material 9 Item Code",
        "Process 3 Material 9 Lot Number",
        "Process 3 Material 10 Item Code",
        "Process 3 Material 10 Lot Number",
        "Process 3 ST",
        "Process 3 Actual Time",
        "Process 3 NG Cause",
        "Process 3 Repaired Action",

        "Process 4 Model Code",
        "Process 4 S/N",
        "Process 4 ID",
        "Process 4 NAME",
        "Process 4 Regular/Contractual",
        "Process 4 Material 1 Item Code",
        "Process 4 Material 1 Lot Number",
        "Process 4 Material 2 Item Code",
        "Process 4 Material 2 Lot Number",
        "Process 4 Material 3 Item Code",
        "Process 4 Material 3 Lot Number",
        "Process 4 Material 4 Item Code",
        "Process 4 Material 4 Lot Number",
        "Process 4 Material 5 Item Code",
        "Process 4 Material 5 Lot Number",
        "Process 4 Material 6 Item Code",
        "Process 4 Material 6 Lot Number",
        "Process 4 Material 7 Item Code",
        "Process 4 Material 7 Lot Number",
        "Process 4 Material 8 Item Code",
        "Process 4 Material 8 Lot Number",
        "Process 4 ST",
        "Process 4 Actual Time",
        "Process 4 NG Cause",
        "Process 4 Repaired Action",
        
        "Process 5 Model Code",
        "Process 5 S/N",
        "Process 5 ID",
        "Process 5 NAME",
        "Process 5 Regular/Contractual",
        "Process 5 Material 1 Item Code",
        "Process 5 Material 1 Lot Number",
        "Process 5 ST",
        "Process 5 Actual Time",
        "Process 5 NG Cause",
        "Process 5 Repaired Action",

        "Process 6 Model Code",
        "Process 6 S/N",
        "Process 6 ID",
        "Process 6 NAME",
        "Process 6 Regular/Contractual",
        "Process 6 Material 1 Item Code",
        "Process 6 Material 1 Lot Number",
        "Process 6 ST",
        "Process 6 Actual Time",
        "Process 6 NG Cause",
        "Process 6 Repaired Action"
    ]
    compiledFrame = pd.DataFrame(columns=col)

    DateAndTimeManager.GetDateToday()

    try:
        #Checking If There's Master Pump Data
        CheckPICsv()

        #Read Inspection Data From QC
        QualityControlDataManager.ReadAll()

        #Writing Master Pump Data
        if canCompilePI:
            CompilePICsv()
            WriteCsv(compiledFrame)

        #Reading VT CSV Files
        while not isCsvReaded:
            try:
                ReadCsv()
                isCsvReaded = True
            except:
                print("Cannot Read Csv Retrying In 1 Seconds")
                isCsvReaded = False
                time.sleep(1)

        #Getting VT Original File
        process1OrigFile = os.path.getmtime(r'\\192.168.2.10\csv\csv\VT1\log000_1.csv')
        process2OrigFile = os.path.getmtime(r'\\192.168.2.10\csv\csv\VT2\log000_2.csv')
        process3OrigFile = os.path.getmtime(r'\\192.168.2.10\csv\csv\VT3\log000_3.csv')
        process4OrigFile = os.path.getmtime(r'\\192.168.2.10\csv\csv\VT4\log000_4.csv')
        process5OrigFile = os.path.getmtime(r'\\192.168.2.10\csv\csv\VT5\log000_5.csv')
        process6OrigFile = os.path.getmtime(r'\\192.168.2.10\csv\csv\VT6\log000_6.csv')

        piOrigFile = os.path.getmtime(r'\\192.168.2.19\ai_team\AI Program\Outputs\PICompiled6.csv')

        while programRunning:
            CsvOrganize()
            if canCompile:
                CompileCsv()
            if loadingText == "Loading...":
                loadingText = "Loading"
            else:
                loadingText += "."
                compileButton.config(text= loadingText)

            print(f"Process 1 S/N{tempDfVt1["Process 1 S/N"]}_______________________________________________________________________________")
            print(f"Process 2 S/N{tempDfVt2["Process 2 S/N"]}_______________________________________________________________________________")
            print(f"Process 3 S/N{tempDfVt3["Process 3 S/N"]}_______________________________________________________________________________")
            print(f"Process 4 S/N{tempDfVt4["Process 4 S/N"]}_______________________________________________________________________________")
            print(f"Process 5 S/N{tempDfVt5["Process 5 S/N"]}_______________________________________________________________________________")
            print(f"Process 6 S/N{tempDfVt6["Process 6 S/N"]}_______________________________________________________________________________")

            #Clearing Cmd Logs When Reaches 10 Lines
            readCount += 1
            if readCount >= 10:
                os.system('cls')
                readCount = 0
            #_______________________________________
        WriteCsv(compiledFrame)
        compileButton.config(text= "Done")
        openOutputDirectory()
        time.sleep(2)
        compileButton.config(text= "COMPILE")
        compileButton.config(state= "normal")
    except FileNotFoundError:
        ErrorReading()
        compileButton.config(text= "COMPILE")
        compileButton.config(state= "normal")

# %%
def StartProgram():
    threading.Thread(target=start).start()

# %%
def openOutputDirectory():
    location = r'\\192.168.2.19\ai_team\AI Program\Outputs\CompiledProcess'
    os.startfile(location)

# %%
def AutoRun():
    global autoRun
    global time_picker

    coolDown = False

    while autoRun:
        print("Auto Run Activated")
        DateAndTimeManager.GetTimeNow()
        print(DateAndTimeManager.timeNow)
        
        hour = time_picker.hours()
        minutes = time_picker.minutes()
        period = time_picker.period()

        timeSet = f"{hour}:{minutes} {period}"
        timeSet = datetime2.strptime(timeSet, "%I:%M %p")
        timeSet = timeSet.strftime("%H:%M")

        print(timeSet)

        if DateAndTimeManager.timeNow == timeSet and not coolDown:
            coolDown = True
            StartProgram()
            time.sleep(70)
            coolDown = False
        time.sleep(1)

# %%
def toggleAutoRun():
    global autoRunButton
    global autoRun
    global compileButton
    global calendarPicker

    if not autoRun:
        autoRunButton.config(image = on)
        compileButton.config(state = "disabled")
        calendarPicker.config(state = "disabled")
        autoRun = True
        setDate()
        AutoRun()
    else:
        autoRunButton.config(image = off)
        compileButton.config(state = "normal")
        calendarPicker.config(state = "normal")
        autoRun = False
        setDate()

# %%
def ToggleAutoRun():
    threading.Thread(target=toggleAutoRun).start()

# %%
def Configure():
    global frame1
    global frame2

    frame1.pack_forget()
    frame2.pack()

# %%
def Back():
    global frame1
    global frame2

    frame1.pack()
    frame2.pack_forget()

# %%
#Ok/Cancel Dialog
def SetTimeConfirmation():
    answer = askokcancel(title='Confirmation', message='Are you sure you want to set the time?')
    if answer:
        Back()

# %%
def setDate():
    global dateToRead
    global dateToReadDashFormat

    global calendarPicker
    global autoRun

    if autoRun:
        DateAndTimeManager.GetDateToday()
        dateToRead = DateAndTimeManager.dateToday
        dateToReadDashFormat = dateToRead.replace("/", "-")
        QualityControlDataManager.yearSet = dateToReadDashFormat[:4]
        print(f"Date To Read: {dateToReadDashFormat}")
        print(f"Year To Read: {QualityControlDataManager.yearSet}")
    else:
        selectedDate = calendarPicker.get_date()
        selectedDate = selectedDate.strftime("%Y/%m/%d")

        dateToRead = selectedDate
        dateToReadDashFormat = dateToRead.replace("/", "-")
        QualityControlDataManager.yearSet = dateToReadDashFormat[:4]
        print(f"Date To Read: {dateToReadDashFormat}")
        print(f"Year To Read: {QualityControlDataManager.yearSet}")

# %%
def ErrorReading():
    showerror(title='Deletion Status', message='File Not Found')

# %%
#Fixing Blur
windll.shcore.SetProcessDpiAwareness(1)

root = tk.Tk()
root.title('FC1 Compiler')
root.iconbitmap('Icons/HiblowLogo.ico')
root.geometry('600x650+50+50')
root.resizable(False, False)

on = PhotoImage(file = "Icons/on.png")
off = PhotoImage(file = "Icons/off.png")

#Frames
frame1 = tk.Frame(root)
frame1.pack()

frame2 = tk.Frame(root)
frame2.pack_forget()

# configure the grid
frame1.columnconfigure(0, weight=1)
frame1.columnconfigure(1, weight=1)

#FRAME1

# place a label on the root window
message = tk.Label(frame1, text="FC1 Compiler", font=("Arial", 12, "bold"))
message.grid(column=0, row=0, columnspan=2, padx=220)

# button
compileButton = tk.Button(frame1, text='COMPILE', font=("Arial", 12), command = StartProgram, width=15, height=1)
compileButton.grid(column=0, row=1, ipadx=5, ipady=5, pady=10, columnspan=2)
compileButton.config(bg="lightgreen", fg="black")

autoRunLabel = tk.Label(frame1, text="Auto Run", font=("Arial", 12, "bold"))
autoRunLabel.grid(column=0, row=2)

autoRunButton = tk.Button(frame1, image = off, bd = 0, font=("Arial", 12), command = ToggleAutoRun)
autoRunButton.grid(column=1, row=2, ipadx=5, ipady=5, pady=10)

configureButton = tk.Button(frame1, text='CONFIGURE', font=("Arial", 8), command = Configure, width=10, height=1)
configureButton.grid(column=0, row=3, ipadx=5, ipady=5, pady=10, columnspan=2)
configureButton.config(bg="lightgreen", fg="black")

calendarPicker = DateEntry(frame1, width=16, background='darkblue', foreground='white', borderwidth=2, date_pattern='yyyy/mm/dd')
calendarPicker.grid(column=0, row=4, pady=20, padx=(200, 0))

#FRAME2

message = tk.Label(frame2, text="Configure", font=("Arial", 12, "bold"))
message.grid(column=0, row=1, columnspan=2, padx=220)

# button
backButton = tk.Button(frame2, text='BACK', font=("Arial", 8), command = Back, width=10, height=1)
backButton.grid(column=0, row=0, ipadx=5, ipady=5, sticky=W)
backButton.config(bg="lightgreen", fg="black")

applyButton = tk.Button(frame2, text='APPLY', font=("Arial", 8), command = SetTimeConfirmation, width=10, height=1)
applyButton.grid(column=1, row=0, ipadx=5, ipady=5, sticky=E)
applyButton.config(bg="lightgreen", fg="black")

time_picker = AnalogPicker(frame2)
time_picker.grid(column = 0, row = 4, columnspan = 2)
theme = AnalogThemes(time_picker)
theme.setNavyBlue()

# StartProgram()

root.protocol("WM_DELETE_WINDOW", StopProgram)
root.mainloop()
